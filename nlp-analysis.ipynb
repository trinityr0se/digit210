# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk import FreqDist
from nltk.text import Text

# %%
with open("sample.txt") as f:
    text = f.read()

tokens = word_tokenize(text)
tokens[:20]
# Out:
# ['[',
#  'Disney',
#  "'s",
#  'Mulan',
#  'Compiled',
#  'by',
#  'Barry',
#  'Adams',
#  'during',
#  'theater',
#  'showings',
#  'in',
#  '1998',
#  'Last',
#  'updated',
#  ':',
#  'August',
#  '18',
#  ',',
#  '1998']

# %%
len(tokens)
# Out:
# 21499

# %%
fdist = FreqDist(tokens)
fdist.most_common(10)
# Out:
# [('the', 989),
#  ('.', 975),
#  (']', 771),
#  ('[', 770),
#  (',', 594),
#  (':', 561),
#  ('and', 533),
#  ('to', 528),
#  ('Mulan', 506),
#  ('a', 297)]

# %%
len(set(tokens)) / len(tokens)
# Out:
# 0.1281454951393088

# %%
text_obj = Text(tokens)
text_obj.similar("war")
# Out:
# to palace break stay fight close means shang training naked
