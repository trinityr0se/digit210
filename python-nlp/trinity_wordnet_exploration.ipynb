# %% [markdown]
# # Reading File Directories and Exploring WordNet
#
# This notebook provides some guidance on working with file directories for a text corpus. It's also introducing some things we can explore with the WordNet dictionary accessible through NLTK.
#
# Read about [Wordnet in Chapter 2, section 5.2](https://www.nltk.org/book/ch02.html#wordnet) of the NLTK book. Wordnet is used in NLP to investigate different forms and senses of meaning that a word might possibly have: we can determine levels of potential ambiguity by working with it. Here's some [more introductory reading](https://mbrenndoerfer.com/writing/history-wordnet-semantic-network) about it.
#
# Credits: Some of our explanations are distilled from [David Birnbaum's introductory Wordnet notebook](https://github.com/djbpitt/wordnet/blob/master/Wordnet.ipynb) that we used to explore ambiguity of spooky words in previous student projects like:
# * This project on [H. P. Lovecraft](https://newtfire.org/eldritch/)
# * This project on Poe and Lovecraft's [Weird Fiction](https://mo-wright.github.io/weirdfiction/svg.html) from Spring 2025

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('tagsets_json')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/trinityrose/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/trinityrose/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/trinityrose/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /Users/trinityrose/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package tagsets_json to
# [nltk_data]     /Users/trinityrose/nltk_data...
# [nltk_data]   Package tagsets_json is already up-to-date!
# True

# %%
# Imports
import os
import nltk
from nltk.corpus import wordnet as wn

# %%
# SMOKE TEST: Explore Wordnet for specific words.
wn.synsets('clear')
# Out:
# [Synset('clear.n.01'),
#  Synset('open.n.01'),
#  Synset('unclutter.v.01'),
#  Synset('clear.v.02'),
#  Synset('clear_up.v.04'),
#  Synset('authorize.v.01'),
#  Synset('clear.v.05'),
#  Synset('pass.v.09'),
#  Synset('clear.v.07'),
#  Synset('clear.v.08'),
#  Synset('clear.v.09'),
#  Synset('clear.v.10'),
#  Synset('clear.v.11'),
#  Synset('clear.v.12'),
#  Synset('net.v.02'),
#  Synset('net.v.01'),
#  Synset('gain.v.08'),
#  Synset('clear.v.16'),
#  Synset('clear.v.17'),
#  Synset('acquit.v.01'),
#  Synset('clear.v.19'),
#  Synset('clear.v.20'),
#  Synset('clear.v.21'),
#  Synset('clear.v.22'),
#  Synset('clear.v.23'),
#  Synset('clear.v.24'),
#  Synset('clear.a.01'),
#  Synset('clear.s.01'),
#  Synset('clear.s.02'),
#  Synset('clear.a.04'),
#  Synset('clear.s.03'),
#  Synset('clear.s.04'),
#  Synset('clean.s.02'),
#  Synset('clear.s.06'),
#  Synset('clear.s.07'),
#  Synset('well-defined.a.02'),
#  Synset('clear.a.11'),
#  Synset('clean.s.01'),
#  Synset('clear.s.09'),
#  Synset('clear.s.10'),
#  Synset('clear.s.11'),
#  Synset('absolved.s.01'),
#  Synset('clear.s.13'),
#  Synset('clear.r.01'),
#  Synset('clearly.r.04')]

# %% [markdown]
# ### Look at some synset data from WordNet
# Choose one of the synsets by its identifier, and lets explore what you can see with it.
# In the next couple of cells we explore how WordNet shares information:
#
# Wordnet shows:
# * A representative word that stands for set of meanings (a "synset"). There may be other representative words, and that same representative word might be used in different senses (and have multiple synsets).
# * A part of speech (POS) identifier, like “n” for ‘noun’ or “v” for ‘verb’.
# * A two-digit number that distinguishes different synsets that may have the same head word and the same POS, but that convey different meaning. For example, the synsets 'ghost.n.01' and 'ghost.n.02' are two different nominal meanings that can be expressed by the lexeme “ghost.”
#
# In WordNet you can request:
# * the available **lemmas** which mean "lexemes" or the available set of words associated with a particular synset.
# * the **definition** associated with a synset

# %%
wn.synset('acquit.v.01').lemmas()
# Out:
# [Lemma('acquit.v.01.acquit'),
#  Lemma('acquit.v.01.assoil'),
#  Lemma('acquit.v.01.clear'),
#  Lemma('acquit.v.01.discharge'),
#  Lemma('acquit.v.01.exonerate'),
#  Lemma('acquit.v.01.exculpate')]

# %%
# For every lem in one of the synsets, isolate just the names without the extra stuff:
for lem in wn.synset('acquit.v.01').lemmas():
    print(lem.name())
# Out:
# acquit
# assoil
# clear
# discharge
# exonerate
# exculpate

# %%
# Here we'll just return the count of the available lemmas for each synset for "clear"
# In this output we're just surveying the data as lists:
for synset in wn.synsets('clear'):
    print(synset, ": ", synset.lemma_names(), ": ", len(synset.lemma_names()))
# Out:
# Synset('clear.n.01') :  ['clear'] :  1
# Synset('open.n.01') :  ['open', 'clear'] :  2
# Synset('unclutter.v.01') :  ['unclutter', 'clear'] :  2
# Synset('clear.v.02') :  ['clear'] :  1
# Synset('clear_up.v.04') :  ['clear_up', 'clear', 'light_up', 'brighten'] :  4
# Synset('authorize.v.01') :  ['authorize', 'authorise', 'pass', 'clear'] :  4
# Synset('clear.v.05') :  ['clear'] :  1
# Synset('pass.v.09') :  ['pass', 'clear'] :  2
# Synset('clear.v.07') :  ['clear'] :  1
# Synset('clear.v.08') :  ['clear'] :  1
# Synset('clear.v.09') :  ['clear', 'top'] :  2
# Synset('clear.v.10') :  ['clear', 'clear_up', 'shed_light_on', 'crystallize', 'crystallise', 'crystalize', 'crystalise', 'straighten_out', 'sort_out', 'enlighten', 'illuminate', 'elucidate'] :  12
# Synset('clear.v.11') :  ['clear'] :  1
# Synset('clear.v.12') :  ['clear'] :  1
# Synset('net.v.02') :  ['net', 'clear'] :  2
# Synset('net.v.01') :  ['net', 'sack', 'sack_up', 'clear'] :  4
# Synset('gain.v.08') :  ['gain', 'take_in', 'clear', 'make', 'earn', 'realize', 'realise', 'pull_in', 'bring_in'] :  9
# Synset('clear.v.16') :  ['clear'] :  1
# Synset('clear.v.17') :  ['clear'] :  1
# Synset('acquit.v.01') :  ['acquit', 'assoil', 'clear', 'discharge', 'exonerate', 'exculpate'] :  6
# Synset('clear.v.19') :  ['clear', 'solve'] :  2
# Synset('clear.v.20') :  ['clear'] :  1
# Synset('clear.v.21') :  ['clear'] :  1
# Synset('clear.v.22') :  ['clear'] :  1
# Synset('clear.v.23') :  ['clear'] :  1
# Synset('clear.v.24') :  ['clear', 'clear_up'] :  2
# Synset('clear.a.01') :  ['clear'] :  1
# Synset('clear.s.01') :  ['clear'] :  1
# Synset('clear.s.02') :  ['clear', 'open'] :  2
# Synset('clear.a.04') :  ['clear'] :  1
# Synset('clear.s.03') :  ['clear'] :  1
# Synset('clear.s.04') :  ['clear'] :  1
# Synset('clean.s.02') :  ['clean', 'clear', 'light', 'unclouded'] :  4
# Synset('clear.s.06') :  ['clear', 'unmortgaged'] :  2
# Synset('clear.s.07') :  ['clear', 'clean-cut', 'clear-cut'] :  3
# Synset('well-defined.a.02') :  ['well-defined', 'clear'] :  2
# Synset('clear.a.11') :  ['clear'] :  1
# Synset('clean.s.01') :  ['clean', 'clear'] :  2
# Synset('clear.s.09') :  ['clear'] :  1
# Synset('clear.s.10') :  ['clear'] :  1
# Synset('clear.s.11') :  ['clear', 'decipherable', 'readable'] :  3
# Synset('absolved.s.01') :  ['absolved', 'clear', 'cleared', 'exculpated', 'exonerated', 'vindicated'] :  6
# Synset('clear.s.13') :  ['clear', 'percipient'] :  2
# Synset('clear.r.01') :  ['clear', 'all_the_way'] :  2
# Synset('clearly.r.04') :  ['clearly', 'clear'] :  2

# %%
# Ask for the definitions and part of speech available for a word lemma names in WordNet
for synset in wn.synsets('clear'):
    print(synset.lemma_names(), ": Part of Speech: ", synset.pos(), ": Definition: ", synset.definition())
# Out:
# ['clear'] : Part of Speech:  n : Definition:  the state of being free of suspicion
# ['open', 'clear'] : Part of Speech:  n : Definition:  a clear or unobstructed space or expanse of land or water
# ['unclutter', 'clear'] : Part of Speech:  v : Definition:  rid of obstructions
# ['clear'] : Part of Speech:  v : Definition:  make a way or path by removing objects
# ['clear_up', 'clear', 'light_up', 'brighten'] : Part of Speech:  v : Definition:  become clear
# ['authorize', 'authorise', 'pass', 'clear'] : Part of Speech:  v : Definition:  grant authorization or clearance for
# ['clear'] : Part of Speech:  v : Definition:  remove
# ['pass', 'clear'] : Part of Speech:  v : Definition:  go unchallenged; be approved
# ['clear'] : Part of Speech:  v : Definition:  be debited and credited to the proper bank accounts
# ['clear'] : Part of Speech:  v : Definition:  go away or disappear
# ['clear', 'top'] : Part of Speech:  v : Definition:  pass by, over, or under without making contact
# ['clear', 'clear_up', 'shed_light_on', 'crystallize', 'crystallise', 'crystalize', 'crystalise', 'straighten_out', 'sort_out', 'enlighten', 'illuminate', 'elucidate'] : Part of Speech:  v : Definition:  make free from confusion or ambiguity; make clear
# ['clear'] : Part of Speech:  v : Definition:  free from payment of customs duties, as of a shipment
# ['clear'] : Part of Speech:  v : Definition:  clear from impurities, blemishes, pollution, etc.
# ['net', 'clear'] : Part of Speech:  v : Definition:  yield as a net profit
# ['net', 'sack', 'sack_up', 'clear'] : Part of Speech:  v : Definition:  make as a net profit
# ['gain', 'take_in', 'clear', 'make', 'earn', 'realize', 'realise', 'pull_in', 'bring_in'] : Part of Speech:  v : Definition:  earn on some commercial or business transaction; earn as salary or wages
# ['clear'] : Part of Speech:  v : Definition:  sell
# ['clear'] : Part of Speech:  v : Definition:  pass an inspection or receive authorization
# ['acquit', 'assoil', 'clear', 'discharge', 'exonerate', 'exculpate'] : Part of Speech:  v : Definition:  pronounce not guilty of criminal charges
# ['clear', 'solve'] : Part of Speech:  v : Definition:  settle, as of a debt
# ['clear'] : Part of Speech:  v : Definition:  make clear, bright, light, or translucent
# ['clear'] : Part of Speech:  v : Definition:  rid of instructions or data
# ['clear'] : Part of Speech:  v : Definition:  remove (people) from a building
# ['clear'] : Part of Speech:  v : Definition:  remove the occupants of
# ['clear', 'clear_up'] : Part of Speech:  v : Definition:  free (the throat) by making a rasping sound
# ['clear'] : Part of Speech:  a : Definition:  readily apparent to the mind
# ['clear'] : Part of Speech:  s : Definition:  free from confusion or doubt
# ['clear', 'open'] : Part of Speech:  s : Definition:  affording free passage or view
# ['clear'] : Part of Speech:  a : Definition:  allowing light to pass through
# ['clear'] : Part of Speech:  s : Definition:  free from contact or proximity or connection
# ['clear'] : Part of Speech:  s : Definition:  characterized by freedom from troubling thoughts (especially guilt)
# ['clean', 'clear', 'light', 'unclouded'] : Part of Speech:  s : Definition:  (of sound or color) free from anything that dulls or dims
# ['clear', 'unmortgaged'] : Part of Speech:  s : Definition:  (especially of a title) free from any encumbrance or limitation that presents a question of fact or law
# ['clear', 'clean-cut', 'clear-cut'] : Part of Speech:  s : Definition:  clear and distinct to the senses; easily perceptible
# ['well-defined', 'clear'] : Part of Speech:  a : Definition:  accurately stated or described
# ['clear'] : Part of Speech:  a : Definition:  free from clouds or mist or haze
# ['clean', 'clear'] : Part of Speech:  s : Definition:  free of restrictions or qualifications
# ['clear'] : Part of Speech:  s : Definition:  free from flaw or blemish or impurity
# ['clear'] : Part of Speech:  s : Definition:  clear of charges or deductions
# ['clear', 'decipherable', 'readable'] : Part of Speech:  s : Definition:  easily deciphered
# ['absolved', 'clear', 'cleared', 'exculpated', 'exonerated', 'vindicated'] : Part of Speech:  s : Definition:  freed from any question of guilt
# ['clear', 'percipient'] : Part of Speech:  s : Definition:  characterized by ease and quickness in perceiving
# ['clear', 'all_the_way'] : Part of Speech:  r : Definition:  completely
# ['clearly', 'clear'] : Part of Speech:  r : Definition:  in an easily perceptible manner

# %% [markdown]
# ## Ambiguity from WordNet's point of view
# When words are ambiguous, they can multiple shades of meaning or different ways we could interpret them. How we decide on the meaning depends on the context of the words. WordNet can't tell you everything about how you could interpret every word in your project, but when words are available in its vast database, you can explore how many synsets (or possible meaningful interpretations) it has on file for that word. You can find which words depend the most on specific contexts for their meaning.
#
# To find out WordNet's sense of how ambiguous a word is, you could just count the number of available synsets for it with Python's **len()**.
# Note: when you want ALL the synsets, use **wn.synsets** (plural)

# %%
spooky_words = ['creep', 'eldritch', 'horror', 'cry', 'scream', 'ghost', 'scare']
for w in spooky_words:
    synsets = len(wn.synsets(w))
    print("The word ", w, "belongs to ", synsets, "synsets in WordNet.")
# Out:
# The word  creep belongs to  8 synsets in WordNet.
# The word  eldritch belongs to  1 synsets in WordNet.
# The word  horror belongs to  3 synsets in WordNet.
# The word  cry belongs to  12 synsets in WordNet.
# The word  scream belongs to  6 synsets in WordNet.
# The word  ghost belongs to  7 synsets in WordNet.
# The word  scare belongs to  4 synsets in WordNet.

# %% [markdown]
# ### WordNet's morphy: for inflected forms like plural vs. singular
# Wordnet won't have an entry for plural forms of words (for example). For other things like -ing words, those tend to have their own WordNet entry.
#
# When working with project data, **run your word tokens through Wordnet's morphy in case they need to be looked up in a lemmatized form**
# `wn.morphy('ghosts')`. Try it out on various word forms:

# %%
wn.morphy('cries')
# Out:
# 'cry'

# %% [markdown]
# ### A Workflow for projects exploring ambiguity
# * Start by isolating a set of words of interest from your project. (One idea: Use nltk's pos tagger to identify all the verbs in your files and retrieve a set of them).
# * Deliver them to WordNet to retrieve their synset counts
# * Output the information on each distinct word from Python to a simple XML, TSV, or JSON (We'll probably use XML)
# * Options:
#     * Use the frequency distribution plotting in Python to see how frequently ambiguous words are used in your corpus (plotting is a bit limited)
#     * Write XSLT to map that information back into your XML files: We can use this to **instantiate** the uses of ambiguous words: retrieve counts of how frequently they appear in the text, and plot with SVGs of your own design. (You could make an SVG representing info about the most ambiguous words. You could also make specific SVGs for ambiguous words of interest to show how they're distributed throughout your texts... what would be interesting to visualize?

# %% [markdown]
# ## Part of Speech (and other related kinds of) Tagging
# NLTK (and spacY and other language models) offer Part of Speech tagging. We could use this to collect sets of distinct verbs, nouns, adjectives.
# * We could learn more about the words in a set by sending them to WordNet.
# * We could also look at words as a network: How often do specific characters rely on a word of interest? Which characters share a word of interest? Or which words of interest are shared by say, male vs. female characters?  (Here's [a student project](http://bamfs.obdurodon.org/allFilms_Results.xhtml) that explored a collection of colorful swear words used by characters in Quentin Tarantino's films.)
#
# In our Text Analysis class, you didn't spend time marking specific words, but you could do that using regex search and replace over your texts. But you could also get some help from POS tagging from NLTK, and mapping that information back to your XML files for further analysis. So let's explore that.  We'll look at POS (part of speech) tagging, but note that it's related to Named Entity Recognition and sentiment analysis.
#
# (Full disclosure: We like POS for reasons of interesting patterns it can display without overdetermining what the data means in context. You can show interesting patterns, especially by working with POS tagging together with WordNet analyses.)

# %% [markdown]
# ## How to get NLTK to do POS tagging
# * Let's open a file, tokenize it, prepare it for nltk to analyze.
# * Then apply the .pos tagger
# * What we see in the output is a list of tuples

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag

filepath = 'sample.txt'
f = open(filepath, 'r', encoding='utf8').read()
# Make a list of tokens in your text. 
# tokenList = f.split()
tokenList = word_tokenize(f)
# How is NLTK's word_tokenize() different from just splitting on spaces? Here's an example of how it's different: 
# Look for "don't" in the output of this cell and see how it's split.
print(tokenList)
# Out:
# ['[', 'Disney', "'s", 'Mulan', 'Compiled', 'by', 'Barry', 'Adams', 'during', 'theater', 'showings', 'in', '1998', 'Last', 'updated', ':', 'August', '18', ',', '1998', 'Source', ':', 'The', 'Internet', 'Movie', 'Scripts', 'Database', '(', 'IMSDb', ')', ':', 'https', ':', '//imsdb.com/scripts/Mulan.html', ']', 'Mulan', 'is', 'the', 'property', 'and', 'copyright', 'of', 'the', 'Walt', 'Disney', 'Company', ',', 'Inc', '.', 'The', 'script', 'on', 'this', 'page', 'was', 'compiled', 'while', 'watching', 'Mulan', 'in', 'the', 'theater', 'during', 'the', 'summer', 'of', '1998', 'when', 'the', 'film', 'originally', 'aired', '.', ']', '[', 'Chinese', 'guard', 'is', 'seen', 'walking', 'on', 'The', 'Great', 'Wall', '.', 'Shan-Yu', "'s", 'falcon', 'swoops', 'down', 'and', 'hits', 'the', 'guard', 'on', 'the', 'head', 'knocking', 'his', 'helmet', 'off', '.', 'The', 'falcon', 'lands', 'on', 'top', 'of', 'a', 'flag', 'pole', 'in', 'front', 'of', 'a', 'full', 'moon', 'and', 'lets', 'out', 'a', 'large', 'cry', '.', 'One', 'grappling', 'hook', 'comes', 'over', 'The', 'Great', 'Wall', '.', 'The', 'guard', 'walks', 'over', 'to', 'the', 'edge', 'and', 'sees', 'many', 'grappling', 'hooks', 'coming', 'towards', 'him', ']', 'Guard', '[', 'yelling', ']', ':', 'We', "'re", 'under', 'attack', '!', 'Light', 'the', 'signal', '!', '[', 'Guard', 'runs', 'to', 'the', 'tower', 'and', 'up', 'the', 'ladder', 'as', 'Hun', 'Bald', 'Man', '#', '1', 'and', 'Hun', 'Long', 'Hair', 'Man', 'appear', 'trying', 'to', 'stop', 'him', '.', 'Hun', 'Bald', 'Man', '#', '1', 'breaks', 'the', 'ladder', 'with', 'his', 'sword', 'just', 'as', 'Guard', 'reaches', 'the', 'top', '.', 'The', 'guard', 'picks', 'up', 'the', 'torch', 'to', 'light', 'the', 'fire', 'and', 'sees', 'Shan-Yu', 'jump', 'over', 'the', 'edge', 'of', 'the', 'tower', 'and', 'looks', 'at', 'him', 'across', 'from', 'the', 'caldron', '.', 'The', 'guard', 'throws', 'the', 'torch', 'into', 'the', 'caldron', 'lighting', 'a', 'large', 'fire', '.', 'Shan-Yu', 'watches', 'as', 'each', 'tower', 'lights', 'their', 'caldrons', 'one', 'by', 'one', ']', 'Guard', '[', 'sternly', ']', ':', 'Now', 'all', 'of', 'China', 'knows', 'you', "'re", 'here', '.', 'Shan-Yu', '[', 'taking', 'the', 'flag', 'and', 'holding', 'it', 'over', 'the', 'fire', ']', ':', 'Perfect', '.', '[', 'Cut', 'to', 'the', 'palace', '.', 'The', 'large', 'doors', 'to', 'the', 'central', 'chamber', 'open', 'as', 'General', 'Li', 'walks', 'in', 'flanked', 'on', 'his', 'left', 'and', 'right', 'by', 'soldiers', 'and', 'approaches', 'the', 'Emperor', '.', 'He', 'bows', ',', 'then', 'looks', 'up', ']', 'General', 'Li', ':', 'Your', 'Majesty', ',', 'the', 'Huns', 'have', 'crossed', 'our', 'Northern', 'border', '.', 'Chi', 'Fu', ':', 'Impossible', '!', 'No', 'one', 'can', 'get', 'through', 'The', 'Great', 'Wall', '.', '[', 'The', 'Emperor', 'motions', 'for', 'Chi', 'Fu', "'s", 'silence', ']', 'General', 'Li', ':', 'Shun-Yu', 'is', 'leading', 'them', '.', 'We', "'ll", 'set', 'up', 'defenses', 'around', 'your', 'palace', 'immediately', '.', 'Emperor', '[', 'forcefully', ']', ':', 'No', '!', 'Send', 'your', 'troops', 'to', 'protect', 'my', 'people', '.', 'Chi', 'Fu', ',', 'Chi', 'Fu', ':', 'Yes', ',', 'your', 'highness', '.', 'Emperor', ':', 'Deliver', 'conscription', 'notices', 'throughout', 'all', 'the', 'provinces', '.', 'Call', 'up', 'reserves', 'and', 'as', 'many', 'new', 'recruits', 'as', 'possible', '.', 'General', 'Li', ':', 'Forgive', 'me', 'your', 'Majesty', ',', 'but', 'I', 'believe', 'my', 'troops', 'can', 'stop', 'him', '.', 'Emperor', ':', 'I', 'wont', 'take', 'any', 'chances', ',', 'General', '.', 'A', 'single', 'grain', 'of', 'rice', 'can', 'tip', 'the', 'scale', '.', 'One', 'man', 'may', 'be', 'the', 'difference', 'between', 'victory', 'and', 'defeat', '.', '[', 'Cut', 'to', 'Mulan', 'using', 'her', 'chopsticks', 'to', 'single', 'out', 'a', 'grain', 'of', 'rice', 'on', 'top', 'of', 'the', 'mound', 'of', 'rice', ']', 'Mulan', ':', 'Quiet', 'and', 'demure', '...', ...

# %%
# Reduce the complexity by: 1) lowercasing them, and 2) returning the set() of words (remove multiple of the same value)
lowercaseTokens = [token.lower() for token in tokenList]
uniqueTokens = set(lowercaseTokens)
print(uniqueTokens)
# Out:
# {'cannon', 'opaque', 'honor', 'sadness', 'positioned', 'ugly', 'nervous', 'show', 'sleep', 'reacting', 'aims', 'flags', 'smoke', 'sighing', 'recent', 'sticking', 'rabbit', 'dear', 'lady/fa', 'across', 'passed', 'why', 'fruit', 'copyright', 'hook', 'thrown', 'pond', 'covering', 'intact', 'cheers', 'through', 'knew', "'m", 'tries', 'yeah', 'thinks', 'dinner', 'past', 'laugh', 'hya', 'attacks', 'bucket', 'different', 'confidently', 'glow', 'far', 'motions', 'make', 'worthwhile', 'company', 'elbow', 'clear', '5', 'fortune', 'soldier', 'it', 'sees', 'immediately', 'crouched', 'opposite', 'picture', 'sadly', 'ahem', 'circle', 'curd', 'wades', 'brushing', 'bust', 'came', 'scars', 'real', 'bessy', 'rides', 'continues', 'crest', 'flanked', 'highness', 'chances', 'happens', 'ouch', 'in', 'forehead', 'moouuuu', 'hauling', 'groans', 'bearing', 'clay', 'fought', 'breakfast', 'ignore', 'tip', 'taste', 'horror', 'truly', 'rocket', 'serve', 'bows', 'drawn', 'tight', 'chopsticks', 'monkey', 'spot', 'respect', 'bringing', 'otherwise', 'stabs', 'aching', 'flips', 'fast', 'inspiring', 'fashion', 'match', 'return', 'forgive', 'stay', 'gift', 'lighters', '7', 'disgracing', 'starting', 'mulan', 'like', 'begin', 'make-up', 'village', 'images', "'kay", 'ask', 'grasps', 'whiskers', 'lodged', 'cutting', 'pointer', 'keeping', 'their', 'fight', 'misses', 'words', 'without', 'maybe', 'eat', 'hoo', 'breathes', 'gon', 'corner', 'stumbling', '[', 'actions', 'either', 'woo', 'disapprovingly', 'fade', 'job', 'tossing', 'hi', 'knees', 'charges', 'imsdb', 'city', 'throws', 'dodges', 'nothing', 'mess', 'watching', 'counting', "n't", 'ooo', 'talkin', 'smiley', 'ghost', 'military', 'protection', '``', 'cover', 'carrying', 'act', 'unlike', 'lady-killer', 'push', 'muffled', 'recite', 'was', 'troops', 'paler', 'fa', 'win', 'expect', 'grab', 'look', 'demure', 'what', 'thank', 'enough', 'starts', 'stallions', 'somberly', 'tea-cup', 'baby', 'dismount', 'clip', 'polite', 'reemerge', 'remember', 'shows', 'flying', 'feathers', 'townsfolk', 'face', 'hesitantly', 'general', 'closing', 'coursing', 'train', 'swallows', 'stuck', 'writes', 'uhhh', 'shirt', 'an', 'penalty', 'kingdom', 'ear', 'kill', 'ride', 'feeding', 'continuing', 'chinese', 'fuse', 'allowing', 'claws', 'shoot', 'stomach', 'mind', 'khan-ie', "'s", 'case', 'cricket', 'pole', 'made', 'ga', 'charred', 'hold', 'safety', 'sets', 'shield', 'he', 'along', 'agreement', 'opening', 'singing', 'anybody', 'pattern', 'grrrr', 'outdoors', 'twisted', 'egg', 'stamps', 'prepares', 'nods', 'learned', 'hooks', 'forcefully', 'me', 'next', 'salutes', 'inc', 'hua', 'night', 'boo', 'takes', 'fail', 'cheer', 'ways', 'characters', 'upwards', 'whistles', 'stoney', 'acting', 'go', 'pleadingly', 'anywhere', 'produces', 'appears', 'pay', 'grounds', 'gasps', 'falls', 'the', 'young', 'post', 'ram', 'word', 'dreamily', 'cage', 'saliva', 'during', 'crows', 'him', "'xcuses", 'support', 'flail', 'main', 'well', 'drinking', 'uphold', 'excellency', 'parade', 'belly', 'glancing', 'canopy', 'breathing', 'fall', 'fal', 'mountain', 'rest', 'explodes', 'throw', "'ve", 'pad', 'refusing', 'heads', 'belong', 'reassuredly', 'caldron', 'glory', 'embedded', 'catch', 'disney', 'know', 'doggie', 'sweep', 'struck', 'his', 'letter', 'climb', 'ahhhhhhhhhhh', 'die', 'comes', 'forces', 'pride', 'working', 'stunned', 'silence', 'hide', 'brings', 'xiao', 'strongest', 'propelled', 'sill', 'looked', 'makes', 'fire', 'wish', 'truth', 'clipboard', 'boxers', 'announcing', 'anyone', 'prepare', 'greatest', 'southern', 'wrapped', 'dishonored', 'vile', 'hawk', 'going', "fam'ly", 'three', 'uses', 'pulled', 'pathetic', 'close-up', 'caldrons', 'throat', 'wings', 'skinny', 'peeks', 'searches', 'grinning', 'frauds', 'sticks', 'chest', 'allowed', 'second', 'beautiful', 'feel', 'gallops', 'daughter', 'road', 'gladly', 'handing', 'grandma', 'gir-', 'outstretched', 'feet', 'cabinet', 'we', 'pile', 'except', 'emerged', 'mmm', 'size', "''", 'crouching', "'ll", 'soar', 'crossed', 'teapot',  ...

# %%
# Let's try out the NLTK POS tagger on the uniqueTokens
pos_tag(uniqueTokens)
# Out:
# [('cannon', 'NN'),
#  ('opaque', 'NNS'),
#  ('honor', 'VBP'),
#  ('sadness', 'NN'),
#  ('positioned', 'VBN'),
#  ('ugly', 'RB'),
#  ('nervous', 'JJ'),
#  ('show', 'NN'),
#  ('sleep', 'JJ'),
#  ('reacting', 'VBG'),
#  ('aims', 'NNS'),
#  ('flags', 'NNS'),
#  ('smoke', 'VBD'),
#  ('sighing', 'VBG'),
#  ('recent', 'JJ'),
#  ('sticking', 'VBG'),
#  ('rabbit', 'NN'),
#  ('dear', 'JJ'),
#  ('lady/fa', 'NN'),
#  ('across', 'IN'),
#  ('passed', 'VBN'),
#  ('why', 'WRB'),
#  ('fruit', 'NN'),
#  ('copyright', 'NN'),
#  ('hook', 'NN'),
#  ('thrown', 'VBN'),
#  ('pond', 'NN'),
#  ('covering', 'VBG'),
#  ('intact', 'JJ'),
#  ('cheers', 'NNS'),
#  ('through', 'IN'),
#  ('knew', 'NN'),
#  ("'m", 'VBP'),
#  ('tries', 'NNS'),
#  ('yeah', 'VBP'),
#  ('thinks', 'NNS'),
#  ('dinner', 'VBP'),
#  ('past', 'IN'),
#  ('laugh', 'NN'),
#  ('hya', 'NN'),
#  ('attacks', 'NNS'),
#  ('bucket', 'VBP'),
#  ('different', 'JJ'),
#  ('confidently', 'RB'),
#  ('glow', 'VBP'),
#  ('far', 'RB'),
#  ('motions', 'NNS'),
#  ('make', 'VBP'),
#  ('worthwhile', 'JJ'),
#  ('company', 'NN'),
#  ('elbow', 'VBD'),
#  ('clear', 'JJ'),
#  ('5', 'CD'),
#  ('fortune', 'NN'),
#  ('soldier', 'JJR'),
#  ('it', 'PRP'),
#  ('sees', 'VBZ'),
#  ('immediately', 'RB'),
#  ('crouched', 'VBN'),
#  ('opposite', 'JJ'),
#  ('picture', 'NN'),
#  ('sadly', 'RB'),
#  ('ahem', 'JJ'),
#  ('circle', 'NN'),
#  ('curd', 'NN'),
#  ('wades', 'IN'),
#  ('brushing', 'VBG'),
#  ('bust', 'NN'),
#  ('came', 'VBD'),
#  ('scars', 'NNS'),
#  ('real', 'JJ'),
#  ('bessy', 'JJ'),
#  ('rides', 'NNS'),
#  ('continues', 'VBZ'),
#  ('crest', 'JJS'),
#  ('flanked', 'JJ'),
#  ('highness', 'NN'),
#  ('chances', 'NNS'),
#  ('happens', 'VBZ'),
#  ('ouch', 'JJ'),
#  ('in', 'IN'),
#  ('forehead', 'JJ'),
#  ('moouuuu', 'NN'),
#  ('hauling', 'VBG'),
#  ('groans', 'NNS'),
#  ('bearing', 'VBG'),
#  ('clay', 'NN'),
#  ('fought', 'VBD'),
#  ('breakfast', 'NN'),
#  ('ignore', 'NN'),
#  ('tip', 'NN'),
#  ('taste', 'NN'),
#  ('horror', 'NN'),
#  ('truly', 'RB'),
#  ('rocket', 'JJ'),
#  ('serve', 'NN'),
#  ('bows', 'NNS'),
#  ('drawn', 'VBN'),
#  ('tight', 'JJ'),
#  ('chopsticks', 'NNS'),
#  ('monkey', 'VBP'),
#  ('spot', 'NN'),
#  ('respect', 'NN'),
#  ('bringing', 'VBG'),
#  ('otherwise', 'RB'),
#  ('stabs', 'JJ'),
#  ('aching', 'VBG'),
#  ('flips', 'NNS'),
#  ('fast', 'RB'),
#  ('inspiring', 'VBG'),
#  ('fashion', 'NN'),
#  ('match', 'NN'),
#  ('return', 'NN'),
#  ('forgive', 'JJ'),
#  ('stay', 'NN'),
#  ('gift', 'NN'),
#  ('lighters', 'NNS'),
#  ('7', 'CD'),
#  ('disgracing', 'VBG'),
#  ('starting', 'VBG'),
#  ('mulan', 'NN'),
#  ('like', 'IN'),
#  ('begin', 'JJ'),
#  ('make-up', 'JJ'),
#  ('village', 'NN'),
#  ('images', 'NNS'),
#  ("'kay", 'POS'),
#  ('ask', 'NN'),
#  ('grasps', 'NN'),
#  ('whiskers', 'NNS'),
#  ('lodged', 'VBD'),
#  ('cutting', 'VBG'),
#  ('pointer', 'NN'),
#  ('keeping', 'VBG'),
#  ('their', 'PRP$'),
#  ('fight', 'NN'),
#  ('misses', 'VBZ'),
#  ('words', 'NNS'),
#  ('without', 'IN'),
#  ('maybe', 'RB'),
#  ('eat', 'NN'),
#  ('hoo', 'JJ'),
#  ('breathes', 'NNS'),
#  ('gon', 'VBP'),
#  ('corner', 'NN'),
#  ('stumbling', 'VBG'),
#  ('[', 'JJ'),
#  ('actions', 'NNS'),
#  ('either', 'CC'),
#  ('woo', 'JJ'),
#  ('disapprovingly', 'RB'),
#  ('fade', 'JJ'),
#  ('job', 'NN'),
#  ('tossing', 'VBG'),
#  ('hi', 'NN'),
#  ('knees', 'NNS'),
#  ('charges', 'NNS'),
#  ('imsdb', 'VBP'),
#  ('city', 'NN'),
#  ('throws', 'NNS'),
#  ('dodges', 'VBZ'),
#  ('nothing', 'NN'),
#  ('mess', 'NN'),
#  ('watching', 'VBG'),
#  ('counting', 'VBG'),
#  ("n't", 'RB'),
#  ('ooo', 'VB'),
#  ('talkin', 'JJ'),
#  ('smiley', 'NN'),
#  ('ghost', 'NN'),
#  ('military', 'JJ'),
#  ('protection', 'NN'),
#  ('``', '``'),
#  ('cover', 'NN'),
#  ('carrying', 'NN'),
#  ('act', 'NN'),
#  ('unlike', 'IN'),
#  ('lady-killer', 'JJ'),
#  ('push', 'NN'),
#  ('muffled', 'VBD'),
#  ('recite', 'NN'),
#  ('was', 'VBD'),
#  ('troops', 'JJ'),
#  ('paler', 'NN'),
#  ('fa', 'NN'),
#  ('win', 'VBP'),
#  ('expect', 'JJ'),
#  ('grab', 'NN'),
#  ('look', 'NN'),
#  ('demure', 'NN'),
#  ('what', 'WP'),
#  ('thank', 'VBD'),
#  ('enough', 'JJ'),
#  ('starts', 'NNS'),
#  ('stallions', 'NNS'),
#  ('somberly', 'RB'),
#  ('tea-cup', 'JJ'),
#  ('baby', 'NN'),
#  ('dismount', 'NN'),
#  ('clip', 'NN'),
#  ('polite', 'JJ'),
#  ('reemerge', 'NN'),
#  ('remember', 'NN'),
#  ('shows', 'NNS'),
#  ('flying', 'VBG'),
#  ('feathers', 'NNS'),
#  ('townsfolk', 'JJ'),
#  ('face', 'NN'),
#  ('hesitantly', 'RB'),
#  ('general', 'JJ'),
#  ('closing', 'NN'),
#  ('coursing', 'VBG'),
#  ('train', 'NN'),
#  ('swallows', 'NNS'),
#  ('stuck', 'VBP'),
#  ('writes', 'VBZ'),
#  ('uhhh', 'JJ'),
#  ('shirt', 'NN'),
#  ('an', 'DT'),
#  ('penalty', 'NN'),
#  ('kingdom', 'NN'),
#  ('ear', 'VBP'),
#  ('kill', 'VB'),
#  ('ride', 'VB'),
#  ('feeding', 'VBG'),
#  ('continuing', 'VBG'),
#  ('chinese', 'JJ'),
#  ('fuse', 'NN'),
#  ('allowing', 'VBG'),
#  ('claws', 'NNS'),
#  ('shoot', 'VBP'),
#  ('stomach', 'NN'),
#  ('mind', 'RBS'),
#  ('khan-ie', 'NN'),
#  ("'s", 'POS'),
#  ('case', 'NN'),
#  ('cricket', 'NN'),
#  ('pole', 'NN'),
#  ('made', 'VBD'),
#  ('ga', 'NN'),
#  ('charred', 'VBD'),
#  ('hold', 'JJ'),
#  ('safety', 'NN'),
#  ('sets', 'NNS'),
#  ('shield', 'VBD'),
#  ('he', 'PRP'),
#  ('along', 'RP'),
#  ('agreement', 'NN'),
#  ('opening', 'VBG'),
#  ('singing', 'VBG'),
#  ('anybody', 'NN'),
#  ('pattern', 'JJ'),
#  ('grrrr', 'NN'),
#  ('outdoors', 'NNS'),
#  ('twisted', 'VBD'),
#  ('egg', 'NN'),
#  ('stamps', 'NNS'),
#  ('prepares', 'VBZ'),
#  ('nods', 'NNS'),
#  ('learned', 'VBD'),
#  ('hooks', 'NNS'),
#  ('forcefully', 'RB'),
#  ('me', 'PRP'),
#  ('next', 'JJ'),
#  ('salutes', 'NNS'),
#  ('inc', 'VBP'),
#  ('hua', 'JJ'),
#  ('night', 'NN'),
#  ('boo', 'NN'),
#  ('takes', 'VBZ'),
#  ('fail', 'VBP'),
#  ('cheer', 'NN'),
#  ('ways', 'NNS'),
#  ('characters', 'NNS'),
#  ('upwards', 'NNS'),
#  ('whistles', 'NNS'),
#  ('stoney', 'VBP'),
#  ('acting', 'VBG'),
#  ('go', 'VBP'),
#  ('pleadingly', 'RB'),
#  ('anywhere', 'RB'),
#  ('produces', 'VBZ'),
#  ('appears', 'VBZ'),
#  ('pay', 'VB'),
#  ('grounds', 'NNS'),
#  ('gasps', 'JJ'),
#  ('falls', 'VBZ'),
#  ('the', 'DT'),
#  ('young', 'JJ'),
#  ('post', 'NN'),
#  ('ram', 'NN'),
#  ('word', 'NN'),
#  ('dreamily', 'RB'),
#  ('cage', 'VB'),
#  ('saliva', 'NN'),
#  ('during', 'IN'),
#  ('crows', 'NNS'),
#  ('him', 'PRP'),
#  ("'xcuses", 'VBZ'),
#  ('support', 'NN'),
#  ('flail', 'NN'),
#  ('main', 'JJ'),
#  ('well', 'RB'),
#  ('drinking', 'VBG'),
#  ('uphold', 'JJ'),
#  ('excellency', 'NN'),
#  ('parade', 'VBD'),
#  ('belly', 'RB'),
#  ('glancing', 'VBG'),
#  ('canopy', 'NN'),
#  ('breathing', 'VBG'),
#  ('fall', 'NN'),
#  ('fal', 'NN'),
#  ('mountain', 'NN'),
#  ('rest', 'NN'),
#  ('explodes', 'NNS'),
#  ('throw', 'VBP'),
#  ("'ve", 'VBP'),
#  ('pad', 'VBN'),
#  ('refusing', 'VBG'),
#  ('heads', 'NNS'),
#  ('belong', 'RB'),
#  ('reassuredly', 'RB'),
#  ('caldron', 'JJ'),
#  ('glory', 'NN'),
#  ('embedded', 'VBD'),
#  ('catch', 'NN'),
#  ('disney', 'NN'),
#  ('know', 'VBP'),
#  ('doggie', 'JJ'),
#  ('sweep', 'JJ'),
#  ('struck', 'VBD'),
#  ('his', 'PRP$'),
#  ('letter', 'NN'),
#  ('climb', 'NN'),
#  ('ahhhhhhhhhhh', 'NN'),
#  ('die', 'NN'),
#  ('comes', 'VBZ'),
#  ('forces', 'NNS'),
#  ('pride', 'IN'),
#  ('working', 'VBG'),
#  ('stunned', 'VBN'),
#  ('silence', 'NN'),
#  ('hide', 'NN'),
#  ('brings', 'VBZ'),
#  ('xiao', 'JJ'),
#  ('strongest', 'NN'),
#  ('propelled', 'VBD'),
#  ('sill', 'NN'),
#  ('looked', 'VBD'),
#  ('makes', 'VBZ'),
#  ('fire', 'NN'),
#  ('wish', 'JJ'),
#  ('truth', 'NN'),
#  ('clipboard', 'NN'),
#  ('boxers', 'NNS'),
#  ('announcing', 'VBG'),
#  ('anyone', 'NN'),
#  ('prepare', 'JJ'),
#  ('greatest', 'JJS'),
#  ('southern', 'JJ'),
#  ('wrapped', 'VBN'),
#  ('dishonored', 'VBN'),
#  ('vile', 'IN'),
#  ('hawk', 'NN'),
#  ('going', 'VBG'),
#  ("fam'ly", 'JJ'),
#  ('three', 'CD'),
#  ('uses', 'NNS'),
#  ('pulled', 'VBD'),
#  ('pathetic', 'JJ'),
#  ('close-up', 'JJ'),
#  ('caldrons', 'NNS'),
#  ('throat', 'VBP'),
#  ('wings', 'NNS'),
#  ('skinny', 'JJ'),
#  ('peeks', 'NNS'),
#  ('searches', 'NNS'),
#  ('grinning', 'VBG'),
#  ('frauds', 'NN'),
#  ('sticks', 'NNS'),
#  ('chest', 'VBP'),
#  ('allowed', 'VBN'),
#  ('second', 'JJ'),
#  ('beautiful', 'JJ'),
#  ('feel', 'NN'),
#  ('gallops', 'NNS'),
#  ('daughter', 'VBP'),
#  ('road', 'NN'),
#  ('gladly', 'RB'),
#  ('handing', 'VBG'),
#  ('grandma', 'JJ'),
#  ('gir-', 'JJ'),
#  ('outstretched', 'JJ'),
#  ('feet', 'NNS'),
#  ('cabinet', 'NN'),
#  ('we', 'PRP'),
#  ('pile', 'VBP'),
#  ('except', 'IN'),
#  ('emerged', 'VBN'),
#  ('mmm', 'NN'),
#  ('size', 'NN'),
#  ("''", "''"),
#  ('crouching', 'VBG'),
#  ("'ll", 'MD'),
#  ('soar', 'VB'),
#  ('crossed', 'JJ'),
#  ('teapot', 'NN'),
#  ('exits', 'NNS'),
#  ('slices', 'NNS'),
#  ('fulfill', 'RB'),
#  ('stances', 'NNS'),
#  ('sitting', 'VBG'),
#  ('prayer', 'NN'),
#  ('stops', 'NNS'),
#  ('bang', 'VBP'),
#  ('raises', 'VBZ'),
#  ('again', 'RB'),
#  ('winds', 'NNS'),
#  ('rinse', 'VBP'),
#  ('highly', 'RB'),
#  ('dress', 'JJ'),
#  ('townspeople', 'NN'),
#  ('business', 'NN'),
#  ('reading', 'VBG'),
#  ('believe', 'VBP'),
#  ('proceeding', 'VBG'),
#  ('sequence', 'NN'),
#  ('ow', 'NN'),
#  ('would', 'MD'),
#  ('remains', 'VB'),
#  ('surprising', 'JJ'),
#  ('undertaker', 'NN'),
#  ('gains', 'NNS'),
#  ('comb', 'VBP'),
#  ('river', 'NN'),
#  ('prayed', 'VBN'),
#  ('old', 'JJ'),
#  ('loudly', 'RB'),
#  ('difference', 'NN'),
#  ('sack', 'NN'),
#  ('blow', 'NN'),
#  ('swinging', 'VBG'),
#  ('lake', 'NN'),
#  ('might', 'MD'),
#  ('bye', 'VB'),
#  ('silently', 'RB'),
#  ('screen', 'JJ'),
#  ('grain', 'NN'),
#  ('hitting', 'VBG'),
#  ('wild', 'JJ'),
#  ('waiting', 'VBG'),
#  ('growl', 'JJ'),
#  ('end', 'NN'),
#  ('parasol', 'NNS'),
#  ('take', 'VBP'),
#  ('swim', 'JJ'),
#  ('destroy', 'NN'),
#  ('blast', 'NN'),
#  ('better', 'RBR'),
#  ('doing', 'VBG'),
#  ('august', 'JJ'),
#  ('waves', 'NNS'),
#  ('easily', 'RB'),
#  ('ta', 'IN'),
#  ('messing', 'VBG'),
#  ('step', 'NN'),
#  ('loss', 'NN'),
#  ('provinces', 'NNS'),
#  ('caused', 'VBD'),
#  ('saddest', 'JJS'),
#  ('kindly', 'RB'),
#  ('shadow', 'JJ'),
#  ('news', 'NN'),
#  ('done', 'VBN'),
#  ('okey', 'JJ'),
#  ('arrive', 'JJ'),
#  ('finest', 'JJS'),
#  ('rope', 'NN'),
#  ('course', 'NN'),
#  ('yard', 'NN'),
#  ('self', 'PRP'),
#  ('small', 'JJ'),
#  ('since', 'IN'),
#  ('speaks', 'JJ'),
#  ('slaps', 'NNS'),
#  ('bedroom', 'NN'),
#  ('ya', 'NN'),
#  ('honorable', 'JJ'),
#  ('tranquil', 'NN'),
#  ('hai', 'NN'),
#  ('skills', 'NNS'),
#  ('will', 'MD'),
#  ('yep', 'VB'),
#  ('expressing', 'VBG'),
#  ('zoom', 'NN'),
#  ('brew', 'VBD'),
#  ('source', 'NN'),
#  ('then', 'RB'),
#  ('conscription', 'NN'),
#  ('sits', 'NNS'),
#  ('pen', 'VBP'),
#  ('sings', 'NNS'),
#  ('try', 'VBP'),
#  ('entire', 'JJ'),
#  ('ahhhhhhh', 'JJ'),
#  ('warriors', 'NNS'),
#  ('cleaned', 'VBD'),
#  ('wrong', 'JJ'),
#  ('skyward', 'RB'),
#  ('wraps', 'VBZ'),
#  ('happy', 'JJ'),
#  ('rises', 'NNS'),
#  ('found', 'VBD'),
#  ('shaking', 'VBG'),
#  ('innocently', 'RB'),
#  ('incense', 'JJ'),
#  ('apple', 'NN'),
#  ('pacing', 'NN'),
#  ('reins', 'VBZ'),
#  ('king', 'VBG'),
#  ('daisies', 'NNS'),
#  ('floor', 'NN'),
#  ('ahhhhhh', 'IN'),
#  ('not', 'RB'),
#  ('repeat', 'VB'),
#  ('patient', 'JJ'),
#  ('doll', 'NN'),
#  ('walls', 'NNS'),
#  ('dragon', 'VBP'),
#  ('stroking', 'VBG'),
#  ('also', 'RB'),
#  ('ancestors', 'NNS'),
#  ('pop', 'VBP'),
#  ('follows', 'VBZ'),
#  ('tail', 'NN'),
#  ('smile', 'NN'),
#  ('heavily', 'RB'),
#  ('perfect', 'NN'),
#  ('said', 'VBD'),
#  ('manly', 'RB'),
#  ('run', 'VBN'),
#  ('volley', 'NN'),
#  ('lip', 'NN'),
#  ('man', 'NN'),
#  ('heart', 'NN'),
#  ('upset', 'JJ'),
#  ('splashing', 'NN'),
#  ('slouch', 'JJ'),
#  ('taps', 'NNS'),
#  ('mister', 'RBR'),
#  ('stuff', 'NN'),
#  ('armies', 'NNS'),
#  ('never', 'RB'),
#  ('horde', 'VBP'),
#  ('impress', 'JJ'),
#  ('direction', 'NN'),
#  ('kneel', 'VB'),
#  ('discontent', 'JJ'),
#  ('hurry', 'JJ'),
#  ('chamber', 'NN'),
#  ('does', 'VBZ'),
#  ('had', 'VBD'),
#  ('home', 'VBN'),
#  ('number', 'NN'),
#  ('transformation', 'NN'),
#  ('pushes', 'NNS'),
#  ('broken', 'VBP'),
#  ('tattered', 'JJ'),
#  ('huny', 'NN'),
#  ('reads', 'VBZ'),
#  ('quiver', 'RB'),
#  ('unsuccessfully', 'RB'),
#  ('upstream', 'JJ'),
#  ('needs', 'NNS'),
#  ('lantern', 'JJ'),
#  ('roll', 'NN'),
#  ('explain', 'NN'),
#  ('defeat', 'NN'),
#  ('cooks', 'NNS'),
#  ('because', 'IN'),
#  ('signal', 'JJ'),
#  ('give', 'NN'),
#  ('mountains', 'NNS'),
#  ('masquerade', 'VBP'),
#  ('those', 'DT'),
#  ('chicken', 'JJ'),
#  ('wobbling', 'JJ'),
#  ('cannons', 'NNS'),
#  ('sense', 'NN'),
#  ('reflects', 'VBZ'),
#  ('stars', 'NNS'),
#  ('fireworks', 'VBZ'),
#  ('trust', 'NN'),
#  ('background', 'NN'),
#  ('tomorrow', 'NN'),
#  ('break', 'NN'),
#  ('movement', 'NN'),
#  ('are', 'VBP'),
#  ('showering', 'VBG'),
#  ('blending', 'VBG'),
#  ('hole', 'NN'),
#  ('due', 'JJ'),
#  ('tell', 'NN'),
#  ('rowing', 'VBG'),
#  ('air', 'NN'),
#  ('cup', 'NN'),
#  ('doooou', 'NN'),
#  ('strike', 'NN'),
#  ('fool', 'NN'),
#  ('knock', 'NN'),
#  ('dumbfounded', 'VBD'),
#  ('hit', 'JJ'),
#  ('coach', 'NN'),
#  ('duties', 'NNS'),
#  ('is', 'VBZ'),
#  ('slips', 'NNS'),
#  ('back', 'RB'),
#  ('spitting', 'VBG'),
#  ('message', 'NN'),
#  ('did', 'VBD'),
#  ('danger', 'RB'),
#  ('injured', 'VBN'),
#  ('before', 'IN'),
#  ('goes', 'VBZ'),
#  ('hungry', 'JJ'),
#  ('rushing', 'VBG'),
#  ('shrimp', 'JJ'),
#  ('hits', 'NNS'),
#  ('other', 'JJ'),
#  ('search', 'NN'),
#  ('collide', 'NN'),
#  ('buildings', 'NNS'),
#  ('thinking', 'VBG'),
#  ('should', 'MD'),
#  ('long-hair', 'JJ'),
#  ('fans', 'NNS'),
#  ('killed', 'VBN'),
#  ('humph', 'RB'),
#  ('hu', 'JJ'),
#  ('instead', 'RB'),
#  ('ummmm', 'JJ'),
#  ('uncovers', 'NNS'),
#  ('people', 'NNS'),
#  ('ringing', 'VBG'),
#  ('matchmaker', 'NN'),
#  ('gai', 'NN'),
#  ('awning', 'VBG'),
#  ('mmm-hmm', 'JJ'),
#  ('knocking', 'VBG'),
#  ('corn', 'NN'),
#  ('relax', 'VB'),
#  ('off', 'RP'),
#  ('clean', 'JJ'),
#  ('gate', 'NN'),
#  ('yelling', 'VBG'),
#  ('staff', 'NN'),
#  ('screaming', 'VBG'),
#  ('uncontrollably', 'RB'),
#  ('washed', 'VBN'),
#  ('wont', 'NN'),
#  ('tonight', 'NN'),
#  ('elbowing', 'VBG'),
#  ('hun', 'NN'),
#  ('major', 'JJ'),
#  ('behind', 'IN'),
#  ('inside', 'JJ'),
#  ('bear', 'JJ'),
#  ('tongue', 'NN'),
#  ('slip', 'NN'),
#  ('pauses', 'VBZ'),
#  ('reflection', 'NN'),
#  ('giant', 'JJ'),
#  ('free', 'JJ'),
#  ('deceived', 'VBN'),
#  ('notes', 'NNS'),
#  ('standing', 'VBG'),
#  ('suit', 'NN'),
#  ('kite', 'FW'),
#  ('combing', 'VBG'),
#  ('met', 'VBD'),
#  ('lunges', 'NNS'),
#  ('of', 'IN'),
#  ('exactly', 'RB'),
#  ('retreating', 'VBG'),
#  ('statue', 'JJ'),
#  ('identity', 'NN'),
#  ('himself', 'PRP'),
#  ('cook', 'VBP'),
#  ('depends', 'VBZ'),
#  ('scattering', 'NN'),
#  ('could', 'MD'),
#  ('ca', 'MD'),
#  ('imperial', 'VB'),
#  ('knocked', 'VBD'),
#  ('saddle', 'JJ'),
#  ('somehow', 'RB'),
#  ('shore', 'RB'),
#  ('stationed', 'JJ'),
#  ('shine', 'NN'),
#  ('swiftly', 'RB'),
#  ('get', 'VB'),
#  ('dumpling', 'VBG'),
#  ('torch', 'RB'),
#  ('mysterious', 'JJ'),
#  ('extra', 'JJ'),
#  ('arts', 'NNS'),
#  ('breaks', 'NNS'),
#  ('tear', 'JJ'),
#  ('multiple', 'JJ'),
#  ('final', 'JJ'),
#  ('neck', 'NN'),
#  ('toes', 'NNS'),
#  ("'hello", 'CD'),
#  ('appearing', 'VBG'),
#  ('land', 'NN'),
#  ('teacher', 'NN'),
#  ('squirts', 'NNS'),
#  ('steady', 'JJ'),
#  ('kissing', 'VBG'),
#  ('in-laws', 'JJ'),
#  ('means', 'NNS'),
#  ('database', 'VBP'),
#  ('dead', 'JJ'),
#  ("'black", 'POS'),
#  ('pleasurable', 'JJ'),
#  ('demonstrate', 'NN'),
#  ('trough', 'IN'),
#  ('live', 'JJ'),
#  ('propelling', 'VBG'),
#  ('chien-po', 'JJ'),
#  ('astonishingly', 'RB'),
#  ('bone', 'NN'),
#  ('shot', 'NN'),
#  ('dressed', 'VBN'),
#  ('rare', 'JJ'),
#  ('parents', 'NNS'),
#  ('nodding', 'VBG'),
#  ('march', 'NN'),
#  ('earrings', 'NNS'),
#  ('square', 'VBP'),
#  ('adams', 'IN'),
#  ('closer', 'JJR'),
#  ('offers', 'NNS'),
#  ('dances', 'NNS'),
#  ('getting', 'VBG'),
#  ('typhoon', 'NN'),
#  ('covered', 'VBD'),
#  ('ha', 'JJ'),
#  ('both', 'DT'),
#  ('worried', 'JJ'),
#  ('picky', 'NN'),
#  ('wait', 'NN'),
#  ('little', 'JJ'),
#  ('meeting', 'NN'),
#  ('pointing', 'VBG'),
#  ('walk', 'NN'),
#  ('disintegrate', 'NN'),
#  ('warrior', 'WRB'),
#  ('disdainfully', 'RB'),
#  ('alarmed', 'VBN'),
#  ('granddaughter', 'JJ'),
#  ('life', 'NN'),
#  ('gallop', 'NN'),
#  ('seeing', 'VBG'),
#  ('shake', 'JJ'),
#  ('length', 'NN'),
#  ('were', 'VBD'),
#  ('responsibility', 'JJ'),
#  ('some', 'DT'),
#  ('scripts', 'NNS'),
#  ('put', 'VBD'),
#  ('thunder', 'RP'),
#  ('chin', 'NN'),
#  ('bites', 'NNS'),
#  ('stupid', 'VBP'),
#  ('insecurely', 'RB'),
#  ('pots', 'JJ'),
#  ('hug', 'NN'),
#  ('stretched', 'VBD'),
#  ('charging', 'VBG'),
#  ('impressive', 'JJ'),
#  ("'t", 'JJ'),
#  ('tablets', 'NNS'),
#  ('dancers', 'NNS'),
#  ('pig', 'VBP'),
#  ('weeks', 'NNS'),
#  ('full', 'JJ'),
#  ('follow', 'VBP'),
#  ('worked', 'VBN'),
#  ('add', 'RP'),
#  ('sorry', 'JJ'),
#  ('short', 'JJ'),
#  ('smugly', 'RB'),
#  ('order', 'NN'),
#  ('spineless', 'NN'),
#  ('busy', 'JJ'),
#  ('bancroft', 'JJ'),
#  ('reserves', 'NNS'),
#  ('khan', 'VBP'),
#  ('escapes', 'NNS'),
#  ('lady', 'RB'),
#  ('invaded', 'VBD'),
#  ('jump', 'NN'),
#  ('scrub', 'NN'),
#  ('questions', 'NNS'),
#  ('twists', 'VBZ'),
#  ('handle', 'VBP'),
#  ('this', 'DT'),
#  ('sniffle', 'NN'),
#  ('squawk', 'NN'),
#  ('can', 'MD'),
#  ('calmed', 'VB'),
#  ('beef', 'NN'),
#  ('yrraaaaahhhh', 'NN'),
#  ('xiangqi', 'NNP'),
#  ('tried', 'VBD'),
#  ('scream', 'NN'),
#  ('ma', 'NN'),
#  ('range', 'NN'),
#  ('flames', 'NNS'),
#  ('staring', 'VBG'),
#  ('hurried', 'VBD'),
#  ('attached', 'JJ'),
#  ('china', 'NN'),
#  ('begging', 'VBG'),
#  ('homestead', 'JJ'),
#  ('present', 'JJ'),
#  ('script', 'NN'),
#  ('picks', 'NNS'),
#  ('kick', 'VBP'),
#  ('war', 'NN'),
#  ('map', 'NN'),
#  ('set', 'VBN'),
#  ('launch', 'JJ'),
#  ('cape', 'NN'),
#  ('crumbles', 'NNS'),
#  ('decapitated', 'VBD'),
#  ('glances', 'NNS'),
#  ('no', 'DT'),
#  ('arrives', 'NNS'),
#  ('fright', 'VBD'),
#  ('da', 'NNS'),
#  ('facing', 'VBG'),
#  ('something', 'NN'),
#  ('cart', 'JJ'),
#  ('flies', 'NNS'),
#  ('bug', 'VBP'),
#  ('instance', 'NN'),
#  ('goo', 'NN'),
#  ('lit-', 'JJ'),
#  ('lighting', 'NN'),
#  ('oh', 'NN'),
#  ('physique', 'NN'),
#  ('pendant', 'NN'),
#  ('painted', 'VBD'),
#  ('sandwich', 'JJ'),
#  ('play', 'NN'),
#  ('hooooo', 'NN'),
#  ('aim', 'NN'),
#  ('saw', 'VBD'),
#  ('reigns', 'NNS'),
#  ('adjusting', 'VBG'),
#  ('powers', 'NNS'),
#  ('strikes', 'NNS'),
#  ('anticipating', 'VBG'),
#  ('shoulders', 'NNS'),
#  ('level', 'NN'),
#  ('shoulder', 'NN'),
#  ('after', 'IN'),
#  ('wooo', 'JJ'),
#  ('moo', 'NN'),
#  ('buns', 'VBZ'),
#  ('yin-yang', 'JJ'),
#  ('smashes', 'NNS'),
#  ('laying', 'VBG'),
#  ('discovered', 'VBD'),
#  ('soft', 'JJ'),
#  ('um', 'JJ'),
#  ('hides', 'NNS'),
#  ('crouches', 'NNS'),
#  ('holder', 'VBP'),
#  ('heard', 'VBN'),
#  ('leap', 'JJ'),
#  ('bag', 'NN'),
#  ('grief', 'NN'),
#  ('butts', 'JJ'),
#  ('explosions', 'NNS'),
#  ('finalizing', 'VBG'),
#  ('archers', 'NNS'),
#  ('dejectedly', 'RB'),
#  ('bowing', 'VBG'),
#  ('stick', 'JJ'),
#  ('feeling', 'NN'),
#  ('artistry', 'NN'),
#  ('minute', 'NN'),
#  ('reeds', 'NNS'),
#  ('shocked', 'VBD'),
#  ('comforts', 'NNS'),
#  ('window', 'IN'),
#  ('cute', 'JJ'),
#  ('passing', 'VBG'),
#  ('stable', 'JJ'),
#  ('matter', 'NN'),
#  ('excellent', 'JJ'),
#  ('cracks', 'NNS'),
#  ('coming', 'VBG'),
#  ('fading', 'VBG'),
#  ('pour', 'NN'),
#  ('with', 'IN'),
#  ('threaten', 'JJ'),
#  ('prays', 'NNS'),
#  ('survivors', 'NNS'),
#  ('spits', 'NNS'),
#  ('quieting', 'VBG'),
#  ('just', 'RB'),
#  ('momentum', 'RB'),
#  ('many', 'JJ'),
#  ('kicks', 'NNS'),
#  ('coals', 'NNS'),
#  ('composure', 'VBP'),
#  ('section', 'NN'),
#  ('aiya', 'NN'),
#  ('places', 'VBZ'),
#  ('how', 'WRB'),
#  ('yeeahhhhhh', 'JJ'),
#  ('lipstick', 'JJ'),
#  ('cleaning', 'NN'),
#  ('cast', 'NN'),
#  ('concubines', 'NNS'),
#  ('officer', 'NN'),
#  ('arm', 'NN'),
#  ('chang', 'NN'),
#  ('unsuccessful', 'JJ'),
#  ('ideal', 'JJ'),
#  ('ultimate', 'JJ'),
#  ('obscured', 'VBN'),
#  ('smug', 'NN'),
#  ('thundering', 'VBG'),
#  ('whispers', 'NNS'),
#  ('upon', 'IN'),
#  ('sinister', 'NN'),
#  ('stealing', 'VBG'),
#  ('maidens', 'NNS'),
#  ('-', ':'),
#  ('leaf', 'NN'),
#  ('plea', 'NN'),
#  ('ho', 'NN'),
#  ('fuuuu', 'NN'),
#  ('crowd', 'NN'),
#  ('sleeve', 'JJ'),
#  ('ladies', 'NNS'),
#  ('side', 'VBP'),
#  ('rain', 'NN'),
#  ('uniform', 'JJ'),
#  ('recruit', 'NN'),
#  ('eaten', 'JJ'),
#  ('block', 'NN'),
#  ('save', 'VBP'),
#  ('quite', 'RB'),
#  ('extensive', 'JJ'),
#  ('needed', 'VBN'),
#  ('smartest', 'JJS'),
#  ('swift', 'JJ'),
#  ('yes', 'RB'),
#  ('2', 'CD'),
#  ('preacher', 'NN'),
#  ('till', 'NN'),
#  ('joining', 'VBG'),
#  ('jade', 'NN'),
#  ('fanning', 'VBG'),
#  ('hanging', 'VBG'),
#  ('black', 'JJ'),
#  ('check', 'NN'),
#  ('gaping', 'VBG'),
#  ('slide', 'NN'),
#  ('lowering', 'VBG'),
#  ('meant', 'JJ'),
#  ('crosses', 'NNS'),
#  ('caught', 'VBD'),
#  ('attempt', 'RP'),
#  ('cocking', 'VBG'),
#  ('every', 'DT'),
#  ('outta', 'NN'),
#  ('owe', 'VBP'),
#  ('encense', 'NN'),
#  ('riding', 'VBG'),
#  ('doctor', 'NN'),
#  ('am', 'VBP'),
#  ('teasing', 'VBG'),
#  ('each', 'DT'),
#  ('group', 'NN'),
#  ('been', 'VBN'),
#  ('whinces', 'NNS'),
#  ('exploding', 'VBG'),
#  ('balance', 'NN'),
#  ('practices', 'NNS'),
#  ('even', 'RB'),
#  ('door', 'VBP'),
#  ('beyond', 'IN'),
#  ...]

# %% [markdown]
# ### Wait...what is that POS category?
# Find out what a category is by asking NLTK:
# `nltk.help.upenn_tagset('VBZ')`

# %%
nltk.help.upenn_tagset('JJ')
# Out:
# JJ: adjective or numeral, ordinal
#     third ill-mannered pre-war regrettable oiled calamitous first separable
#     ectoplasmic battery-powered participatory fourth still-to-be-named
#     multilingual multi-disciplinary ...

# %% [markdown]
# We can limit our list of words of interest by asking for words of a particular kind, isolating them by POS

# %%
POStagged = pos_tag(uniqueTokens)
tagsIwant = ['JJ']
# This is a Python list comprehension that'll help us with our list of tuples [(word, tag), (word, tag), ...]
shortList = [word for word, tag in POStagged if tag in tagsIwant]
setList = set(shortList)
print(len(setList))
print(shortList)

# Fancy string formatting (not super useful here, just reviewing it): 
# f'My short list is {shortList} and it is this long: {len(shortList)}'
# Out:
# 452
# ['nervous', 'sleep', 'recent', 'dear', 'intact', 'different', 'worthwhile', 'clear', 'opposite', 'ahem', 'real', 'bessy', 'flanked', 'ouch', 'forehead', 'rocket', 'tight', 'stabs', 'forgive', 'begin', 'make-up', 'hoo', '[', 'woo', 'fade', 'talkin', 'military', 'lady-killer', 'troops', 'expect', 'enough', 'tea-cup', 'polite', 'townsfolk', 'general', 'uhhh', 'chinese', 'hold', 'pattern', 'next', 'hua', 'gasps', 'young', 'main', 'uphold', 'caldron', 'doggie', 'sweep', 'xiao', 'wish', 'prepare', 'southern', "fam'ly", 'pathetic', 'close-up', 'skinny', 'second', 'beautiful', 'grandma', 'gir-', 'outstretched', 'crossed', 'dress', 'surprising', 'old', 'screen', 'wild', 'growl', 'swim', 'august', 'shadow', 'okey', 'arrive', 'small', 'speaks', 'honorable', 'entire', 'ahhhhhhh', 'wrong', 'happy', 'incense', 'patient', 'upset', 'slouch', 'impress', 'discontent', 'hurry', 'tattered', 'upstream', 'lantern', 'signal', 'chicken', 'wobbling', 'due', 'hit', 'hungry', 'shrimp', 'other', 'long-hair', 'hu', 'ummmm', 'mmm-hmm', 'clean', 'major', 'inside', 'bear', 'giant', 'free', 'statue', 'saddle', 'stationed', 'mysterious', 'extra', 'tear', 'multiple', 'final', 'steady', 'in-laws', 'dead', 'pleasurable', 'live', 'chien-po', 'rare', 'ha', 'worried', 'little', 'granddaughter', 'shake', 'responsibility', 'pots', 'impressive', "'t", 'full', 'sorry', 'short', 'busy', 'bancroft', 'attached', 'homestead', 'present', 'launch', 'cart', 'lit-', 'sandwich', 'wooo', 'yin-yang', 'soft', 'um', 'leap', 'butts', 'stick', 'cute', 'stable', 'excellent', 'threaten', 'many', 'yeeahhhhhh', 'lipstick', 'unsuccessful', 'ideal', 'ultimate', 'sleeve', 'uniform', 'eaten', 'extensive', 'swift', 'black', 'meant', 'song', 'sweet', 'finish', 'proud', 'noooooo', 'lose', 'worth', 'head-butts', 'pruny', 'obedient', 'clumsy', 'middle', 'enormous', 'chant', 'noticeable', 'tiny', 'expose', 'throng', 'sister', 'muscular', 'warm', 'possible', 'single', 'alive', 'nasty', 'purse', 'nice', 'upright', 'jive', 'flat', 'bunny', 'pushed', 'chagrin', 'firework', 'long-haired', 'aww', 'pompous', 'unsuited', 'guardian', 'hear', 'shun-yu', 'utter', 'armory', 'noise', 'wide', 'al', 'waist', 'ready', 'li', 'come', 'burning', 'hay', 'easy', 'mortal', 'outer', 'boy', 'sure', 'aaaaaahhhhhh', 'human', 'foolish', 'tie', 'big', 'mean', 'empty', 'mention', 'stern', 'bite', 'cheek', 'hard', 'porridge', 'right', 'hot', 'wounded', 'luck', 'ancestor', 'bean', 'spy', 'good', 'howls', 'stoop', 'last', 'open', 'shan', 'evil', 'avoids', 'pull', 'touch', 'carriage', 'threshold', 'quicky', 'new', 'strong', 'aaaaa', 'arrrrr', 'table', 'sorta', 'naked', 'medal', 'rice', 'such', 'awaken', 'centerfold', 'nose', 'batman', 'medic', '*', 'herd', 'delicate', 'straight', 'martial', 'strange', 'true', 'majesty', 'wen', 'fast-paced', 'lunatic', 'local', 'ahhh', 'smart', 'valley', 'tony', 'spare', 'embankment', 'baba', 'unimpressed', 'fish', 'graceful', 'yao', 'whole', 'believing', 'else', 'report', 'squeal', "c'mon", 'silent', 'hair', 'couple', 'complete', 'dumpty', 'funny', 'spend', 'kid', 'hellooooo', 'rocky', 'sight', 'quick', 'drag', 'sound', 'baptist', 'okay', 'trecherous', 'sword', 'fine', 'assemble', 'mistake', 'ooooo', 'outfit', 'powerful', 'grin', 'ptu', 'large', 'sick', 'yeeeeeahhhhhhh', 'bow', 'gifts', 'punctual', 'nope', 'tough', 'late', 'cry', 'first', 'hairdo', 'avoid', 'briskly', 'shimmy', 'fellow', 'mounted', 'unbeknownst', 'butt', 'tent', 'legs', 'strut', 'much', 'own', 'sign', 'cross-dresser', 'f', 'noodle', 'na', 'eh', 'camp', 'marvel', 'sorrowful', 'uhh', 'disappointment', 'quiet', 'speak', 'bride', 'dried', 'dishonor', 'fetal', 'nobody', 'unfurls', 'feminine', 'safe', 'fly', 'stole', 'urgent', 'maiden', 'secret', 'hurriedly', 'humpty', 'timid', 'pops', 'wear', 'top', 'dynasty', 'shakes', 'traditional', 'dis-', 'few', 'survive', 'fu', 'lily', 'shu', 'shan-yu', 'yu', 'heh', 'protect', 'upper', 'worthy', 'arrival', 'sheep', 'gusto', 'impressed', 'huge', "ev'ry", 'yrrrrrrraah', 'indestructible', 'gracious', ...

# %% [markdown]
# ## Send them to WordNet for synset lookup
#
# * Use list comprehension
# * Use wn.morphy to simplify the word to its synset lemma form
# * While we're at it, let's sort the shortList using `sorted()`.
# * We noticed that WordNet has its own parts of speech, and they're a lot simpler than NLTK's.
#     * WordNet's parts of speech are ADJ, ADJ_SAT, ADV, NOUN, VERB:  'a', 's', 'r', 'n', 'v'
#     * We also noticed that NLTK's part of speech tagging is rather shockingly unreliable on our texts.
#     * We wonder if spaCy might be better, or if we really need to train the models on our texts by tagging them ourselves.
#     * You might want to just make a list of all the words that have the same ending, like our [-ing smoke test](https://github.com/newtfire/textAnalysis-Hub/blob/main/Class-Examples/Python/orient-ing.py) from the NLTK book intro in our first Python assignment.

# %%
for w in sorted(shortList):
    lemma = wn.morphy(w)
    # I don't think we need the next line, but it's a fallback if there's no WordNet lemmas: 
    lemma = lemma if lemma else w 
    print(f"Word: {w} | Wordnet Lemma: {lemma}")
    synsets = wn.synsets(lemma)
    pos = {synset.pos() for synset in synsets}
    if synsets:
       
        
        print(f" Word: {w}, POS-according-to-WordNet {pos} Number of Synsets (Ambiguity): {len(synsets)}") 
              
        
        # for syn in synsets:
        #   print(f"  Synset: {syn.name()}, Definition: {syn.definition()}}")
# Out:
# Word: 't | Wordnet Lemma: 't
# Word: * | Wordnet Lemma: *
# Word: [ | Wordnet Lemma: [
# Word: aaaaa | Wordnet Lemma: aaaaa
# Word: aaaaaahhhhhh | Wordnet Lemma: aaaaaahhhhhh
# Word: ahem | Wordnet Lemma: ahem
#  Word: ahem, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 1
# Word: ahhh | Wordnet Lemma: ahhh
# Word: ahhhhhhh | Wordnet Lemma: ahhhhhhh
# Word: al | Wordnet Lemma: al
#  Word: al, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 2
# Word: alive | Wordnet Lemma: alive
#  Word: alive, POS-according-to-WordNet {'a', 's'} Number of Synsets (Ambiguity): 7
# Word: ancestor | Wordnet Lemma: ancestor
#  Word: ancestor, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 1
# Word: armory | Wordnet Lemma: armory
#  Word: armory, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 4
# Word: arrival | Wordnet Lemma: arrival
#  Word: arrival, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 3
# Word: arrive | Wordnet Lemma: arrive
#  Word: arrive, POS-according-to-WordNet {'v'} Number of Synsets (Ambiguity): 2
# Word: arrrrr | Wordnet Lemma: arrrrr
# Word: assemble | Wordnet Lemma: assemble
#  Word: assemble, POS-according-to-WordNet {'v'} Number of Synsets (Ambiguity): 3
# Word: attached | Wordnet Lemma: attach
#  Word: attached, POS-according-to-WordNet {'v'} Number of Synsets (Ambiguity): 5
# Word: august | Wordnet Lemma: august
#  Word: august, POS-according-to-WordNet {'n', 's'} Number of Synsets (Ambiguity): 3
# Word: avoid | Wordnet Lemma: avoid
#  Word: avoid, POS-according-to-WordNet {'v'} Number of Synsets (Ambiguity): 5
# Word: avoids | Wordnet Lemma: avoid
#  Word: avoids, POS-according-to-WordNet {'v'} Number of Synsets (Ambiguity): 5
# Word: awaken | Wordnet Lemma: awaken
#  Word: awaken, POS-according-to-WordNet {'v'} Number of Synsets (Ambiguity): 3
# Word: aww | Wordnet Lemma: aww
# Word: baba | Wordnet Lemma: baba
#  Word: baba, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 1
# Word: bald | Wordnet Lemma: bald
#  Word: bald, POS-according-to-WordNet {'v', 's'} Number of Synsets (Ambiguity): 4
# Word: bancroft | Wordnet Lemma: bancroft
# Word: baptist | Wordnet Lemma: baptist
#  Word: baptist, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 1
# Word: base | Wordnet Lemma: base
#  Word: base, POS-according-to-WordNet {'n', 'v', 's'} Number of Synsets (Ambiguity): 30
# Word: batman | Wordnet Lemma: batman
#  Word: batman, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 1
# Word: bean | Wordnet Lemma: bean
#  Word: bean, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 5
# Word: bear | Wordnet Lemma: bear
#  Word: bear, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 15
# Word: beautiful | Wordnet Lemma: beautiful
#  Word: beautiful, POS-according-to-WordNet {'a', 's'} Number of Synsets (Ambiguity): 2
# Word: begin | Wordnet Lemma: begin
#  Word: begin, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 11
# Word: believing | Wordnet Lemma: believing
#  Word: believing, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 6
# Word: bessy | Wordnet Lemma: bessy
# Word: big | Wordnet Lemma: big
#  Word: big, POS-according-to-WordNet {'a', 'r', 's'} Number of Synsets (Ambiguity): 17
# Word: bite | Wordnet Lemma: bite
#  Word: bite, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 13
# Word: black | Wordnet Lemma: black
#  Word: black, POS-according-to-WordNet {'a', 'n', 'v', 's'} Number of Synsets (Ambiguity): 22
# Word: bow | Wordnet Lemma: bow
#  Word: bow, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 14
# Word: boy | Wordnet Lemma: boy
#  Word: boy, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 4
# Word: bride | Wordnet Lemma: bride
#  Word: bride, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 3
# Word: briskly | Wordnet Lemma: briskly
#  Word: briskly, POS-according-to-WordNet {'r'} Number of Synsets (Ambiguity): 1
# Word: bunny | Wordnet Lemma: bunny
#  Word: bunny, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 2
# Word: burning | Wordnet Lemma: burning
#  Word: burning, POS-according-to-WordNet {'n', 'v', 's'} Number of Synsets (Ambiguity): 22
# Word: busy | Wordnet Lemma: busy
#  Word: busy, POS-according-to-WordNet {'a', 'v', 's'} Number of Synsets (Ambiguity): 6
# Word: butt | Wordnet Lemma: butt
#  Word: butt, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 12
# Word: butts | Wordnet Lemma: butt
#  Word: butts, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 12
# Word: c'mon | Wordnet Lemma: c'mon
# Word: caldron | Wordnet Lemma: caldron
#  Word: caldron, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 1
# Word: camp | Wordnet Lemma: camp
#  Word: camp, POS-according-to-WordNet {'n', 'v', 's'} Number of Synsets (Ambiguity): 12
# Word: careful | Wordnet Lemma: careful
#  Word: careful, POS-according-to-WordNet {'a', 's'} Number of Synsets (Ambiguity): 5
# Word: carriage | Wordnet Lemma: carriage
#  Word: carriage, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 5
# Word: cart | Wordnet Lemma: cart
#  Word: cart, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 4
# Word: centerfold | Wordnet Lemma: centerfold
#  Word: centerfold, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 1
# Word: central | Wordnet Lemma: central
#  Word: central, POS-according-to-WordNet {'a', 'n', 's'} Number of Synsets (Ambiguity): 3
# Word: chagrin | Wordnet Lemma: chagrin
#  Word: chagrin, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 2
# Word: chant | Wordnet Lemma: chant
#  Word: chant, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 3
# Word: cheek | Wordnet Lemma: cheek
#  Word: cheek, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 5
# Word: chicken | Wordnet Lemma: chicken
#  Word: chicken, POS-according-to-WordNet {'n', 's'} Number of Synsets (Ambiguity): 5
# Word: chien-po | Wordnet Lemma: chien-po
# Word: chinese | Wordnet Lemma: chinese
#  Word: chinese, POS-according-to-WordNet {'a', 'n'} Number of Synsets (Ambiguity): 4
# Word: clean | Wordnet Lemma: clean
#  Word: clean, POS-according-to-WordNet {'a', 'v', 'n', 's', 'r'} Number of Synsets (Ambiguity): 31
# Word: clear | Wordnet Lemma: clear
#  Word: clear, POS-according-to-WordNet {'a', 'v', 'n', 's', 'r'} Number of Synsets (Ambiguity): 45
# Word: close-up | Wordnet Lemma: close-up
# Word: clumsy | Wordnet Lemma: clumsy
#  Word: clumsy, POS-according-to-WordNet {'s'} Number of Synsets (Ambiguity): 4
# Word: come | Wordnet Lemma: come
#  Word: come, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 22
# Word: complete | Wordnet Lemma: complete
#  Word: complete, POS-according-to-WordNet {'a', 'v', 's'} Number of Synsets (Ambiguity): 10
# Word: congee | Wordnet Lemma: congee
#  Word: congee, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 6
# Word: corridor | Wordnet Lemma: corridor
#  Word: corridor, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 1
# Word: couple | Wordnet Lemma: couple
#  Word: couple, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 9
# Word: crawl | Wordnet Lemma: crawl
#  Word: crawl, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 8
# Word: cross-dresser | Wordnet Lemma: cross-dresser
#  Word: cross-dresser, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 1
# Word: crossed | Wordnet Lemma: cross
#  Word: crossed, POS-according-to-WordNet {'n', 'v', 's'} Number of Synsets (Ambiguity): 16
# Word: cry | Wordnet Lemma: cry
#  Word: cry, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 12
# Word: cute | Wordnet Lemma: cute
#  Word: cute, POS-according-to-WordNet {'s'} Number of Synsets (Ambiguity): 2
# Word: dark | Wordnet Lemma: dark
#  Word: dark, POS-according-to-WordNet {'a', 'n', 's'} Number of Synsets (Ambiguity): 16
# Word: dead | Wordnet Lemma: dead
#  Word: dead, POS-according-to-WordNet {'a', 'n', 'r', 's'} Number of Synsets (Ambiguity): 21
# Word: dear | Wordnet Lemma: dear
#  Word: dear, POS-according-to-WordNet {'n', 'r', 's'} Number of Synsets (Ambiguity): 8
# Word: deflect | Wordnet Lemma: deflect
#  Word: deflect, POS-according-to-WordNet {'v'} Number of Synsets (Ambiguity): 5
# Word: delicate | Wordnet Lemma: delicate
#  Word: delicate, POS-according-to-WordNet {'a', 's'} Number of Synsets (Ambiguity): 7
# Word: deliver | Wordnet Lemma: deliver
#  Word: deliver, POS-according-to-WordNet {'v'} Number of Synsets (Ambiguity): 12
# Word: deng | Wordnet Lemma: deng
# Word: different | Wordnet Lemma: different
#  Word: different, POS-according-to-WordNet {'a', 's'} Number of Synsets (Ambiguity): 5
# Word: dis- | Wordnet Lemma: dis-
# Word: disappointed | Wordnet Lemma: disappoint
#  Word: disappointed, POS-according-to-WordNet {'v'} Number of Synsets (Ambiguity): 1
# Word: disappointment | Wordnet Lemma: disappointment
#  Word: disappointment, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 2
# Word: discontent | Wordnet Lemma: discontent
#  Word: discontent, POS-according-to-WordNet {'a', 'n', 'v'} Number of Synsets (Ambiguity): 3
# Word: dishonor | Wordnet Lemma: dishonor
#  Word: dishonor, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 5
# Word: doggie | Wordnet Lemma: doggie
#  Word: doggie, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 1
# Word: drag | Wordnet Lemma: drag
#  Word: drag, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 17
# Word: draw | Wordnet Lemma: draw
#  Word: draw, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 45
# Word: dress | Wordnet Lemma: dress
#  Word: dress, POS-according-to-WordNet {'n', 'v', 's'} Number of Synsets (Ambiguity): 21
# Word: dried | Wordnet Lemma: dry
#  Word: dried, POS-according-to-WordNet {'a', 'n', 'v', 's'} Number of Synsets (Ambiguity): 19
# Word: due | Wordnet Lemma: due
#  Word: due, POS-according-to-WordNet {'a', 'n', 'r', 's'} Number of Synsets (Ambiguity): 7
# Word: dumpty | Wordnet Lemma: dumpty
# Word: dynasty | Wordnet Lemma: dynasty
#  Word: dynasty, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 1
# Word: easy | Wordnet Lemma: easy
#  Word: easy, POS-according-to-WordNet {'a', 'r', 's'} Number of Synsets (Ambiguity): 15
# Word: eaten | Wordnet Lemma: eat
#  Word: eaten, POS-according-to-WordNet {'v'} Number of Synsets (Ambiguity): 6
# Word: eh | Wordnet Lemma: eh
# Word: else | Wordnet Lemma: else
# Word: embankment | Wordnet Lemma: embankment
#  Word: embankment, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 1
# Word: empty | Wordnet Lemma: empty
#  Word: empty, POS-according-to-WordNet {'a', 'n', 'v', 's'} Number of Synsets (Ambiguity): 10
# Word: enormous | Wordnet Lemma: enormous
#  Word: enormous, POS-according-to-WordNet {'s'} Number of Synsets (Ambiguity): 1
# Word: enough | Wordnet Lemma: enough
#  Word: enough, POS-according-to-WordNet {'n', 'r', 's'} Number of Synsets (Ambiguity): 3
# Word: entire | Wordnet Lemma: entire
#  Word: entire, POS-according-to-WordNet {'n', 's'} Number of Synsets (Ambiguity): 5
# Word: ev'ry | Wordnet Lemma: ev'ry
# Word: evil | Wordnet Lemma: evil
#  Word: evil, POS-according-to-WordNet {'a', 'n', 's'} Number of Synsets (Ambiguity): 6
# Word: excellent | Wordnet Lemma: excellent
#  Word: excellent, POS-according-to-WordNet {'s'} Number of Synsets (Ambiguity): 1
# Word: expect | Wordnet Lemma: expect
#  Word: expect, POS-according-to-WordNet {'v'} Number of Synsets (Ambiguity): 6
# Word: expose | Wordnet Lemma: expose
#  Word: expose, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 10
# Word: extensive | Wordnet Lemma: extensive
#  Word: extensive, POS-according-to-WordNet {'a', 's'} Number of Synsets (Ambiguity): 3
# Word: extra | Wordnet Lemma: extra
#  Word: extra, POS-according-to-WordNet {'n', 'r', 's'} Number of Synsets (Ambiguity): 7
# Word: f | Wordnet Lemma: f
#  Word: f, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 4
# Word: fade | Wordnet Lemma: fade
#  Word: fade, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 6
# Word: fam'ly | Wordnet Lemma: fam'ly
# Word: fast-paced | Wordnet Lemma: fast-paced
#  Word: fast-paced, POS-according-to-WordNet {'s'} Number of Synsets (Ambiguity): 1
# Word: fellow | Wordnet Lemma: fellow
#  Word: fellow, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 7
# Word: feminine | Wordnet Lemma: feminine
#  Word: feminine, POS-according-to-WordNet {'a', 'n', 's'} Number of Synsets (Ambiguity): 5
# Word: fetal | Wordnet Lemma: fetal
#  Word: fetal, POS-according-to-WordNet {'a'} Number of Synsets (Ambiguity): 1
# Word: few | Wordnet Lemma: few
#  Word: few, POS-according-to-WordNet {'a', 'n'} Number of Synsets (Ambiguity): 2
# Word: ffft | Wordnet Lemma: ffft
# Word: final | Wordnet Lemma: final
#  Word: final, POS-according-to-WordNet {'n', 's'} Number of Synsets (Ambiguity): 5
# Word: fine | Wordnet Lemma: fine
#  Word: fine, POS-according-to-WordNet {'a', 'v', 'n', 's', 'r'} Number of Synsets (Ambiguity): 10
# Word: finish | Wordnet Lemma: finish
#  Word: finish, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 15
# Word: firework | Wordnet Lemma: firework
#  Word: firework, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 1
# Word: first | Wordnet Lemma: first
#  Word: first, POS-according-to-WordNet {'a', 'n', 'r', 's'} Number of Synsets (Ambiguity): 16
# Word: fish | Wordnet Lemma: fish
#  Word: fish, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 6
# Word: flanked | Wordnet Lemma: flank
#  Word: flanked, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 5
# Word: flat | Wordnet Lemma: flat
#  Word: flat, POS-according-to-WordNet {'a', 'n', 'r', 's'} Number of Synsets (Ambiguity): 24
# Word: fly | Wordnet Lemma: fly
#  Word: fly, POS-according-to-WordNet {'n', 'v', 's'} Number of Synsets (Ambiguity): 20
# Word: foolish | Wordnet Lemma: foolish
#  Word: foolish, POS-according-to-WordNet {'a', 's'} Number of Synsets (Ambiguity): 2
# Word: forehead | Wordnet Lemma: forehead
#  Word: forehead, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 2
# Word: forgive | Wordnet Lemma: forgive
#  Word: forgive, POS-according-to-WordNet {'v'} Number of Synsets (Ambiguity): 2
# Word: forgot | Wordnet Lemma: forget
#  Word: forgot, POS-according-to-WordNet {'v'} Number of Synsets (Ambiguity): 4
# Word: free | Wordnet Lemma: free
#  Word: free, POS-according-to-WordNet {'a', 'v', 'n', 's', 'r'} Number of Synsets (Ambiguity): 22
# Word: fu | Wordnet Lemma: fu
# Word: full | Wordnet Lemma: full
#  Word: full, POS-according-to-WordNet {'a', 'v', 'n', 's', 'r'} Number of Synsets (Ambiguity): 13
# Word: funny | Wordnet Lemma: funny
#  Word: funny, POS-according-to-WordNet {'n', 's'} Number of Synsets (Ambiguity): 5
# Word: gasps | Wordnet Lemma: gasp
#  Word: gasps, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 2
# Word: general | Wordnet Lemma: general
#  Word: general, POS-according-to-WordNet {'a', 'n', 'v', 's'} Number of Synsets (Ambiguity): 10
# Word: giant | Wordnet Lemma: giant
#  Word: giant, POS-according-to-WordNet {'n', 's'} Number of Synsets (Ambiguity): 8
# Word: gifts | Wordnet Lemma: gift
#  Word: gifts, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 5
# Word: gir- | Wordnet Lemma: gir-
# Word: good | Wordnet Lemma: good
#  Word: good, POS-according-to-WordNet {'a', 'n', 'r', 's'} Number of Synsets (Ambiguity): 27
# Word: good-bye | Wordnet Lemma: good-bye
#  Word: good-bye, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 1
# Word: graceful | Wordnet Lemma: graceful
#  Word: graceful, POS-according-to-WordNet {'a', 's'} Number of Synsets (Ambiguity): 2
# Word: gracious | Wordnet Lemma: gracious
#  Word: gracious, POS-according-to-WordNet {'a', 's'} Number of Synsets (Ambiguity): 4
# Word: granddaughter | Wordnet Lemma: granddaughter
#  Word: granddaughter, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 1
# Word: grandma | Wordnet Lemma: grandma
#  Word: grandma, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 1
# Word: great | Wordnet Lemma: great
#  Word: great, POS-according-to-WordNet {'n', 's'} Number of Synsets (Ambiguity): 7
# Word: grin | Wordnet Lemma: grin
#  Word: grin, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 2
# Word: growl | Wordnet Lemma: growl
#  Word: growl, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 2
# Word: guardian | Wordnet Lemma: guardian
#  Word: guardian, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 1
# Word: guide | Wordnet Lemma: guide
#  Word: guide, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 11
# Word: gusto | Wordnet Lemma: gusto
#  Word: gusto, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 1
# Word: ha | Wordnet Lemma: ha
#  Word: ha, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 1
# Word: hair | Wordnet Lemma: hair
#  Word: hair, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 6
# Word: hairdo | Wordnet Lemma: hairdo
#  Word: hairdo, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 1
# Word: happy | Wordnet Lemma: happy
#  Word: happy, POS-according-to-WordNet {'a', 's'} Number of Synsets (Ambiguity): 4
# Word: hard | Wordnet Lemma: hard
#  Word: hard, POS-according-to-WordNet {'a', 'r', 's'} Number of Synsets (Ambiguity): 22
# Word: hay | Wordnet Lemma: hay
#  Word: hay, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 2
# Word: head-butts | Wordnet Lemma: head-butts
# Word: hear | Wordnet Lemma: hear
#  Word: hear, POS-according-to-WordNet {'v'} Number of Synsets (Ambiguity): 5
# Word: heh | Wordnet Lemma: heh
# Word: hellooooo | Wordnet Lemma: hellooooo
# Word: herd | Wordnet Lemma: herd
#  Word: herd, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 6
# Word: heros | Wordnet Lemma: hero
#  Word: heros, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 7
# Word: high | Wordnet Lemma: high
#  Word: high, POS-according-to-WordNet {'a', 'n', 'r', 's'} Number of Synsets (Ambiguity): 18
# Word: hit | Wordnet Lemma: hit
#  Word: hit, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 24
# Word: hmm | Wordnet Lemma: hmm
# Word: hold | Wordnet Lemma: hold
#  Word: hold, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 45
# Word: homestead | Wordnet Lemma: homestead
#  Word: homestead, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 4
# Word: honorable | Wordnet Lemma: honorable
#  Word: honorable, POS-according-to-WordNet {'a', 's'} Number of Synsets (Ambiguity): 4
# Word: hoo | Wordnet Lemma: hoo
# Word: hot | Wordnet Lemma: hot
#  Word: hot, POS-according-to-WordNet {'a', 's'} Number of Synsets (Ambiguity): 21
# Word: howls | Wordnet Lemma: howl
#  Word: howls, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 7
# Word: hu | Wordnet Lemma: hu
# Word: hua | Wordnet Lemma: hua
#  Word: hua, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 1
# Word: huge | Wordnet Lemma: huge
#  Word: huge, POS-according-to-WordNet {'s'} Number of Synsets (Ambiguity): 1
# Word: human | Wordnet Lemma: human
#  Word: human, POS-according-to-WordNet {'a', 'n'} Number of Synsets (Ambiguity): 4
# Word: humpty | Wordnet Lemma: humpty
# Word: hungry | Wordnet Lemma: hungry
#  Word: hungry, POS-according-to-WordNet {'a', 's'} Number of Synsets (Ambiguity): 2
# Word: hurriedly | Wordnet Lemma: hurriedly
#  Word: hurriedly, POS-according-to-WordNet {'r'} Number of Synsets (Ambiguity): 1
# Word: hurry | Wordnet Lemma: hurry
#  Word: hurry, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 6
# Word: ideal | Wordnet Lemma: ideal
#  Word: ideal, POS-according-to-WordNet {'a', 'n', 's'} Number of Synsets (Ambiguity): 5
# Word: impersonated | Wordnet Lemma: impersonate
#  Word: impersonated, POS-according-to-WordNet {'v'} Number of Synsets (Ambiguity): 3
# Word: impossible | Wordnet Lemma: impossible
#  Word: impossible, POS-according-to-WordNet {'a', 'n', 's'} Number of Synsets (Ambiguity): 4
# Word: impress | Wordnet Lemma: impress
#  Word: impress, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 8
# Word: impressed | Wordnet Lemma: impress
#  Word: impressed, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 8
# Word: impressive | Wordnet Lemma: impressive
#  Word: impressive, POS-according-to-WordNet {'a', 's'} Number of Synsets (Ambiguity): 2
# Word: in-laws | Wordnet Lemma: in-law
#  Word: in-laws, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 1
# Word: incense | Wordnet Lemma: incense
#  Word: incense, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 4
# Word: indestructible | Wordnet Lemma: indestructible
#  Word: indestructible, POS-according-to-WordNet {'a', 's'} Number of Synsets (Ambiguity): 2
# Word: inside | Wordnet Lemma: inside
#  Word: inside, POS-according-to-WordNet {'a', 'n', 'r', 's'} Number of Synsets (Ambiguity): 10
# Word: intact | Wordnet Lemma: intact
#  Word: intact, POS-according-to-WordNet {'s'} Number of Synsets (Ambiguity): 4
# Word: jive | Wordnet Lemma: jive
#  Word: jive, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 2
# Word: kid | Wordnet Lemma: kid
#  Word: kid, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 7
# Word: lady-killer | Wordnet Lemma: lady-killer
# Word: lantern | Wordnet Lemma: lantern
#  Word: lantern, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 1
# Word: large | Wordnet Lemma: large
#  Word: large, POS-according-to-WordNet {'a', 'n', 'r', 's'} Number of Synsets (Ambiguity): 11
# Word: last | Wordnet Lemma: last
#  Word: last, POS-according-to-WordNet {'a', 'v', 'n', 's', 'r'} Number of Synsets (Ambiguity): 21
# Word: late | Wordnet Lemma: late
#  Word: late, POS-according-to-WordNet {'a', 'r', 's'} Number of Synsets (Ambiguity): 11
# Word: launch | Wordnet Lemma: launch
#  Word: launch, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 8
# Word: lead | Wordnet Lemma: lead
#  Word: lead, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 31
# Word: leap | Wordnet Lemma: leap
#  Word: leap, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 8
# Word: legs | Wordnet Lemma: legs
#  Word: legs, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 10
# Word: li | Wordnet Lemma: li
#  Word: li, POS-according-to-WordNet {'n', 's'} Number of Synsets (Ambiguity): 3
# Word: lily | Wordnet Lemma: lily
#  Word: lily, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 1
# Word: lipstick | Wordnet Lemma: lipstick
#  Word: lipstick, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 3
# Word: listen | Wordnet Lemma: listen
#  Word: listen, POS-according-to-WordNet {'v'} Number of Synsets (Ambiguity): 3
# Word: lit- | Wordnet Lemma: lit-
# Word: little | Wordnet Lemma: little
#  Word: little, POS-according-to-WordNet {'a', 'n', 'r', 's'} Number of Synsets (Ambiguity): 10
# Word: live | Wordnet Lemma: live
#  Word: live, POS-according-to-WordNet {'a', 'r', 'v', 's'} Number of Synsets (Ambiguity): 19
# Word: local | Wordnet Lemma: local
#  Word: local, POS-according-to-WordNet {'a', 'n'} Number of Synsets (Ambiguity): 5
# Word: long-hair | Wordnet Lemma: long-hair
# Word: long-haired | Wordnet Lemma: long-haired
#  Word: long-haired, POS-according-to-WordNet {'s'} Number of Synsets (Ambiguity): 1
# Word: lose | Wordnet Lemma: lose
#  Word: lose, POS-according-to-WordNet {'v'} Number of Synsets (Ambiguity): 11
# Word: luck | Wordnet Lemma: luck
#  Word: luck, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 3
# Word: lunatic | Wordnet Lemma: lunatic
#  Word: lunatic, POS-according-to-WordNet {'n', 's'} Number of Synsets (Ambiguity): 3
# Word: maiden | Wordnet Lemma: maiden
#  Word: maiden, POS-according-to-WordNet {'n', 's'} Number of Synsets (Ambiguity): 3
# Word: main | Wordnet Lemma: main
#  Word: main, POS-according-to-WordNet {'a', 'n', 's'} Number of Synsets (Ambiguity): 5
# Word: majesty | Wordnet Lemma: majesty
#  Word: majesty, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 1
# Word: major | Wordnet Lemma: major
#  Word: major, POS-according-to-WordNet {'a', 'n', 'v', 's'} Number of Synsets (Ambiguity): 13
# Word: make-up | Wordnet Lemma: make-up
#  Word: make-up, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 3
# Word: many | Wordnet Lemma: many
#  Word: many, POS-according-to-WordNet {'a'} Number of Synsets (Ambiguity): 1
# Word: martial | Wordnet Lemma: martial
#  Word: martial, POS-according-to-WordNet {'n', 's'} Number of Synsets (Ambiguity): 4
# Word: marvel | Wordnet Lemma: marvel
#  Word: marvel, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 3
# Word: mean | Wordnet Lemma: mean
#  Word: mean, POS-according-to-WordNet {'n', 'v', 's'} Number of Synsets (Ambiguity): 16
# Word: meant | Wordnet Lemma: mean
#  Word: meant, POS-according-to-WordNet {'n', 'v', 's'} Number of Synsets (Ambiguity): 16
# Word: medal | Wordnet Lemma: medal
#  Word: medal, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 1
# Word: medic | Wordnet Lemma: medic
#  Word: medic, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 2
# Word: mention | Wordnet Lemma: mention
#  Word: mention, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 6
# Word: middle | Wordnet Lemma: middle
#  Word: middle, POS-according-to-WordNet {'a', 'n', 'v', 's'} Number of Synsets (Ambiguity): 9
# Word: military | Wordnet Lemma: military
#  Word: military, POS-according-to-WordNet {'a', 'n'} Number of Synsets (Ambiguity): 4
# Word: mistake | Wordnet Lemma: mistake
#  Word: mistake, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 5
# Word: mmm-hmm | Wordnet Lemma: mmm-hmm
# Word: mongolian | Wordnet Lemma: mongolian
#  Word: mongolian, POS-according-to-WordNet {'a', 'n'} Number of Synsets (Ambiguity): 4
# Word: mortal | Wordnet Lemma: mortal
#  Word: mortal, POS-according-to-WordNet {'a', 'n', 's'} Number of Synsets (Ambiguity): 5
# Word: mounted | Wordnet Lemma: mount
#  Word: mounted, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 13
# Word: much | Wordnet Lemma: much
#  Word: much, POS-according-to-WordNet {'a', 'n', 'r'} Number of Synsets (Ambiguity): 7
# Word: multiple | Wordnet Lemma: multiple
#  Word: multiple, POS-according-to-WordNet {'a', 'n'} Number of Synsets (Ambiguity): 2
# Word: muscular | Wordnet Lemma: muscular
#  Word: muscular, POS-according-to-WordNet {'a', 's'} Number of Synsets (Ambiguity): 4
# Word: mysterious | Wordnet Lemma: mysterious
#  Word: mysterious, POS-according-to-WordNet {'s'} Number of Synsets (Ambiguity): 2
# Word: na | Wordnet Lemma: na
#  Word: na, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 1
# Word: nah | Wordnet Lemma: nah
# Word: naked | Wordnet Lemma: naked
#  Word: naked, POS-according-to-WordNet {'s'} Number of Synsets (Ambiguity): 5
# Word: nasty | Wordnet Lemma: nasty
#  Word: nasty, POS-according-to-WordNet {'a', 's'} Number of Synsets (Ambiguity): 4
# Word: nervous | Wordnet Lemma: nervous
#  Word: nervous, POS-according-to-WordNet {'a', 's'} Number of Synsets (Ambiguity): 5
# Word: new | Wordnet Lemma: new
#  Word: new, POS-according-to-WordNet {'a', 'r', 's'} Number of Synsets (Ambiguity): 12
# Word: next | Wordnet Lemma: next
#  Word: next, POS-according-to-WordNet {'r', 's'} Number of Synsets (Ambiguity): 4
# Word: nice | Wordnet Lemma: nice
#  Word: nice, POS-according-to-WordNet {'a', 'n', 's'} Number of Synsets (Ambiguity): 6
# Word: nobody | Wordnet Lemma: nobody
#  Word: nobody, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 1
# Word: noise | Wordnet Lemma: noise
#  Word: noise, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 7
# Word: noodle | Wordnet Lemma: noodle
#  Word: noodle, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 2
# Word: noooooo | Wordnet Lemma: noooooo
# Word: nope | Wordnet Lemma: nope
# Word: normal | Wordnet Lemma: normal
#  Word: normal, POS-according-to-WordNet {'a', 'n', 's'} Number of Synsets (Ambiguity): 5
# Word: nose | Wordnet Lemma: nose
#  Word: nose, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 14
# Word: noticeable | Wordnet Lemma: noticeable
#  Word: noticeable, POS-according-to-WordNet {'a', 's'} Number of Synsets (Ambiguity): 4
# Word: obedient | Wordnet Lemma: obedient
#  Word: obedient, POS-according-to-WordNet {'a'} Number of Synsets (Ambiguity): 1
# Word: okay | Wordnet Lemma: okay
#  Word: okay, POS-according-to-WordNet {'n', 'r', 'v', 's'} Number of Synsets (Ambiguity): 4
# Word: okey | Wordnet Lemma: okey
#  Word: okey, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 1
# Word: old | Wordnet Lemma: old
#  Word: old, POS-according-to-WordNet {'a', 'n', 's'} Number of Synsets (Ambiguity): 9
# Word: ooooo | Wordnet Lemma: ooooo
# Word: open | Wordnet Lemma: open
#  Word: open, POS-according-to-WordNet {'a', 'n', 'v', 's'} Number of Synsets (Ambiguity): 36
# Word: opposite | Wordnet Lemma: opposite
#  Word: opposite, POS-according-to-WordNet {'a', 'n', 'r', 's'} Number of Synsets (Ambiguity): 11
# Word: other | Wordnet Lemma: other
#  Word: other, POS-according-to-WordNet {'a', 's'} Number of Synsets (Ambiguity): 4
# Word: ouch | Wordnet Lemma: ouch
# Word: outer | Wordnet Lemma: outer
#  Word: outer, POS-according-to-WordNet {'a', 's'} Number of Synsets (Ambiguity): 13
# Word: outfit | Wordnet Lemma: outfit
#  Word: outfit, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 4
# Word: outstretched | Wordnet Lemma: outstretched
#  Word: outstretched, POS-according-to-WordNet {'s'} Number of Synsets (Ambiguity): 1
# Word: own | Wordnet Lemma: own
#  Word: own, POS-according-to-WordNet {'v', 's'} Number of Synsets (Ambiguity): 2
# Word: pardon | Wordnet Lemma: pardon
#  Word: pardon, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 5
# Word: pathetic | Wordnet Lemma: pathetic
#  Word: pathetic, POS-according-to-WordNet {'s'} Number of Synsets (Ambiguity): 3
# Word: patient | Wordnet Lemma: patient
#  Word: patient, POS-according-to-WordNet {'a', 'n'} Number of Synsets (Ambiguity): 3
# Word: pattern | Wordnet Lemma: pattern
#  Word: pattern, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 10
# Word: pleasurable | Wordnet Lemma: pleasurable
#  Word: pleasurable, POS-according-to-WordNet {'s'} Number of Synsets (Ambiguity): 1
# Word: point | Wordnet Lemma: point
#  Word: point, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 40
# Word: polite | Wordnet Lemma: polite
#  Word: polite, POS-according-to-WordNet {'a', 's'} Number of Synsets (Ambiguity): 3
# Word: pompous | Wordnet Lemma: pompous
#  Word: pompous, POS-according-to-WordNet {'a', 's'} Number of Synsets (Ambiguity): 2
# Word: pops | Wordnet Lemma: pop
#  Word: pops, POS-according-to-WordNet {'n', 'r', 'v', 's'} Number of Synsets (Ambiguity): 19
# Word: porridge | Wordnet Lemma: porridge
#  Word: porridge, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 1
# Word: possible | Wordnet Lemma: possible
#  Word: possible, POS-according-to-WordNet {'a', 'n'} Number of Synsets (Ambiguity): 4
# Word: pots | Wordnet Lemma: pot
#  Word: pots, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 10
# Word: powerful | Wordnet Lemma: powerful
#  Word: powerful, POS-according-to-WordNet {'a', 'r', 's'} Number of Synsets (Ambiguity): 6
# Word: prepare | Wordnet Lemma: prepare
#  Word: prepare, POS-according-to-WordNet {'v'} Number of Synsets (Ambiguity): 8
# Word: present | Wordnet Lemma: present
#  Word: present, POS-according-to-WordNet {'a', 'n', 'v'} Number of Synsets (Ambiguity): 18
# Word: protect | Wordnet Lemma: protect
#  Word: protect, POS-according-to-WordNet {'v'} Number of Synsets (Ambiguity): 2
# Word: proud | Wordnet Lemma: proud
#  Word: proud, POS-according-to-WordNet {'a', 's'} Number of Synsets (Ambiguity): 2
# Word: pruny | Wordnet Lemma: pruny
# Word: ptu | Wordnet Lemma: ptu
# Word: pull | Wordnet Lemma: pull
#  Word: pull, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 24
# Word: punctual | Wordnet Lemma: punctual
#  Word: punctual, POS-according-to-WordNet {'a'} Number of Synsets (Ambiguity): 1
# Word: purse | Wordnet Lemma: purse
#  Word: purse, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 6
# Word: pushed | Wordnet Lemma: push
#  Word: pushed, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 15
# Word: quick | Wordnet Lemma: quick
#  Word: quick, POS-according-to-WordNet {'n', 'r', 's'} Number of Synsets (Ambiguity): 8
# Word: quicky | Wordnet Lemma: quicky
#  Word: quicky, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 1
# Word: quiet | Wordnet Lemma: quiet
#  Word: quiet, POS-according-to-WordNet {'a', 'v', 'n', 's', 'r'} Number of Synsets (Ambiguity): 13
# Word: rare | Wordnet Lemma: rare
#  Word: rare, POS-according-to-WordNet {'s'} Number of Synsets (Ambiguity): 6
# Word: re | Wordnet Lemma: re
#  Word: re, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 3
# Word: ready | Wordnet Lemma: ready
#  Word: ready, POS-according-to-WordNet {'a', 'n', 'v', 's'} Number of Synsets (Ambiguity): 8
# Word: real | Wordnet Lemma: real
#  Word: real, POS-according-to-WordNet {'a', 'n', 'r', 's'} Number of Synsets (Ambiguity): 13
# Word: recent | Wordnet Lemma: recent
#  Word: recent, POS-according-to-WordNet {'n', 's'} Number of Synsets (Ambiguity): 3
# Word: refinement | Wordnet Lemma: refinement
#  Word: refinement, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 5
# Word: report | Wordnet Lemma: report
#  Word: report, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 13
# Word: responsibility | Wordnet Lemma: responsibility
#  Word: responsibility, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 3
# Word: rice | Wordnet Lemma: rice
#  Word: rice, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 5
# Word: right | Wordnet Lemma: right
#  Word: right, POS-according-to-WordNet {'a', 'v', 'n', 's', 'r'} Number of Synsets (Ambiguity): 36
# Word: rocket | Wordnet Lemma: rocket
#  Word: rocket, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 7
# Word: rocky | Wordnet Lemma: rocky
#  Word: rocky, POS-according-to-WordNet {'a', 's'} Number of Synsets (Ambiguity): 4
# Word: roof | Wordnet Lemma: roof
#  Word: roof, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 5
# Word: saddle | Wordnet Lemma: saddle
#  Word: saddle, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 9
# Word: safe | Wordnet Lemma: safe
#  Word: safe, POS-according-to-WordNet {'a', 'n', 's'} Number of Synsets (Ambiguity): 7
# Word: sandwich | Wordnet Lemma: sandwich
#  Word: sandwich, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 3
# Word: screen | Wordnet Lemma: screen
#  Word: screen, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 16
# Word: second | Wordnet Lemma: second
#  Word: second, POS-according-to-WordNet {'a', 'v', 'n', 's', 'r'} Number of Synsets (Ambiguity): 15
# Word: secret | Wordnet Lemma: secret
#  Word: secret, POS-according-to-WordNet {'n', 's'} Number of Synsets (Ambiguity): 14
# Word: shadow | Wordnet Lemma: shadow
#  Word: shadow, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 12
# Word: shadows | Wordnet Lemma: shadow
#  Word: shadows, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 12
# Word: shake | Wordnet Lemma: shake
#  Word: shake, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 15
# Word: shakes | Wordnet Lemma: shake
#  Word: shakes, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 15
# Word: shan | Wordnet Lemma: shan
#  Word: shan, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 1
# Word: shan-yu | Wordnet Lemma: shan-yu
# Word: shao | Wordnet Lemma: shao
# Word: sheep | Wordnet Lemma: sheep
#  Word: sheep, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 3
# Word: shimmy | Wordnet Lemma: shimmy
#  Word: shimmy, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 5
# Word: short | Wordnet Lemma: short
#  Word: short, POS-according-to-WordNet {'a', 'v', 'n', 's', 'r'} Number of Synsets (Ambiguity): 23
# Word: shrimp | Wordnet Lemma: shrimp
#  Word: shrimp, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 4
# Word: shu | Wordnet Lemma: shu
# Word: shun-yu | Wordnet Lemma: shun-yu
# Word: sick | Wordnet Lemma: sick
#  Word: sick, POS-according-to-WordNet {'a', 'n', 'v', 's'} Number of Synsets (Ambiguity): 9
# Word: sight | Wordnet Lemma: sight
#  Word: sight, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 9
# Word: sign | Wordnet Lemma: sign
#  Word: sign, POS-according-to-WordNet {'n', 'v', 's'} Number of Synsets (Ambiguity): 20
# Word: signal | Wordnet Lemma: signal
#  Word: signal, POS-according-to-WordNet {'n', 'v', 's'} Number of Synsets (Ambiguity): 6
# Word: silent | Wordnet Lemma: silent
#  Word: silent, POS-according-to-WordNet {'s'} Number of Synsets (Ambiguity): 6
# Word: single | Wordnet Lemma: single
#  Word: single, POS-according-to-WordNet {'a', 'n', 'v', 's'} Number of Synsets (Ambiguity): 10
# Word: sister | Wordnet Lemma: sister
#  Word: sister, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 4
# Word: skinny | Wordnet Lemma: skinny
#  Word: skinny, POS-according-to-WordNet {'a', 'n', 's'} Number of Synsets (Ambiguity): 5
# Word: sleep | Wordnet Lemma: sleep
#  Word: sleep, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 6
# Word: sleeve | Wordnet Lemma: sleeve
#  Word: sleeve, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 2
# Word: slipper | Wordnet Lemma: slipper
#  Word: slipper, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 2
# Word: slouch | Wordnet Lemma: slouch
#  Word: slouch, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 4
# Word: small | Wordnet Lemma: small
#  Word: small, POS-according-to-WordNet {'a', 'n', 'r', 's'} Number of Synsets (Ambiguity): 13
# Word: smart | Wordnet Lemma: smart
#  Word: smart, POS-according-to-WordNet {'a', 'n', 'v', 's'} Number of Synsets (Ambiguity): 9
# Word: soft | Wordnet Lemma: soft
#  Word: soft, POS-according-to-WordNet {'a', 'r', 's'} Number of Synsets (Ambiguity): 20
# Word: song | Wordnet Lemma: song
#  Word: song, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 6
# Word: sorrowful | Wordnet Lemma: sorrowful
#  Word: sorrowful, POS-according-to-WordNet {'a'} Number of Synsets (Ambiguity): 1
# Word: sorry | Wordnet Lemma: sorry
#  Word: sorry, POS-according-to-WordNet {'a', 's'} Number of Synsets (Ambiguity): 4
# Word: sorta | Wordnet Lemma: sorta
# Word: sound | Wordnet Lemma: sound
#  Word: sound, POS-according-to-WordNet {'a', 'n', 'v', 's'} Number of Synsets (Ambiguity): 24
# Word: southern | Wordnet Lemma: southern
#  Word: southern, POS-according-to-WordNet {'a', 's'} Number of Synsets (Ambiguity): 4
# Word: spare | Wordnet Lemma: spare
#  Word: spare, POS-according-to-WordNet {'n', 'v', 's'} Number of Synsets (Ambiguity): 13
# Word: speak | Wordnet Lemma: speak
#  Word: speak, POS-according-to-WordNet {'v'} Number of Synsets (Ambiguity): 5
# Word: speaks | Wordnet Lemma: speak
#  Word: speaks, POS-according-to-WordNet {'v'} Number of Synsets (Ambiguity): 5
# Word: spend | Wordnet Lemma: spend
#  Word: spend, POS-according-to-WordNet {'v'} Number of Synsets (Ambiguity): 3
# Word: spy | Wordnet Lemma: spy
#  Word: spy, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 6
# Word: squeal | Wordnet Lemma: squeal
#  Word: squeal, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 3
# Word: stable | Wordnet Lemma: stable
#  Word: stable, POS-according-to-WordNet {'a', 'n', 'v', 's'} Number of Synsets (Ambiguity): 7
# Word: stabs | Wordnet Lemma: stab
#  Word: stabs, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 6
# Word: stationed | Wordnet Lemma: station
#  Word: stationed, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 6
# Word: statue | Wordnet Lemma: statue
#  Word: statue, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 1
# Word: steady | Wordnet Lemma: steady
#  Word: steady, POS-according-to-WordNet {'a', 'v', 'n', 's', 'r'} Number of Synsets (Ambiguity): 10
# Word: stern | Wordnet Lemma: stern
#  Word: stern, POS-according-to-WordNet {'n', 's'} Number of Synsets (Ambiguity): 7
# Word: stick | Wordnet Lemma: stick
#  Word: stick, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 25
# Word: stole | Wordnet Lemma: stole
#  Word: stole, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 4
# Word: stoop | Wordnet Lemma: stoop
#  Word: stoop, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 8
# Word: straight | Wordnet Lemma: straight
#  Word: straight, POS-according-to-WordNet {'a', 'n', 'r', 's'} Number of Synsets (Ambiguity): 21
# Word: strange | Wordnet Lemma: strange
#  Word: strange, POS-according-to-WordNet {'a', 's'} Number of Synsets (Ambiguity): 3
# Word: strong | Wordnet Lemma: strong
#  Word: strong, POS-according-to-WordNet {'a', 's'} Number of Synsets (Ambiguity): 10
# Word: strut | Wordnet Lemma: strut
#  Word: strut, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 3
# Word: such | Wordnet Lemma: such
#  Word: such, POS-according-to-WordNet {'r', 's'} Number of Synsets (Ambiguity): 2
# Word: sure | Wordnet Lemma: sure
#  Word: sure, POS-according-to-WordNet {'a', 'r', 's'} Number of Synsets (Ambiguity): 10
# Word: surprising | Wordnet Lemma: surprise
#  Word: surprising, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 6
# Word: survive | Wordnet Lemma: survive
#  Word: survive, POS-according-to-WordNet {'v'} Number of Synsets (Ambiguity): 4
# Word: sweep | Wordnet Lemma: sweep
#  Word: sweep, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 15
# Word: sweet | Wordnet Lemma: sweet
#  Word: sweet, POS-according-to-WordNet {'a', 'n', 'r', 's'} Number of Synsets (Ambiguity): 16
# Word: swept | Wordnet Lemma: sweep
#  Word: swept, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 15
# Word: swift | Wordnet Lemma: swift
#  Word: swift, POS-according-to-WordNet {'n', 's'} Number of Synsets (Ambiguity): 5
# Word: swim | Wordnet Lemma: swim
#  Word: swim, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 6
# Word: sword | Wordnet Lemma: sword
#  Word: sword, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 1
# Word: syllable | Wordnet Lemma: syllable
#  Word: syllable, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 1
# Word: table | Wordnet Lemma: table
#  Word: table, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 8
# Word: talkin | Wordnet Lemma: talkin
# Word: tattered | Wordnet Lemma: tattered
#  Word: tattered, POS-according-to-WordNet {'s'} Number of Synsets (Ambiguity): 2
# Word: tattoo | Wordnet Lemma: tattoo
#  Word: tattoo, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 4
# Word: tea-cup | Wordnet Lemma: tea-cup
# Word: tear | Wordnet Lemma: tear
#  Word: tear, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 9
# Word: tent | Wordnet Lemma: tent
#  Word: tent, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 3
# Word: thin | Wordnet Lemma: thin
#  Word: thin, POS-according-to-WordNet {'a', 'r', 'v', 's'} Number of Synsets (Ambiguity): 13
# Word: threaten | Wordnet Lemma: threaten
#  Word: threaten, POS-according-to-WordNet {'v'} Number of Synsets (Ambiguity): 3
# Word: threshold | Wordnet Lemma: threshold
#  Word: threshold, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 5
# Word: thrill | Wordnet Lemma: thrill
#  Word: thrill, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 7
# Word: throng | Wordnet Lemma: throng
#  Word: throng, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 2
# Word: tie | Wordnet Lemma: tie
#  Word: tie, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 18
# Word: tight | Wordnet Lemma: tight
#  Word: tight, POS-according-to-WordNet {'a', 'r', 's'} Number of Synsets (Ambiguity): 16
# Word: timid | Wordnet Lemma: timid
#  Word: timid, POS-according-to-WordNet {'a', 'n', 's'} Number of Synsets (Ambiguity): 4
# Word: tiny | Wordnet Lemma: tiny
#  Word: tiny, POS-according-to-WordNet {'s'} Number of Synsets (Ambiguity): 1
# Word: tony | Wordnet Lemma: tony
# Word: top | Wordnet Lemma: top
#  Word: top, POS-according-to-WordNet {'a', 'n', 'v'} Number of Synsets (Ambiguity): 22
# Word: touch | Wordnet Lemma: touch
#  Word: touch, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 27
# Word: tough | Wordnet Lemma: tough
#  Word: tough, POS-according-to-WordNet {'a', 'n', 's'} Number of Synsets (Ambiguity): 12
# Word: townsfolk | Wordnet Lemma: townsfolk
#  Word: townsfolk, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 1
# Word: traditional | Wordnet Lemma: traditional
#  Word: traditional, POS-according-to-WordNet {'a', 's'} Number of Synsets (Ambiguity): 2
# Word: trecherous | Wordnet Lemma: trecherous
# Word: troops | Wordnet Lemma: troops
#  Word: troops, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 7
# Word: true | Wordnet Lemma: true
#  Word: true, POS-according-to-WordNet {'a', 'v', 'n', 's', 'r'} Number of Synsets (Ambiguity): 15
# Word: twigs | Wordnet Lemma: twig
#  Word: twigs, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 3
# Word: uhh | Wordnet Lemma: uhh
# Word: uhhh | Wordnet Lemma: uhhh
# Word: ultimate | Wordnet Lemma: ultimate
#  Word: ultimate, POS-according-to-WordNet {'a', 'n', 's'} Number of Synsets (Ambiguity): 3
# Word: um | Wordnet Lemma: um
# Word: ummmm | Wordnet Lemma: ummmm
# Word: unbeknownst | Wordnet Lemma: unbeknownst
#  Word: unbeknownst, POS-according-to-WordNet {'r', 's'} Number of Synsets (Ambiguity): 2
# Word: unfurls | Wordnet Lemma: unfurl
#  Word: unfurls, POS-according-to-WordNet {'v'} Number of Synsets (Ambiguity): 1
# Word: uniform | Wordnet Lemma: uniform
#  Word: uniform, POS-according-to-WordNet {'a', 'n', 'v', 's'} Number of Synsets (Ambiguity): 6
# Word: unimpressed | Wordnet Lemma: unimpressed
#  Word: unimpressed, POS-according-to-WordNet {'s'} Number of Synsets (Ambiguity): 1
# Word: unsuccessful | Wordnet Lemma: unsuccessful
#  Word: unsuccessful, POS-according-to-WordNet {'a', 's'} Number of Synsets (Ambiguity): 2
# Word: unsuited | Wordnet Lemma: unsuited
#  Word: unsuited, POS-according-to-WordNet {'s'} Number of Synsets (Ambiguity): 1
# Word: uphold | Wordnet Lemma: uphold
#  Word: uphold, POS-according-to-WordNet {'v'} Number of Synsets (Ambiguity): 3
# Word: upper | Wordnet Lemma: upper
#  Word: upper, POS-according-to-WordNet {'n', 's'} Number of Synsets (Ambiguity): 6
# Word: upright | Wordnet Lemma: upright
#  Word: upright, POS-according-to-WordNet {'a', 'n', 's'} Number of Synsets (Ambiguity): 5
# Word: upset | Wordnet Lemma: upset
#  Word: upset, POS-according-to-WordNet {'n', 'v', 's'} Number of Synsets (Ambiguity): 17
# Word: upstream | Wordnet Lemma: upstream
#  Word: upstream, POS-according-to-WordNet {'a', 'r'} Number of Synsets (Ambiguity): 2
# Word: urgent | Wordnet Lemma: urgent
#  Word: urgent, POS-according-to-WordNet {'s'} Number of Synsets (Ambiguity): 1
# Word: utter | Wordnet Lemma: utter
#  Word: utter, POS-according-to-WordNet {'v', 's'} Number of Synsets (Ambiguity): 6
# Word: valley | Wordnet Lemma: valley
#  Word: valley, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 1
# Word: waist | Wordnet Lemma: waist
#  Word: waist, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 2
# Word: warm | Wordnet Lemma: warm
#  Word: warm, POS-according-to-WordNet {'a', 'r', 'v', 's'} Number of Synsets (Ambiguity): 13
# Word: wear | Wordnet Lemma: wear
#  Word: wear, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 12
# Word: wen | Wordnet Lemma: wen
#  Word: wen, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 1
# Word: white | Wordnet Lemma: white
#  Word: white, POS-according-to-WordNet {'a', 'n', 'v', 's'} Number of Synsets (Ambiguity): 25
# Word: whole | Wordnet Lemma: whole
#  Word: whole, POS-according-to-WordNet {'a', 'n', 'r', 's'} Number of Synsets (Ambiguity): 8
# Word: whoop | Wordnet Lemma: whoop
#  Word: whoop, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 3
# Word: wide | Wordnet Lemma: wide
#  Word: wide, POS-according-to-WordNet {'a', 'r', 's'} Number of Synsets (Ambiguity): 11
# Word: wild | Wordnet Lemma: wild
#  Word: wild, POS-according-to-WordNet {'a', 'n', 'r', 's'} Number of Synsets (Ambiguity): 17
# Word: wish | Wordnet Lemma: wish
#  Word: wish, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 10
# Word: wobbling | Wordnet Lemma: wobble
#  Word: wobbling, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 4
# Word: woo | Wordnet Lemma: woo
#  Word: woo, POS-according-to-WordNet {'v'} Number of Synsets (Ambiguity): 2
# Word: wooo | Wordnet Lemma: wooo
# Word: worried | Wordnet Lemma: worry
#  Word: worried, POS-according-to-WordNet {'n', 'v'} Number of Synsets (Ambiguity): 8
# Word: worth | Wordnet Lemma: worth
#  Word: worth, POS-according-to-WordNet {'n', 's'} Number of Synsets (Ambiguity): 5
# Word: worthwhile | Wordnet Lemma: worthwhile
#  Word: worthwhile, POS-according-to-WordNet {'s'} Number of Synsets (Ambiguity): 1
# Word: worthy | Wordnet Lemma: worthy
#  Word: worthy, POS-according-to-WordNet {'a', 'n', 's'} Number of Synsets (Ambiguity): 4
# Word: wounded | Wordnet Lemma: wounded
#  Word: wounded, POS-according-to-WordNet {'n', 'v', 's'} Number of Synsets (Ambiguity): 4
# Word: wrong | Wordnet Lemma: wrong
#  Word: wrong, POS-according-to-WordNet {'a', 'v', 'n', 's', 'r'} Number of Synsets (Ambiguity): 13
# Word: xiao | Wordnet Lemma: xiao
# Word: yao | Wordnet Lemma: yao
# Word: yeeahhhhhh | Wordnet Lemma: yeeahhhhhh
# Word: yeeeeeahhhhhhh | Wordnet Lemma: yeeeeeahhhhhhh
# Word: yin-yang | Wordnet Lemma: yin-yang
# Word: young | Wordnet Lemma: young
#  Word: young, POS-according-to-WordNet {'a', 'n', 's'} Number of Synsets (Ambiguity): 14
# Word: yrrrrrrraah | Wordnet Lemma: yrrrrrrraah
# Word: yu | Wordnet Lemma: yu

# %% [markdown]
# ## Read in just one file from a directory in your repo
# Open one of your text files in your repo for reading.
# In this example, we'll climb directories, and that means we'll use the os library to show you how to handle filepaths.
#
# When your file isn't immediately in the same folder as your Python script, and you need to climb for it, start with os library by getting the current working directory:

# %%
# cwd is my shorthand for "current working directory"
cwd = os.getcwd()
print(cwd)
# Out:
# /Users/trinityrose/Documents/github/digit210/python-nlp

# %%
# climb up one directory and retrieve a file. (here's how you would do that)
# (ADAPT THIS CODE TO REACH DOWN OR UP AS NEEDED.)
filepath = 'sample.txt'
print(filepath)
# Out:
# sample.txt

# %%
# Now, Python must OPEN and READ the text file in order to process it:
f = open(filepath, 'r', encoding='utf8').read()
# readFile = f.read()
print(f)
# Out:
# [Disney's Mulan
# Compiled by Barry Adams during theater showings in 1998
# Last updated: August 18, 1998
# Source: The Internet Movie Scripts Database (IMSDb): https://imsdb.com/scripts/Mulan.html]
# Mulan is the property and copyright of the Walt Disney Company, Inc.  The
# script on this page was compiled while watching Mulan in the theater during
# the summer of 1998 when the film originally aired.]
#
# [Chinese guard is seen walking on The Great Wall.  Shan-Yu's falcon swoops
# down and hits the guard on the head knocking his helmet off.  The falcon lands
# on top of a flag pole in front of a full moon and lets out a large cry.  One
# grappling hook comes over The Great Wall.  The guard walks over to the edge
# and sees many grappling hooks coming towards him]
#
# Guard [yelling]:  We're under attack!  Light the signal!
#
# [Guard runs to the tower and up the ladder as Hun Bald Man #1 and Hun Long
# Hair Man appear trying to stop him.  Hun Bald Man #1 breaks the ladder with
# his sword just as Guard reaches the top.  The guard picks up the torch to
# light the fire and sees Shan-Yu jump over the edge of the tower and looks at
# him across from the caldron.  The guard throws the torch into the caldron
# lighting a large fire.  Shan-Yu watches as each tower lights their caldrons
# one by one]
#
# Guard [sternly]:  Now all of China knows you're here.
#
# Shan-Yu [taking the flag and holding it over the fire]:  Perfect.
#
# [Cut to the palace.  The large doors to the central chamber open as General Li
# walks in flanked on his left and right by soldiers and approaches the Emperor.
# He bows, then looks up]
#
# General Li:  Your Majesty, the Huns have crossed our Northern border.
#
# Chi Fu:  Impossible! No one can get through The Great Wall.  [The Emperor
# motions for Chi Fu's silence]
#
# General Li:  Shun-Yu is leading them.  We'll set up defenses around your
# palace immediately.
#
# Emperor [forcefully]:  No!  Send your troops to protect my people.  Chi Fu,
#
# Chi Fu:  Yes, your highness.
#
# Emperor: Deliver conscription notices throughout all the provinces.  Call up
# reserves and as many new recruits as possible.
#
# General Li:  Forgive me your Majesty, but I believe my troops can stop him.
#
# Emperor:  I wont take any chances, General.  A single grain of rice can tip
# the scale.  One man may be the difference between victory and defeat.
#
# [Cut to Mulan using her chopsticks to single out a grain of rice on top of the
# mound of rice]
#
# Mulan: Quiet and demure...graceful...polite...[picking up some rice with her
# chopsticks and eating a mouthful] delicate...refined...poised... [She sets
# down her chopsticks and writes down a final word on her right arm] punctual.
# [A cock crows]  Aiya.  [Calling out]  Little brother. Little brother.  Lit-
# ahhh, there you are.  Who's the smartest doggie in the world?  Come on smart
# boy, can you help me with my chores today?
#
# [Mulan ties a sack of grain around Little Brother's waist.  She ties a stick
# onto Little brother so that end of it is in front of Little Brother's face.
# She ties the bone on the end of the stick just out of reach.  Little Brother
# begins to run after the bone which he cannot reach.  Mulan opens the door for
# Little Brother and he runs into the door frame, then out the open door.
# Little brother runs by the chickens and Khan - the family horse]
#
# [Cut to Mulan's Father, Fa Zhou, kneeling and praying before the Fa family's
# ancestors]
#
# Fa Zhou:  Honorable ancestors, please help Mulan impress the matchmaker today.
#
#
# Little Brother [running into the temple and around Fa Zhou scattering grain
# around the floor]: Bark, bark, bark, bark, bark.
#
# [The chickens follow Little Brother into the temple and begin to feed on the
# grain]
#
# Fa Zhou:  Please, PLEASE, help her.
#
# [Mulan steps up to the temple seeing Little Brother on his hind legs trying to
# get the bone.  Mulan bends the stick down so that Little brother can reach the
# bone.  Little brother gnaws on the bone happily.  Mulan continues toward the
# temple]
#
# Mulan [calling out]: Father I brought your--whoop!  [Fa Zhou bumps into Mulan.
# The cup falls to the ground and Fa Zhou catches the teapot with the handle of
# his cane]
#
# Fa Zhou:  Mulan--
#
# Mulan:  I brought a spare. [Mulan pulls out a cup from underneath the back of
# her dress and begins to pour the tea]
#
# Fa Zhou:  Mulan--
#
# Mulan [hurried]: Remember, the doctor said three cups of tea in the morning--
#
# Fa Zhou:  Mulan--
#
# Mulan:  And three at night.
#
# Fa Zhou:  Mulan, you should already be in town.  We're counting on you to up--
#
# Mulan:  --uphold the family honor.  Don't worry father.  I wont let you down.
# [Mulan covers over the writing on her arm with here sleeve]  Wish me luck.
# [Mulan hurries down the stairs]
#
# Fa Zhou [calling out]:  Hurry!  [to himself] I'm going to...pray some more.
# [Fa Zhou turns and walks back into the temple]
#
# [Cut to the town with Fa Li looking worried]
#
# Bath Lady [poking out of her building]:  Fa Li, is your daughter here yet?
# The matchmaker is not a patient woman.  [She goes back into the building]
#
# Fa Li:  Of all days to be late.  I should have prayed to the ancestors for
# luck.
#
# Grandma Fa [walking in with a Cri-Kee in a cage]:  How lucky can they be,
# they're dead.  Besides,  I've got all the luck we'll need.  [Speaking to
# Cri-Kee]  This is your chance to prove yourself.  [Cri-Kee chirps approvingly.
# Grandma Fa covers her eyes steps into a busy street]
#
# Fa Li [excitedly]:  Grandma No!
#
# [The traffic barely misses Grandma Fa as she crosses the busy street.  But two
# horse and carriage collide causing a big accident.  She arrives at the other
# side of the street, uncovers here eyes and looks at Cri-Kee]
#
# Grandma Fa:  Yep, this cricket's a lucky one. [Cri-Kee falls over out of
# fright]
#
# Fa Li [sighing in relief]:  Hai.
#
# [Mulan arrives on Khan jumping over the recent accident in the street and
# jumps off with hay stuck in her hair]
#
# Mulan: I'm here.  [Seeing a stern look from her mother] What?  But Mama I had
# to--
#
# Fa Li:  None of your 'xcuses.  Now let's get you cleaned up. [They walk
# together into the preparation area]
#
# [Song: Honor to us all]
#
# Bath Lady:  [all the while Bath Lady undresses Mulan and pushes her into the
# Bath]
# This is what you give me
# to work with?
# Well, honey, I've seen worse.
# We're gonna turn
# this sow's ear
# Into a silk purse. [Bath Lady moves the silk partition aside showing Mulan in
# the bath]
#
# Mulan [spoken]:  It's freezing.
#
# Fa Li [spoken]:  It would have been warm if you were here on time.
#
# Bath Lady [washing Mulan's hair]:
# We'll have you
# Washed and dried
# Primped and polished
# till you glow with pride
# Trust my recipe for
# instant bride
# You'll bring honor to us all
#
# Fa Li [grabbing a sponge and Mulan's right arm to start cleaning her.  She
# notices the writing] [spoken]:  Mulan, what's this?
#
# Mulan [Drawing her arm back and batting her eyelashes] [spoken]:  Ahh, notes,
# in case I forget something?
#
# Grandma Fa [spoken]:  Here, hold this [hands the cricket to Fa Li].  We'll
# need more luck than I thought.  [Mulan looks on with an air of disappointment]
#
# [Cut to the hair dressers]
#
# Hair Dresser 1 [Brushing and combing Mulan's hair much to Mulan's chagrin]:
# Wait and see
# When we're through
#
# Hair Dresser 2:
# Boys will gladly go to
# war for you
#
# Hair Dresser 1:
# With good fortune
#
# Hair Dresser 2 [Finalizing the hairdo to look exactly like hers]:
# And a great hairdo
#
# Both:
# You'll bring honor to us all
#
# Fa Li and others:  [Mulan following her Mother passes a xiangqi game and
# pauses to make an impressive move.  Mulan has a smug look on her face when Fa
# Li comes back and drags Mulan away]
# A girl can bring her family
# Great honor in one way
# By striking a good match
# And this could be the day
#
# Dresser 1 [Dresser 1, Dresser 2, and Fa Li dress Mulan]:
# Men want girls
# with good taste
#
# Dresser 2:
# Calm
#
# Fa Li:
# Obedient
#
# Dresser 1:
# Who work fast-paced
#
# Fa Li:
# With good breeding
#
# Dresser 2 [Pulling the dress tight around her waist]:
# And a tiny waist
#
# Mulan [expressing her waist being squeezed tight] [spoken]: huh.
#
# All Three:
# You'll bring honor to us all
#
# Chorus:  [Mulan follows Fa Li and sees boy stealing a doll from a girl.  Mulan
# grabs the doll from the boy and returns it to its owner]
# We all must serve
# our Emperor
# Who guards us from the Huns
# A man by bearing arms
# A girl by bearing sons
#
# Make-up Lady/Fa Li: [Putting on Mulan's face, powder, lipstick and eye liner]
# [in a 3 person round]
#  When we're through
# you can't fail
# Like a lotus blossom
# soft and pale
# How could any fellow
# say "No sale"
# You'll bring honor to us all
# [Make-Up Lady holds a mirror so Mulan can see her reflection.  Not looking
# pleased, Mulan takes her single, short bang and brings it down in front of her
# forehead and smiles]
#
# Fa Li [spoken. Fa Li places a hair comb in Mulan's hair]:  There, you're
# ready.
#
# Grandma Fa [spoken]:  Not yet! An apple for serenity [putting an apple in
# Mulan's mouth]...A pendant for balance [places a yin-yang pendant under her
# sash] [sings]
#
# Beads of jade for beauty [putting beads around Mulan's neck]
# You must proudly show it [Grandma Fa raises her chin high with her hand]
# Now add a cricket just for luck [putting the cage with Cri-Kee under Mulan's
# sash in the back.  Cri-Kee doesn't look pleased]
# And even you can't blow it
#
# Mulan:  [Walking to catch up with the other maidens]
# Ancestors
# Hear my plea
# Help me not to make a fool of me
# And to not uproot my fam'ly tree
# Keep my father standing tall
#
# Maidens and Mulan: [Mulan taking the parasol from Fal Li and running to fall
# in line with the other 4 maidens]
# Scarier than the undertaker
# We are meeting our
# matchmaker
#
# All Townspeople:
# Destiny
# Guard our girls
# And our future
# as it fast unfurls
# Please look kindly on
# these cultured pearls
# Each a perfect porcelain doll
#
# Maiden #1:  Please bring honor to us
# Maiden #2:  Please bring honor to us
# Maiden #3:  Please bring honor to us
# Maiden #4:  Please bring honor to us
# Mulan and Maidens:  Please bring honor to us all!
#
# [All Girls and Mulan arrive before the Matchmaker crouched down behind their
# parasols.  End of song]
#
# Matchmaker [looking at her clipboard]:  Fa Mulan
#
# Mulan [Jumping up and raising her hand]:  Present.
#
# Matchmaker:  Speaking without permission.
#
# Mulan:  Oops.
#
# Grandma Fa [to Fa Li]:  Who spit in her bean curd?
#
# [Mulan walks into the Matchmaker's building with the Matchmaker following
# behind and closing the door]
#
# Matchmaker [looking over Mulan]: Huh, Hmm, too skinny.  [Cri-Kee escapes from
# his cage.  Mulan struggles to catch him] Hmph, not good for bearing sons.
# [Mulan puts Cri-Kee in her mouth when Matchmaker turns around to face her]
# Recite the final admonition.
#
# Mulan [nodding and smiling]:  Mmm-Hmm.  [Takes out fan and covers her mouth as
# she spits out Cri-Kee] Ptu
#
# Matchmaker:  Well...
#
# Mulan [with dignity]: Fulfill your duties calmly and re...f--[looking at her
# arm with smeared writing] spectfully.  Reflect before you snack [surprised,
# Mulan looks at her arm again] act.  [now rapidly] This shall bring you honor
# and glory.  [Fanning herself rapidly and sighing in relief] Huh.
#
# Matchmaker [snatches the fan and looks at it on both sides looking for notes
# not finding any.  Mulan smiles big when Matchmaker looks at her.  Matchmaker
# grabs Mulan's right arm pulling her along while smearing the writing and
# leaving some ink on her hand]  Hmmm, this way.  Now, pour the tea  [Pushing a
# teapot towards Mulan].  To please your future in-laws you must demonstrate a
# sense of dignity [Matchmaker smears ink around her mouth.  Mulan staring at
# Matchmaker pours some tea onto the table then notices her mistake and pours
# the tea into the cup] and refinement.  You must also be poised.  [Mulan
# notices Cri-kee in the tea-cup as Matchmaker takes the cup]
#
# Mulan [quiet and timid]:  Um, pardon me.
#
# Matchmaker:  And silent! [Matchmaker sniffs the tea]
#
# Mulan [reaching and grabbing the teacup]:  Could I just take that back...one
# moment.
#
# [They struggle for the teacup and it turns over on Matchmaker and Cri-kee
# jumps down matchmaker's dress]
#
# Matchmaker:  Why you clumsy--[Matchmaker feels Cri-Kee in her dress and dances
# around]  Wooo, woooo, wooooooo, [Matchmaker knocks over her pot of coals, and
# sits down on the coals.  Matchmaker jumps around screaming]  Ahhhhhhhhhhh
# [Mulan grabs her fan and briskly fans the charred area on Matchmaker's behind
# causing it to flame up.  Mulan looks surprised about her mistake]
#
# [Cut to outside Matchmakers building showing Grandma Fa with much noise coming
# from Matchmaker's building]
#
# Grandma Fa [to Fa Li]:  I think it's going well, don't you?
#
# Matchmaker [running out of the building screaming]:  Put it out! Put it out!
# Put it out! [Mulan takes the teapot, throws the tea on Matchmaker and puts out
# the fire.  She bows, hands the teapot back to Matchmaker and covers her face
# as she walks toward Fa Li and Grandma Fa] [with anger]  You are a disgrace!
# [Matchmaker throws the teapot down smashing it to pieces]  You may look like a
# bride, but you will never bring your family honor!
#
# [The townsfolk who have gathered whisper and walk away]
#
# [Cut to Mulan walking through the gate with her home leading khan.  She looks
# sorrowful.  Fa Zhou sees his daughter and smiles.  Mulan sees her father's
# smile.  She covers her face with Khan's head and leads him to the water
# trough]
#
# [Song: Reflection]
#
# Mulan:
# Look at me [looking at her reflection in the water trough]
# I will never pass for
# a perfect bride [taking off her earrings and beads of jade]
# Or a perfect daughter [Mulan watches Fa Li relating what happened at the
# Matchmaker's to Fa Zhou]
# Can it be
# I'm not meant to play
# this part?  [Mulan releases Cri-Kee back to the wild]
# Now I see
# That if I were to truly
# To be myself [Mulan hops along the bridge railing]
# I would break my
# family's heart
#
# Who is that girl I see  [Mulan looks into the pond and sees her own
# reflection]
# Staring straight
# Back at me? [Mulan puts her hand on the Great Stone Dragon and looks toward
# the temple]
# Why is my reflection someone
# I don't know? [Cri-Kee rowing across the pond on a lily pad]
# Somehow I cannot hide [Mulan walking into the family temple]
# Who I am [Cri-Kee watches Mulan in the temple seeing multiple reflections of
# herself in the ancestors' stones]
# Though I've tried  [Mulan bows to the ancestors]
# When will my reflection show
# Who I am inside?  [Mulan finishes wiping off her make-up seeing her reflection
# in the stones]
# When will my reflection show
# Who I am inside? [Mulan gets up and heads out the temple]
#
# [End of song.  Mulan sits on a bench under the blossom tree.  Fa Zhou
# approaches her, clearing his throat.  Mulan sees him approaching and turns her
# head away.  Fa Zhou sits down beside Mulan]
#
# Fa Zhou:  My, my, what beautiful blossoms we have this year [looking up into
# the blossom tree].  But look, this one's late.  But, I'll bet that when it
# blooms, it will be the most beautiful of all.  [Mulan and Fa Zhou share
# smiles.  Drums start pounding announcing the arrival of Chi Fu and two guards
# on horseback]
#
# Mulan:  What is it?
#
# [Fa Zhou gets up and walks to the entrance of their house with Mulan
# following]
#
# Fa Li:  Mulan, stay inside.
#
# [Grandma Fa clears her throat catching Mulan's attention and motions inside.
# Mulan spies the railing near the wall and climbs up to watch over the roof]
#
# Chi Fu:  Citizens  I bring you a proclamation from the Imperial City:  the
# Huns have invaded China!
#
# Townspeople [expressing surprise]:  No!
#
# Chi Fu:  By order of the Emperor, one man from every family must serve in the
# Imperial Army.  The Xiao family [a family member steps up, bows to the guard
# and takes the conscription notice from the guard].  The Yi family.
#
# Yi's Son [holding his old father back]:  I will serve the Emperor in my
# father's place.
#
# Chi Fu:  The Fa Family.
#
# Mulan:  No.
#
# [Fa Zhou gives his cane to Fa Li and walks toward Chi Fu.  Fa Zhou bows before
# the horsemen]
#
# Fa Zhou [standing proud]:  I am ready to serve the Emperor.  [Fa Zhou reaches
# for the conscription notice]
#
# Mulan [running outside to keep her father from taking the conscription
# notice]:  Father, you can't go.
#
# Fa Zhou [turning to see his daughter]:  Mulan!
#
# Mulan:  Please sir, my father has already fought bravely--
#
# Chi Fu:  Silence!  You would do well to teach your daughter to hold her tongue
# in a man's presence.
#
# Fa Zhou [looking away from Mulan]:  Mulan, you dishonor me.
#
# [Grandma Fa guides Mulan back away]
#
# Chi Fu [handing Fa Zhou the conscription notice]:  Report tomorrow at the Wu
# Shu camp.
#
# Fa Zhou:  Yes, sir. [Fa Zhou walks back into the homestead refusing to take
# his cane from Fa Li]
#
# Chi Fu [fading out as we follow Fa Zhou]:  The Chu family.  The Wen family.
# The Chang family.  The...
#
# [Cut to Fa Zhou in his armory at night.  Fa Zhou takes out his sword and
# practices his stances.  Whan he balances on his right leg, his leg injury acts
# up and he falls.  Unbeknownst to her father, Mulan watches in horror.  She
# breathes heavily]
#
# [Cut to dinner.  The Fa Zhou, Grandma Fa, Fa Li, and Mulan eat in silence.
# Thunder can be heard and lightning can be seen through the opaque window.
# Mulan pours the tea for her family.  She slams her teacup down on the table
# and stands up]
#
# Mulan:  You shouldn't have to go.
#
# Fa Li:  Mulan!
#
# Mulan:  There are plenty of young men to fight for China.
#
# Fa Zhou:  It is an honor to protect my country and my family.
#
# Mulan [angrily]:  So you'll die for honor!
#
# Fa Zhou [standing up and angered]:  I will DIE doing what's right.
#
# Mulan [starts to speak but is cut off]: But if you--
#
# Fa Zhou:  I know my place, it is time you learned yours.
#
# [Mulan looking like she's about to cry, turn away from Fa Zhou and runs
# outside into the rain storm and cries]
#
# [Cut to Mulan sitting at the base of the Great Stone Dragon in the rain.
# Mulan looks down to see her reflection in the puddle caused by the rain. She
# watches her parents in the bedroom.  Fa Li turns away from Fa Zhou and walks
# out of site.  Fa Zhou blows out the light.  Mulan gets up and walks to the Fa
# Family Temple.  Mulan's image reflects off the stone tablets as she lights
# incense and places it in the hanging encense holder.  She bows and prays to
# her ancestors. Getting up, Mulan hurries down the steps.  Cri-Kee sees her and
# hops down from above and follows her.  Mulan goes to her parent's bedroom and
# takes the conscription notice replacing it with the hair comb her mother gave
# to her.  She pauses to give her parents a loving, sorrowful look and hurries
# out.  Cut to Mulan in the armory.  She opens the cabinet with the armor.
# Using her father's sword, she cuts her hair short and ties it up above her
# head.  She finishes putting on the armor and ties it in the front.  She takes
# the sword and places it in the scabbard to her left.  Cut to Mulan in the
# stable doorway.  Khan rears back in fright at the sight of Mulan.  Mulan goes
# forward and comforts Khan letting him know her identity.  Mulan walks Khan out
# of the stable, Cri-Kee watches from the ground as she passes by.  Mulan takes
# one sorrowful glance back at her parents bedroom and rides Khan through the
# gate and off to camp.]
#
# [Cut to the face of a statue in the Fa Family Temple.  The eyes glow.  Cut to
# Grandma Fa.  She wakes up with a start rising in bed.  Cut to Grandma Fa
# walking into Fa Li and Fa Zhou's bedroom, both are in bed]
#
# Grandma Fa:  Mulan is gone.
#
# Fa Zhou [waking up]:  What?  It can't be.  [Fa Zhou looks at his night stand
# and notices the hair comb in place of his conscription notice.  He checks the
# cabinet and sees his armor is gone.  He hurries outside] [calling out]  Mulan!
# [He stumbles while walking because of his leg injury] No.
#
# Fa Li [kneeling down beside the fallen Fa Zhou]:  You must go after her.  She
# could be killed!
#
# Fa Zhou [sadly]:  If I reveal her, she will be. [Fa Zhou embraces Fa Li]
#
# Grandma Fa:  Ancestors, hear our prayer: Watch over Mulan.
#
# [Cut to the Fa Family Temple.  A wind blows out the incense at the base of the
# center stone.  The center stone begins to glow as First Ancestor comes to
# life]
#
# First Ancestor [motioning to a bronze dragon]:  Mushu, awaken!
#
# [Mushu comes to life and falls to the ground flat on his back all being
# obscured by smoke]
#
# Mushu [rising from the smoke arms stretched out]:  I live!  So tell me what
# mortal needs my protection Great Ancestor.  You just say the word and I'm
# there.
#
# First Ancestor [agitated]:  Mushu!
#
# Mushu:  Hey, let me say something. Anybody who is foolish enough to threaten
# our family, vengeance will be MINE.  Hrrrrr.
#
# First Ancestor [sternly to silence Mushu]:  Mushu!  These are the family
# guardians [motioning towards the stone statues on pedestals near the ceiling].
# They...
#
# Mushu [dejectedly]:  Protect the family.
#
# First Ancestor [pointing to the empty pedestal]:  And you, oh demoted one.
#
# Mushu:  I...ring the gong.
#
# First Ancestor:  That's right, now, wake up the ancestors.
#
# Mushu:  One family reunion coming right up.  [ringing the gong] Okay people,
# people look alive, lets go! C'mon get up.  Let's move it, rise and shine.
# You're way past the beauty sleep thing now trust me!
#
# Ancestor 1:  I knew it, I knew it. That Mulan was a trouble maker from the
# start.
#
# Ancestor 3:  Don't look at me, she gets it from your side of the family.
#
# Ancestor 2:  She's just trying to help her father.
#
# Ancestor 4 [appearing out of thin air]:  But, if she is discovered, Fa Zhou
# will be forever shamed.  Dishonor will come to the family.  Traditional values
# will disintegrate.
#
# Ancestor 5:  Not to mention they'll lose the farm.
#
# Ancestor 1:  My children never caused such trouble.  They all became
# acupuncturists.
#
# Ancestor 3:  Well, We can't all be acupuncturists.
#
# Ancestor 6:  No, your great granddaughter had to be cross-dresser!
#
# [All ancestors argue at once, except First Ancestor]
#
# Ancestor 7:  Let a guardian bring her back.
#
# Ancestor 8 [grabbing Mushu and bringing him next to a guardian]: Yeah, awaken
# the most cunning.
#
# Ancestor 4 [taking Mushu and holding him next to the stone rabbit guardian]:
# No, the swiftest.
#
# Ancestor 9 [grabbing Mushu and holding him next to the stone monkey guardian]:
# No, send the wisest.
#
# First Ancestor:  Silence!  We must send the most powerful of all [Motioning to
# the Great Stone Dragon as it is seen through the window]
#
# Mushu [climbs up the empty guardian post laughing]:  Ho, ho, heh, heh. Okay,
# okay, I get the drift, I'll go. [All Ancestors give a quick look of surprise
# and laugh uncontrollably]  You all don't think I can do it.  Watch this here.
# [Mushu produces a small flame from his mouth]  Ah, ha, Jump back, I'm pretty
# hot huh.  Don't make me have to singe nobody to prove no point.
#
# First Ancestor [grabbing Mushu and pulling away from the post]:  You had your
# chance to protect the Fa family.
#
# Ancestor 6:  Your mis-guidance led Fa Deng to disaster.
#
# Fa Deng [with his decapitated head on his lap]:  Yeah, thanks a lot.
#
# Mushu:  And your point is?
#
# First Ancestor:  The point is we will be sending a real dragon to retrieve
# Mulan.
#
# Mushu:  What?  But I'm a real dragon.
#
# First Ancestor [grabbing Mushu and pulling him away from the guardian post as
# Mushu fights to hold on]:  You are not worthy of this spot.  Now, awaken the
# Great Stone Dragon.  [First Ancestor throws Mushu out of the temple]
#
# Mushu [looking back into the temple]:  So you'll get back to me on the job
# thing.
#
# [An ancestor throws Mushu's gong and hits Mushu in the face]
#
# Mushu [walking with a slouch and banging the gong on the ground]:  Just one
# chance is that too much to ask?  I mean, it's not like it'll kill ya.
#
# Mushu [rings the gong and looks at the Great Stone Dragon]:  Yo rocky, wake
# up!  You gotta go fetch Mulan.  [pauses as nothing happens.  Mushu walks over
# to the side of the statue] C'mon boy, go get her, go on, [throws the gong
# stick off the screen and whistles] Come on.  [Angrily while climbing up the
# Great Stone Dragon] Grrr, Grrrr.  [speaking in his ear and banging the ear
# with the gong] Hello, helloooooo. [curtly] Hello [bangs the gong extra hard
# against the ear causing it to break off].  Uh oh.  [The Great Stone Dragon
# crumbles to the ground, head intact minus the ear].  [knocks on the dragon's
# head] Uh, Stoney, Stooooneeey.  Oh man, they're gonna kill me!
#
# First Ancestor [calling out through the temple window]:  Great Stone Dragon,
# have you awaken?
#
# Mushu [holding the head of the Great Stone Dragon up to that First Ancestor
# can only see it's head and Mushu's body]:  Uhhh, Yes, I just woke up.  And I
# am the Great Stone Dragon, good morning [Mushu waves].  I will go forth and
# fetch Mulan.  Did, did I mention that I was the Great Stone Dragon?
#
# First Ancestor:  Go, The fate of the Fa Family rests in your claws.
#
# Mushu:  Don't even worry about it, I will not lose face.  [Mushu falls down
# the hill under the weight of the Great Stone Dragon's head and lands on the
# dragon's pedestal with the head falling on top of him]
#
# Mushu [muffled]:  Ow, my elbow.  Aw, aw, I know I twisted something.
# [Throwing the head off him]  That's just great.  Now what?  I'm doomed!   And
# all 'cause miss man decides to take her little drag show on the road.
#
# [Cri-Kee enters stage right]
#
# Cri-Kee:  Chirp, Chirp.
#
# Mushu:  Go get her?   What's the matter with you?  After this great stone
# Humpty Dumpty mess, I'd have to bring her home with a medal to get back in the
# temple.  Wait a minute, that's it!  I make Mulan a war hero, then they'll be
# begging me to come back to work.  That's the master plan.  Oh, you've gone and
# done it now. [Mushu runs off stage right]
#
# Cri-Kee [hopping along side of Mushu]:  Chirp.  Chirp Chirp Chirp.
#
# Mushu [pushing Cri-Kee away]:  Hey, what makes you think you're coming?
#
# Cri-Kee:  Chirp, Chirp.
#
# Mushu:  You're lucky?  Ho, ho, heh.  Do I look like a sucker to you?
#
# Cri-Kee:  Chirp. Chirp.
#
# Mushu:  Whach' you mean loser?  How 'bout I pop one of your antenna's off and
# throw it across the yard.  Then who's a loser, me or you?
#
# [Interlude]
#
# [Cut to Shan-Yu leading his army at a charge on horseback through a forest.
# He stops and motions stage right.  Hun Archer, Hun Strong Guy, Hun Long-Hair
# Guy dismount and walk into the forest.  They throw down two Imperial scouts
# before the rest of the army]
#
# Hun Long-Hair Guy:  Imperial scouts.
#
# [Shan Yu dismounts and walks towards the scouts]
#
# Scout #1:  Shan-Yu.
#
# [He crouches down in front of them]
#
# Shan-Yu [adjusting Scout #1's collar]:  Nice work, gentlemen.  You found the
# Hun army. [motioning to the soldiers on horseback.  The Hun army laughs]
#
# Scout #2:  The Emperor will stop you.
#
# Shan-Yu [grabs Scout #2 by the shirt collar and lifts him up to his face]:
# Stop me?  He invited me.  By building his wall, he challenged my strength.
# Well I'm here to play his game  [Shan-Yu throws Scout #2 to the ground and
# points his sword at Scout #1 as he gets up and runs] [calling out to the
# scouts] Go!  Tell your emperor to send his strongest armies.  [Quietly]  I'm
# ready.
#
# [The Imperial Scouts run off towards the palace]
#
# Shan-Yu [scratching his chin]:  How many men does it take to deliver a
# message.
#
# Archer Guy [drawing back his bow]:  One.
#
# [End Interlude]
#
# [Cut to Mulan on a hill outside of the camp.  Khan is sitting watching]
#
# Mulan:  Okay, okay, how 'bout this?  Ahem, [in her manly voice] excuse me,
# where do I sign in?  Hah, I see you have a sword.  I have one too.  They're
# very manly and tough [Mulan bites her lip as she mishandles pulling the sword
# out of the scabbard and it falls to the ground.  Khan rolls on his back in
# laughter.  Mulan throws her shoe and hits Khan in the head with it quieting
# Khan].  I'm working on it.  Who am I fooling?  It's going to take a miracle to
# get me into the army.
#
# [Mushu appears as a giant shadow being cast on a rock with flames on either
# side.  Mushu's real appearance remains out of sight]
#
# Mushu [in a Southern Baptist Preacher's voice]:  Did I hear someone ask for a
# miracle!?  Let me hear you say aye!
#
# Mulan [Running and hiding behind a rock]:  Ahhhhhh.
#
# Mushu:  That's close enough.
#
# Mulan [from behind a rock]:  Ghost.
#
# Mushu:  Get ready Mulan your serpentine salvation is at hand.  For I have
# been sent by your ancestors-- [notices Cri-Kee making a hand shadow of a
# dragon on the rock and stamps him down with his foot] to guide you through
# your masquerade.  [bending down to Cri-Kee]  C'mon, you're gonna stay you're
# gonna work. [returning to Mulan] Heed my word, 'cause if the army finds out
# that you are a girl, the penalty is death. [big flames shoot up from the
# rocks]
#
# Mulan:  Who are you?
#
# Mushu:  Who am I?  Who am I?  I am the guardian of lost souls. [Mulan smiles
# big in anticipation of seeing her guardian] I am the powerful, the
# pleasurable, the indestructible [coming out from the rocks to show his real
# size] Mushu! Oh hah, hah, pretty hot, huh? [Khan stomps on Mushu.  Mulan
# pushes Khan back]
#
# Mulan:  Ah, my ancestors sent a little lizard to help me?
#
# Mushu:  Hey, dragon, dragon,  not lizard.  I don't do that tongue thing [flips
# out his tongue to show Mulan what he means].
#
# Mulan:  You're uh...
#
# Mushu:  Intimidating?  Awe inspiring?
#
# Mulan [making a hand gesture to denote his smallness of size]: Tiny.
#
# Mushu [with a look of disappointment]:  Of course.  I'm travel size for your
# convenience.  If I was my real size, your cow here [patting Khan on the nose]
# would die of fright.  [Khan tries to bite Mushu]  [pointing to the ground
# speaking to Khan] Down Bessy.  My powers are beyond your mortal imagination.
# For instance, [leaning in and looking at Mulan's chest] my eyes can see
# straight through your armor.  [Mulan cover her bust with her left arm and
# slaps Mushu with the right]  Ow.  [angrily] All right, that's it!  Dishonor!
# Dishonor on your whole family.  [aside to Cri-Kee] Make a note of this
# [Cri-Kee grabs a leaf and a pen and starts writing].  [Loudly with gusto]
# Dishonor on you.  Dishonor on your cow.  Dis-
#
# Mulan [pleadingly while covering Mushu's mouth]:  Stop!  I'm sorry, I'm sorry
# [kneeling down in front of Mushu].  I'm just nervous.  I've never done this
# before.
#
# Mushu: Then you're gonna have to trust me.  And don't you slap me no more, we
# clear on that?  [Mulan nods emphatically].  All right.  Okey dokey, let's get
# this show on the road.  Cri-Kee, get the bags [Mushu starts walking to the
# camp].  [to Khan] Let's move it heifer.
#
# [Cut to Mulan at the camp's entrance]
#
# Mushu [hiding in Mulan's armor poking his head out from her back]:  Okay this
# is it, time to show 'em your man walk.  Shoulders back,  chest high, feet
# apart, head up [Mushu pulls Mulan's head back]  ...and strut 2, 3, break it
# down, 2, 3 and work it, [Mulan walks into the camp drawing the attention the
# men who see her.  Mulan walks into a tent and sees a man picking his nose and
# another man picking out dirt from between his toes with chopsticks] Beautiful
# isn't it?
#
# Mulan [making a face of disgust and continuing to walk]:  They're disgusting.
#
# Mushu:  No, they're men.  And you're going to have to act just like them, so
# pay attention.
#
# [Mulan stops and watches Yao, Ling, Chien-Po and Tattoo Soldier]
#
# Tattoo Soldier [showing the dragon tattoo on his chest and belly]:  Look, this
# tattoo will protect me from harm.
#
# [Yao thinks for a moment, then punches Tattoo Soldier in the stomach causing
# Ling to laugh.  Mulan watches in utter amazement.  Yao kisses his hand]
#
# Ling [laughing]:  I hope you can get your money back.
#
# Mulan:  I don't think I can do this.
#
# Mushu:  It's all attitude.  Be tough like this guy here [looking at Yao].
#
# [Mulan looks at Yao as he hocks up a loogie and spits]
#
# Yao [noticing Mulan watching him]:  What are you looking at?
#
# Mushu:  Punch him, it's how men say 'hello.'
#
# [Mulan looks at her fist, then punches Yao from behind on the shoulder.  The
# force causes Yao to run into Chien-Po]
#
# Chien-Po:  Oh Yao, you made a friend.
#
# Mushu:  Good, Now slap him on the behind, they like that.
#
# [Mulan slaps Yao on the behind]
#
# Yao:  Wu hoo hooooo.  [grabbing Mulan buy the collar]  I'm going to hit you so
# hard it'll make your ancestors dizzy.
#
# Chien-Po [Holding and picking up Yao]:  Yao, relax and chant with me.
# Yaaaaaaa Moouuuu Ahhhhhh Doooou Fuuuu Daaaaa.
#
# Yao:  Ya Mi Ah To Fu Da.
#
# Chien-Po:  Feel better?
#
# Yao [relaxed]:  Yeah. [Chien-Po places Yao back on the ground]  [to Mulan
# while walking away] Aaaaa, you ain't worth my time chicken boy.
#
# Mushu [loudly]:  Chicken boy!?  Say that to my face ya limp noodle!
#
# [Yao grabs Mulan by the collar cocking back his arm to punch.  Mulan ducks as
# Yao hits Ling standing behind her]
#
# Yao:  Oh, sorry Ling.  Hey!
#
# [Yao grabs Mulan's foot as she starts to crawl away.  Ling kicks Yao on the butt causing him to land on Chien-Po's stomach. Ling Jump
# attacks Mulan, but she ducks and he lands on Yao on top of Chien-Po]
#
# Ling:  You're dead.  [They fight on top of Chien-Po.  Mulan runs away.  Ling notices Mulan and then points toward her] Oh, there he goes.
#
# [Mulan runs into a tent and stops.  Yao, Ling, and Chien-Po (in that order) run through the tent.  Yao stops short as he is about to run into a
# soldier in a line for food.  He looks behind him with concerned eyes as Ling stops in time.  Chien-Po bumps into Ling causing the entire line
# of soldiers to fall forward and knock over the pot of congee and the cook behind it.  The men look to the back of the line and spy Mulan who
# has emerged from the tent.  They angrily start walking towards her.  Mulan has a look of horror on her face as if trouble is about to brew]
#
# Mulan:  Hey guys.
#
# [Chi Fu watches and then walks into the tent.  General Li and Li Shang are in the tent.]
#
# General Li [motioning with his pointer to a map of the region]:  The Huns have struck here, here and here.  I will take the main troops up to
# the Tung Shao Pass and stop Shan-Yu before he destroys this village.
#
# Chi Fu:  Excellent strategy, Sir.  I do love surprises, Ha ha, ha, ha.
#
# General Li:  You will stay here and train the new recruits.  When Chi Fu believes you're ready, you will join us...Captain. [General Li hands
# a sword to Shang]
#
# Shang:  Captain?
#
# Chi Fu:  Oh, this is an enormous responsibility, General.  Uh, perhaps a soldier with more experience--
#
# General Li:  Number one in his class, extensive knowledge of training techniques, [leaning back smugly stroking his chin] an impressive
# military lineage.  I believe Li Shang will do an excellent job.
#
# Shang [excitedly]:  Oh, I will.  I wont let you down.  This is, I mean, I...[somberly] yes sir.
#
# General Li [gets up and starts walking out of the tent]:  Very good then.  We'll toast China's victory at the Imperial City.  [to Chi Fu] I'll
# expect a full report in three weeks.
#
# Chi Fu [to Shang]:  And I wont leave anything out.  [exits through the tent]
#
# Shang [while tying his sword to his uniform]:  Captain Li Shang, Hmmm, leader of China's finest troops.  No, the greatest troops of all time.
# Heh, heh, heh, heh.  [Shang walks out of the tent to see the recruits fighting.  He stands stage left of Chi Fu and General Li.  Injured Recruit
# sees the General and salutes him as he falls to the ground.  General Li steps over Injured Recruit and mounts his horse]
#
# Chi Fu:  Most impressive.
#
# General Li:  Good luck Captain.  [The general and his mounted troops leave the camp]
#
# Shang [quietly, to himself]:  Good luck, Father.  [Shang looks at his troops and sighs]
#
# Chi Fu [smirking, with board and brush in hand]:  Day one.
#
# Shang [shouting]:  Soldiers!
#
# All Recruits [backing away revealing Mulan and pointing at her.  Mulan is crouching in the fetal position on the ground]:  He started it!
#
# [Shang approaches Mulan and looks down over her.  Mulan looks up, sees Shang over top of her and gets up quickly dusting herself off]
#
# Shang [to Mulan]:  I don't need anyone causing trouble in my camp!
#
# Mulan:  Sorry, [in her man voice] Uhh, I mean, sorry you had to see that.  [with her fist she taps Shang on the shoulder]  You know how it is
# when you get those, uh [pounding her chest] manly urges and you just have to kill something [slapping her hand], fix things, uh, cook
# outdoors.
#
# Shang:  What's your name?
#
# Mulan [stumbling]:  Ahh, I, uhhh, I, uh--
#
# Chi Fu [stepping into Mulan's face]:  Your commanding officer just asked you a question.
#
# Mulan:  Uhh, I've got a name.  Huh.  And it's a boys name too.
#
# Mushu [from the back of Mulan]:  Ling, How 'bout Ling?
#
# Mulan [to Mushu motioning with her head to Ling]:  His name's Ling.
#
# Shang:  I didn't ask for his name.  I asked for yours.
#
# Mushu:  Try, uh, ahh, Chu!
#
# Mulan:  Ah Chu.
#
# Shang:  Ah Chu?
#
# Mushu:  Gesundheit.  He He, I kill myself.
#
# Mulan [whispering over her shoulder]:  Mushu.
#
# Shang:  Mushu?
#
# Mulan:  No.
#
# Shang:  Then what is it!
#
# Mushu:  Ping! Ping was my best friend growing up!
#
# Mulan:  It's Ping.
#
# Shang:  Ping.
#
# Mushu:  Of course Ping DID steal my gir-[Mulan reaches back and grabs holds Mushu's mouth together]
#
# Mulan:  Yes, my name is Ping.
#
# Shang:  Let me see your conscription notice.  [Takes the notice from Mulan]  Fa Zhou, *the* Fa Zhou?
#
# Chi Fu:  I didn't know Fa Zhou had a son.
#
# Mulan:  Um, he...doesn't talk about me much.  [Mulan tries to hawk up a loogie and spit but the saliva just runs from her mouth.  The
# recruits laugh]
#
# Chi Fu:  I can see why, the boy's an absolute lunatic.
#
# Shang [to the recruits]: Okay gentlemen, thanks to your new friend Ping, you'll spend tonight picking up every single grain of rice.  And
# tomorrow, the real work begins.
#
# [All recruits growl at Mulan]
#
# Mushu [Popping out the front of Mulan's armor]:  You know, we have to work on your people skills.
#
# [Cut to Mulan sleeping in her tent.  Mushu winds up Cri-Kee's wings.  Cri-Kee rings like an alarm clock]
#
# Mushu: All right, rise and shine sleeping beauty.  [Mulan rises and blinks] C'mon [rapping on Mulan's head with each syllable] hup, hup,
# hup. [Mulan groans, lies back down and pulls the covers over her head.  Mushu pulls the covers off Mulan entirely]  Get your clothes on.
# Get ready.  Got breakfast for ya.  [Mushu jumps onto Mulan's knee with a bowl of porridge]  Look, you get porridge, and it's happy to see
# you.  [Mushu shows her the bowl with two eggs and bacon looking like a smiley face.  Cri-Kee pops up out from the bowl of porridge] Hey,
# get outta there, you gonna make people sick!  [Mushu uses chopsticks to push Cri-Kee out of the porridge]
#
# Mulan:  Am I late?
#
# Mushu [while feeding Mulan]:  No time to talk.  Now remember, it's your first day of training so listen to your teacher and no fighting.  Play
# nice with the other kids, unless of course one of the other kids wanna fight, then you have to kick the other kid's butt.
#
# Mulan [with her mouth full of food]:  But I don't wanna kick the other kid's butt.
#
# Mushu:  Don't talk with your mouth full.  Now let's see your war face [Mulan looks at him with wide eyes and chipmunk cheeks full of food].
# I think my bunny slippers just ran for cover.  C'mon scare me, girl!
#
# Mulan [swallows the food]:  Rrrrrrr!
#
# Mushu [rolling back into the half eaten bowl of porridge]:  Oh, that's my tough looking warrior.  That's what I'm talking about.  Now get out
# there and make me proud. [Mushu ties up Mulan's hair]
#
# [Khan whinnies and pokes his head into the tent]
#
# Mushu:  What do you mean the troops just left?
#
# Mulan [acting surprised]:  They what!? [Mulan hurriedly puts on her clothes and jumps out of the tent going off to join the other recruits]
#
# Mushu [running out from the tent calling after Mulan]:  Wait, you forgot your sword.  My little baby off to destroy people [sniffle].
#
# [Cut to the troops muddling around near Shang's tent]
#
# Chi Fu [enters stage left]:  Order people, order!
#
# Recruit #2:  I'd like a pan fried noodle.
#
# Chien-Po:  Oh, oh, sweet and pungent shrimp [Ling and others begin to laugh]
#
# Recruit #3:  Moo goo gai pan
#
# Chi Fu:  That's not funny.
#
# [Mulan comes running up to the group]
#
# Ling [noticing Mulan's arrival]:  Looks like our new friend slept in this morning.  [Mulan stops between Ling and Yao] [to Ping] Hellooo Ping,
# Are you hungry?
#
# Yao:  Yeah, 'cause I owe you a knuckle sandwich.  [grabs Mulan by the shirt collar drawing back his other arm.  Mulan hides her face with
# her hands.  Ling looks away, closes his eyes, and puts his fingers in his ears so that he wont hear anything]
#
# All Soldiers [in agreement with Yao]:  Yeah.
#
# Shang [loudly]:  Soldiers!  [The soldiers line up quicky.  Shang takes off his shirt and grabs a bow and quiver of arrows.  Mulan is duly
# impressed by Shang's physique] You will assemble swiftly and silently every morning. [Shang walks down the line of soldiers] Anyone who
# acts otherwise will answer to me.
#
# Yao:  Ooooo, tough guy.
#
# Shang [turning around with knocked arrow pointing towards Yao]:  Yao.  [All recruits take a step back leaving Yao one step forward.  Shang
# Points arrow skyward and shoots it into the top of a high pole]  Thank you for volunteering.  Retrieve the arrow.
#
# Yao [bows to Shang]:  I'll get that arrow pretty boy.  And I'll do it with my shirt on.  [Yao prepares to leap onto that pole]
#
# Shang:  One moment, you seem to be missing something.  [Chi Fu brings out two large bronze disks.  Shang takes out one disk and holds it
# high speaking to all the troops]  This represents discipline  [Shang hands the weight to Yao and the weight falls to the ground taking Yao's
# arm with it]  and this represents strength [Shang hands the other weight to Yao making him fall to the ground.  The troops laugh while
# Mulan looks concerned].  You need both to reach the arrow.
#
# [Yao climbs up the pole then slips down under the weight.  Ling, Chien-Po, and Mulan each take their turn and fall down.  Mulan rubs her
# behind as she walks away in front of Shang]
#
# Shang:  We've got a long way to go.
#
# [Song I'll Make a Man Out of You]
#
# [Shang throws staffs to the soldiers.  Yao intercepts Mulan's staff and trips her with it]
#
# Shang:
# Let's get down to business--
# to defeat the Huns.
#
# [Shang throws up two clay pots and breaks them apart with his staff.  The troops are highly impressed]
#
# Recruits [putting their staffs out at arms length, spoken]:  Hua
#
# Shang:
# Did they send me daughters
#  when I asked for sons?  [Ling puts a cricket down Mulan's back causing her to flail erratically]
# You're the saddest bunch
#  I ever met  [Most soldiers fall as Mulan moves uncontrollably]
# But you can bet
# before we're through  [Shang does a somersault in the air landing near Mulan.  He takes a pole in the stomach.  Shang stops Mulan and
# takes her staff.  He grabs her by the collar]
# Mister, I'll make a man
#  out of you
#
# [Shang steps on a lever throwing up 3 targets which he hits with 3 arrows from one bow]
# Tranquil as a forest
# [The recruits try and fail.  Mulan gets ready to fire when Mushu sticks a target on her arrow before she shoots.  Mulan looks at Mushu's in
# shock and pauses.  Shang looks disdainfully at Mulan as she cracks a huge smile]
# But on fire within
# [Shang balances a bucket of water on his head holding a staff.  The recruits fire stones at him which Shang deflect with the staff]
# Once you find your center
# You are sure to win
# [Mulan wobbles with the bucket of water on her head.  As the recruits throw stones at her the bucket tips over onto her head]
# You're a spineless, pale,
# pathetic lot
# And you haven't got a clue
# [Shang throws his hand down into a river and retrieves a fish.  Mulan throws her hand down into the river and retrieve's Yao's foot.  Mushu
# comes out of the water with a fish in hand to give to Mulan]
# Somehow I'll make a man
# out of you!
#
# Chien-Po [running through a field of fire arrows]:
# I'm never gonna catch
# my breath
#
# Yao [following Chien-Po, falls and gets hit in the butt with an arrow]:
# Say good-bye to those
# who knew me
#
# Ling [Banging his head on a stone slab]:
# Boy I was a fool in school
# for cutting gym
#
# [Shang practices martial arts with Mulan.  With a punch to the face he knocks her back into a tree]
#
# Mushu [from the tree acts as a boxing coach]:
# This guy's got 'em
# scared to death
#
# Mulan [Mushu pushes Mulan back out into the ring]:
# Hope he doesn't see
# right through me
#
# Chien-Po [stops as he's hopping across poles protruding from water causing Shang and the recruits to pile into him]:
# Now I really wish that I
# knew how to swim!
#
# Shang and Chorus:
# [Cannon fire misses the target in the middle of an open field. Ling kicks the support structure out from Mulan's cannon and it begins to fall.
# Mulan quickly grabs the cannon and it fires high and back towards the camp landing and exploding Chi Fu's tent]
# (Be a man)
# We must be swift as
# the coursing river
# (Be a man)
# With all the force
# of a great typhoon
# (Be a man)
# With all the strength
# of a raging fire
# [Picture of Shang looking over the camp from the hill not looking pleased]
# Mysterious as the
# dark side of the moon
#
# Shang [his troops laden with poles on their shoulders carrying bags of grain - one on each side.  They march up a mountain]:
# Time is racing toward us
# till the Huns arrive
# [Chi Fu points Shang's eyes back to a struggling Mulan who falls to the ground.  Cri-Kee and Mushu try to pick her up but hide when Shang
# comes up to her.  Shang picks up her pole with grain, puts it on top of his and returns to the troops. Mulan looks rejected]
# Heed my every order
# and you might survive
# [Shang hand the reigns of Khan to Mulan]
# You're unsuited for
# the rage of war
# So pack up, go home,
# you're through
# How could I make a man
# out of you?
#
# Shang and Chorus [Mulan takes the weights and tries to climb the pole again]:
# (Be a man)
# We must be swift as
# the coursing river
# [Mulan ties the weights together behind the pole and uses the cloth to help her shimmy up the pole]
# (Be a man)
# With all the force
# of a great typhoon
# [As the sun begins to rise the recruits come out of their tents to cheer on Mulan]
# (Be a man)
# With all the strength
# of a raging fire
# [As Shang comes out of his tent, the arrow he shot up onto the pole comes down to his feet.  He looks up and sees Mulan sitting on top of
# the pole]
# Mysterious as the
# dark side of the moon
#
# [order of events during the last repeat of the chorus:
# Troops hit all targets with arrows correctly.
# Mulan racing in front of Shang and the recruits with the pole and weights on her shoulders.
# Mulan kicking Shang in the face with a round house.  Shang looking pleased.
# Chien-Po doing acrobatics on the poles as the troops follow.
# Staffs being thrown to troops, Yao hands Mulan hers.
# Yao running through arrows.
# Yao grabs Mulan's staff and hands it to her.
# Troop staff practice #1.  (Hya)
# Ling breaking the block
# Troop staff Practice #2.  (Hya)
# Mulan holding up fish.
# Troop staff practice #3.
# Cannon fire hitting the Hun Target.
# Troop staff practice #4 - jumping in the air (Hya)]
# (Be a man)
# We must be swift as
# the coursing river
# (Be a man)
# With all the force
# of a great typhoon
# (Be a man)
# With all the strength
# of a raging fire
# Mysterious as the
# dark side of the moon
#
# [End Song]
#
# [Interlude]
#
# [Cut to Shan Yu sitting on top of a tree.  He cuts off the very top with his sword.  His falcon swoops buy and drops a doll.  Shan-Yu takes
# the doll, sniffs it, looks surprised, and drops down to the ground]
#
# Shan-Yu [tossing the doll to Hun Strong Man]:  What do you see?
#
# Hun Strong Man [feeling the doll]:  Black pine, from the high mountains.  [Long Hair Hun Man takes the doll from Hun Strong Man.  Bald
# Hun Man #1 takes a hair as it passes by him]
#
# Bald Hun Man #1:  White horse hair.  Imperial stallions.
#
# Long Hair Hun Man [sniffing the doll]:  Sulfur, from cannons.
#
# Shan-Yu:  This doll came from a village in the Tung Shao Pass, where the Imperial Army's waiting for us.
#
# Hun Archer:  We can avoid them easily.
#
# Shan-Yu [shaking his head]:  No, the quickest way to the Emperor is through that pass.  Besides, the little girl will be missing her doll.  We
# should return it to her.
#
# [End Interlude]
#
# [Cut to Mulan by the lake with Mushu, Khan, and Cri-Kee]
#
# Mushu:  Hey, oh, ah, no, this is not a good idea.  What if somebody sees you?
#
# Mulan [from behind the reeds]:  Just because I look like a man doesn't mean I have to smell like one.
#
# Mushu [holding a towel covering his eyes with his ears]:  So a couple of guys don't rinse out their socks, picky, picky, picky.  Well myself I
# kinda like that corn chip's smell.
#
# ...
# Hun Archer Man, Hun Strong Man and Hun Long-Hair Man.  Mulan and company are around the corner]
#
# Mulan [whispering]:  Okay, any questions?
#
# Yao [whispering]:  Does this dress make me look fat? [Mulan slaps him]  Ow.
#
# [Mulan, Yao, Ling and Chien-Po walk out smiling, giggling and trying to act lady-like including holding fans and waving fans]
#
# Hun Archer:  Who's there?
#
# Hun Bald Man #2 [putting down Hun Bald Man #1's sword]:  Concubines.
#
# Hun Bald Man #1:  Ugly concubines.
#
# Ling [waving daintily, speaking to Yao]:  Oh he's so cute.
#
# [Hun Bald Man #2 smiles and waves back.  Hun Bald Man #1 elbows Hun Bald Man #2.  A bitten apple falls out from beneath Ling's
# dress.  He pulls the dress out and turns so as not to expose the loss of figure]
#
# Shang [from around the corner putting his head down into his hand]:  Aww.
#
# [Shan-Yu's Falcon sees Shang and starts to squawk.  Mushu from above singes off all his feathers with his fire breathing]
#
# Mushu [to Cri-Kee sitting above him]:  Now that's what I call Mongolian Barbeque.  [Cri-Kee rolls on his back in laughter.  The stunned
# falcon doesn't do anything]
#
# [Hun Bald Man #2 picks up the apple and offers it back to Ling.  Ling, Yao, and Chien-Po pull out the fruit they were using to simulate a
# woman's chest.  Chien-Po takes his watermelons and smashes them on the heads of Hun Bald Man #1 and #2.  He then smashes their two
# heads together and they fall to the ground.  Ling pushes the apple into Hun Long-Hair man's mouth and kicks him in the stomach causing
# Hun Long-Hair Man to stoop over on the ground.  Ling uses his head to crack Hun Long-Hair Man's back.  Hun Strong Guy lunges his fist
# at Yao and misses, he misses with the other.  Yao grabs the outstretched arm and flips him over onto his head. Mulan kicks away Hun
# Archer Man's bow and knocked arrow, avoids his strike by turning her back to Hun Archer.  She follows with a left elbow to the stomach
# followed by a left upper cut knocking Hun Archer to the ground.  She sits on his back and uses the bow to pull his head back]
#
# Mulan [calling out]:  Shang, GO!
#
# [Shang runs out from behind the corner, charges through the door and runs up the stairs]
#
# [Cut to Shan-Yu and the Emperor on the balcony]
#
# Shan-Yu:  I tire of your arrogance old man.  [yelling and putting his sword at the emperor's
# throat] Bow to me!
#
# Emperor:  No matter how the wind howls, the mountain cannot bow to it.
#
# Shan-Yu:  Then you will kneel in pieces. [Shan-Yu draws back his sword to strike the Emperor]
#
# [Shang runs up in time to block the striking blow of Shan-Yu with his sword.  Shang swipes with
# his sword.  Shan-Yu grabs Shang's arm and throws him towards the edge.  Shang grabs onto a column
# and he flies over the edge and uses the momentum to swing back and kick Shan-Yu.  Shan-Yu falls
# to the ground, Shang on top of him. Shang punches Shan-Yu.  Shan-Yu grabs Shang and rolls over
# forcing Shang to be on his back underneath him.  Shang uses his knee to hit Shan-Yu from behind
# as he uses his hand to hit him in the head.  Shang forces Shan-Yu onto his back and grabs his arm
# pulling it behind Shan-Yu's back.  Mulan, Chien-Po, Yao and Ling enter the balcony from the
# stairs]
#
# Mulan:  Chien-Po, get the Emperor.
#
# Chien-Po [standing in front of the Emperor and bowing]:  Sorry, your Majesty.
#
# [Chien-Po lifts up the Emperor and runs over to Mulan who is by a rope attached to a column in
# the balcony.  Chien-Po uses his sash as a pulley and rides down the rope to the ground.  Shan Yu
# watches the Emperor leave]
#
# Shan-Yu:  No!
#
#  [Shan-Yu uses his free arm to elbow Shang in the face.  Shan-Yu gets up and head-butts Shang and
# throws him to the ground.  Shang lies limp.  Mulan watches Shang fall then she looks over the
# edge at Ling and Yao now on the ground.  Chien-Po runs off the screen out of sight]
#
# Yao [motioning her to follow]:  Come on!
#
# [Mulan looks down at Shang with a worried look.  Shan-Yu begins to approach Mulan and the rope.
# Mulan looks at the approaching Shan-Yu and then down to spy his sword. Thinking quickly, Mulan grabs
# Shan-Yu's sword and cuts the taught rope.  Shan-Yu reaches the edge and grabs for the falling rope unsuccessfully as Mulan leaves the
# sword embedded in the column and runs to Shang's position.  The crowd cheers]
#
# Shan-Yu:  No!  [He looks down at the crowd and realizes he cannot find the Emperor among the
# throng of people]  Yrraaaaahhhh!
#
# [Shan-Yu turns and looks back and sees Mulan looking concerned, holding up Shang.  Shan-Yu pulls
# out his sword lodged in the column and heads toward them.  As Shang sees Shan-Yu approaching, he
# puts his arm in front of Mulan to ask her to leave and takes out his knife.  Mulan slides away.
# Shan-Yu comes up to Shang, knocks away his knife, slaps him in the face, and grabs Shang by the
# shirt collar]
#
# Shan-Yu [in Shang's face]:  You, you took away my victory.
#
# [Mulan's shoe hits Shan-Yu in the head and bounces back to her feet.  Shan-Yu turns toward Mulan]
#
# Mulan:  No!  I did!  [Mulan pulls her hair back to look like she did when she was a soldier]
#
# Shan-Yu [looking at Mulan]:  The soldier from the mountains.
#
# [Shan-Yu drops Shang and starts after Mulan as she puts on her shoe and runs down the stairs and
# through the doors to the balcony.  She closes the door with the latch falling in place right
# behind her.  She leans against the doors.  Shan-Yu punches a hole in one door with his fist.
# Mulan runs away from the doors down the corridor.  Mushu riding Shan-Yu's falcon like a horse
# catches up with Mulan]
#
# Mushu:  So what's the plan?
#
# Mulan:  Ummmm.
#
# Mushu:  You don't have a plan?!
#
# Mulan:  Hey, I'm making this up as I...[looks out a window and spies the firework tower] go.
# Mushu--
#
# Mushu:  I'm way ahead of you sister.  C'mon Cri-Kee. [Mushu and Cri-Kee jump onto a kite and use
# the wings to soar over toward the fireworks tower]
#
# [Cut to Shan-Yu.  Shan-Yu breaks through the doors and catches up to Mulan swinging his sword
# wildly knocking down a support column with every swipe.  Mulan runs and ducks his every blow.
# Mulan climbs up a column to get out of Shan-Yu's reach.  Shan-Yu slices the base of the column
# causing it to fall and break through the outer wall.  Mulan screams as the beam falls and comes
# to a stop.  Mulan gets up on the beam and jumps up to catch onto the awning.  She looks off to
# her right and spies Mushu arriving at the fireworks tower]
#
# [Zoom in on the fireworks tower.  Mushu lands near Barry Cook and Tony Bancroft (the firework
# lighters) on the edge of the tower]
#
# Mushu:  Citizens, I need firepower.
#
# Barry Cook:  Who are you?
#
# Mushu [Mushu (using the wings from the kite) and Cri-Kee with wings spread like batman]:  You're
# worst nightmare.
#
# [Barry Cook and Tony Bancroft jump off the tower and plunge toward the ground]
#
# [Cut to Mulan. She pulls herself onto the roof and climbs up to the crest]
#
# Man in Crowd #1:  On the roof.
#
# Man in Crowd #2:  Look!
#
# [Mulan lines up where she is standing with the fireworks tower across the way.  Shan-Yu breaks
# through the roof behind Mulan surprising her.  Mulan backs away and searches for something on her
# person to help her against Shan-Yu.  She finds a her fan, takes it out, and opens it]
#
# Shan-Yu:  It looks like you're out of ideas.
#
# [Shan-Yu lunges with his sword.  Mulan dodges to her right and lets the sword go right through
# the fan.  She closes the fan back up on the sword and twists the fan with both hands so that
# Shan-Yu loses his grip.  The sword flies toward Mulan and she catches it by the handle slipping
# off the fan with her sword movement]
#
# Mulan:  Not quite.  [calling out]  Ready, Mushu?
#
# Mushu [behind Shan-Yu tied to a large rocket firework]:  I am ready, baby. [He blows fire onto a
# stick and hands the stick to Cri-Kee who's standing on the firework]  Light me!  [Cri-Kee lights
# the fuse]
#
# [Shan-Yu approaches Mulan.  Using the sword as a lever, Mulan lunges at Shan-Yu kicking him in
# the face then sweep kicks him and he falls to the ground.  Mulan picks the sword back up and
# stabs it into Shan-Yu's cape.  The rocket on Mushu ignites and hurls him toward Shan-Yu.  Mulan
# lies flat down on the left side of the roof.  Shan-Yu sees the approaching rocket and tries to
# run, but the sword has him pinned to the spot.  The rocket hits Shan-Yu square in the belly
# propelling him toward the firework tower.  Mushu grabbed onto the sword as he went by letting the
# rocket do the work.  Cri-Kee hangs on to Mushu's tail.  Mulan jumps back up to the crest of the
# roof and runs away from the fireworks tower grabbing Mushu and Cri-Kee off the sword]
#
# Mulan [while running]:  Get off the roof, get off the roof, get off the roof.
#
# [The rocket rides Shan-Yu into the fireworks tower causing masses of explosions and fireworks to
# fly everywhere.  Mulan jumps near the edge of the roof.  Propelled by the explosion, she grabs
# onto a lantern that is hanging on a taught rope and starts to slide down.  She looks down and
# releases her grip so that she lands on the back of Shang causing the two of them to fall to the
# ground.  Shan-Yu's sword follows and lands on the ground near by]
#
# Mushu [landing and flying backwards on his butt a couple of times pointing at the fireworks]:  Ah
# ha ha ha ha.  [Mushu's catches Cri-Kee with antenna on fire as Cri-Kee falls toward him] [to
# Cri-Kee]  You are a lucky bug. [Mushu pinches out the fire on Cri-Kee's antenna]
#
# Chi Fu [walking down the stairs in a tattered outfit and slightly burned]:  That was a deliberate
# attempt on my life.  Where is she?  Now she's done it.  What a mess.  [Shang and troops push
# Mulan behind them to protect her] [to Shang] Stand aside, that creature's not worth protecting.
#
# Shang [in Chi Fu's face]:  She's a hero.
#
# Chi Fu:  'Tis a woman.  She will never be worth anything.
#
# Shang [grabbing Chi Fu by the shirt collar]:  Listen, you pompous--
#
# Emperor [walking down the steps]:  That is enough!
#
# Shang:  Your Majesty, I can explain.
#
# [The Emperor motions for Shang to stand aside.  Shang and his men part giving the Emperor a clear
# path to Mulan.  Mulan steps forward and bows before the Emperor.  Chi Fu with a sinister look
# waits to write down the words of the Emperor]
#
# Emperor:  I've heard a great deal about you, Fa Mulan.  You stole your father's armor, ran away
# from home, impersonated a soldier, deceived your commanding officer, dishonored the Chinese army,
# destroyed my palace, AND...you have saved us all.  [the Emperor bows to Mulan]
#
# [Chi Fu looks at the Emperor actions astonishingly then immediately falls prostrate before Mulan.
# Shang, Yao, Ling, and Chien-Po follow suit.  Mulan looks up then turns around hardly believing
# what she sees as the entire Chinese population within the palace grounds fall prostrate on the
# ground in a wave like pattern, bowing to her.  Khan bows with Mushu and Cri-Kee on his back]
#
# Mushu:  My little baby's all grown up and savin' China.  [to Cri-Kee] You have a tissue?
#
# Emperor:  Chi Fu,
#
# Chi Fu:  Your Excellency?
#
# Emperor:  See to it that this woman is made a member of my council.
#
# Chi Fu [muttering to himself]:  A member of your coun...[realizing what the Emperor has said]
# what? [stutters] But there are no council positions open, your Majesty.
#
# Emperor [to Mulan]:  Very well then, you can have his job [pointing out Chi Fu].
#
# Chi Fu [wobbling to and fro]:  What?...My...[faints]
#
# Mulan [smiles big then turns to the Emperor and bows]:  With all due respect, your Excellency.  I
# have been away from home long enough.
#
# Emperor [taking off his pendant]:  Then take this, so your family will know what you have done
# for me.  And this [handing her the sword of Shan-Yu]  so the world will know what you have done
# for China.
#
# [Mulan takes the gifts and hugs the Emperor]
#
# Yao:  Is she allowed to do that?  [Shang, Ling, and Chien-Po shrug]
#
# [Mulan walks away from the Emperor and is embraced by Yao and Ling.  Chien-Po comes up and lifts
# all three of them off the ground in a big bear hug.  Chien-Po lets them all back to the ground
# again.  Mulan walks toward Shang and stops in front of him.  As Shang begins to speak Mulan
# starts to smile anticipating something good]
#
# Shang:  Um...[Mulan grins]  You... [Mulan smiles] You fight good.
#
# Mulan [smile turning into disappointment]:  Oh, thank you.  [Mulan walks toward Khan]
#
# Shang: [turning toward Mulan and grunts with disappointment in himself]:  Hmm.
#
# [Mulan mounts Khan]
#
# Mulan:  Khan, let's go home.
#
# [Khan jumps down the steps and gallops on the flat parts of the stair case back down to ground
# level.  The crowd cheers al the while.  The Emperor approaches Shang and clears his throat]
#
# Emperor [to Shang]:  The flower that blooms in adversity is the most rare and beautiful of all.
#
# Shang [dumbfounded]:  Sir?
#
# Emperor:  You don't meet a girl like that ev'ry dynasty.  [The emperor puts on his hat and walks
# back up the steps to his palace]
#
# [Cut to Mulan's home, her father is sitting beneath the blossom tree.   A blossom falls and lands
# on his leg.  Mulan appears at the threshold and moves toward her father.  Fa Zhou sees her
# approaching and starts to stand]
#
# Fa Zhou:  Mulan.
#
# [Mulan quickly moves in front of her father and kneels causing him to sit back down]
#
# Mulan:  Father, I brought you the sword of Shan-Yu [hands the sword to Fa Zhou] and the crest of
# the Emperor [hands the crest to Fa Zhou].  [with head bowed] They're gifts to honor the Fa
# Family.
#
# [Fa Zhou takes the gifts and throws them down to the ground beside him to the surprise of Mulan.
# He bends down and holds her arms outstretched]
#
# Fa Zhou:  The greatest gift and honor, is having you for a daughter.  [Fa Zhou wipes away Mulan's
# tear then hugs Mulan]  I've missed you so.
#
# Mulan:  I've missed you too Baba.
#
# [Fa li and Grandma Fa watch from the doorway]
#
# Fa Li [sighing]:  Ahhhhh
#
# Grandma Fa:  Great, she brings home a sword.  If you ask me she should have brought home a
# ma--[leaving her mouth open when she sees Shang]
#
# Shang [just arriving]:  Excuse me, does Fa Mulan live here?
#
# [Grandma Fa's mouth stays open as she and Fa Li point toward Mulan's position.  Shang walks
# toward Mulan and Fa Zhou]
#
# Grandma Fa:  Woo, sign me up for the next war.
#
# [Shang approaches seeing Fa Zhou]
#
# Shang [bows before Fa Zhou and speaks confidently]:  Honorable Fa Zhou I--Mulan [Mulan steps up.
# Shang sees her and speaks insecurely] Uh...Uh...You forgot your helmet.  Ah but well, actually
# it's your helmet, isn't it?...[handing the helmet toward Fa Zhou] I mean...
#
# [Fa Zhou motions with his head for Mulan to take over.  Mulan holds the helmet Shang offers]
#
# Mulan:  Would you like to stay for dinner?
#
# Grandma Fa [speaking from stage right]:  Would you like to stay forever? [Mulan shakes her head with a
# smile at Grandma Fa's statement]
#
# Shang [reassuredly to Mulan]:  Dinner would be great.
#
# [Cut to First Ancestor grinning happily looking at the scene through the temple window.  He watches Mulan hand the helmet back to Fa
# Zhou.  Mushu climbs up to the window sill by First Ancestor's his head]
#
# Mushu [tugging on First Ancestor's ear]:  C'mon, who did a good job?  C'mon, tell me who did a
# good job.
#
# First Ancestor [hesitantly]:  Oh, all right.  You can be a guardian again.
#
# Mushu: Yeeeeeahhhhhhh.  [Mushu runs to his post and Cri-Kee bangs the gong awakening all the
# ancestors]
#
# Mushu:  Take it Cri-Kee.
#
# [Song:  True to Your Heart -- No characters sing in the song]
#
# [Ancestor 1 does a dance from Pulp Fiction while Ancestor 3 does the Hand Jive]
#
# Ancestor 3 [spoken to Ancestor 1]:  She get's it from my side of the family.
#
# Mushu [spoken while swinging on a chain]:  Call out for egg rolls!
#
# First Ancestor [disgusted]:  Guardians.
#
# [Mushu lands on the steps outside the temple.  Mulan walks up to him and rests besides him on the
# steps]
#
# Mulan:  Thanks, Mushu [kisses Mushu on the forehead].
#
# Little Brother:  Bark, bark, bark, bark, bark, bark, bark
#
# [Little brother runs up the steps and into the temple with the bag of grain tied to him.  The
# chickens follow him in]
#
# First Ancestor [annoyed]:  Mushu!
#
# [Roll Credits]
#
# [The End]

# %% [markdown]
# ## Read in some project data from a collection of text files
# You have a file directory with some text files probably near your Python script.
#
#  From the "for loop" in the next cell, we can then write code to process information about each file separately.

# %%
# Remember, we defined cwd as our current working directory holding this file.
# list directories:
os.listdir(cwd)
# Out:
# ['nlp-orientation.py',
#  '.DS_Store',
#  'trinity_wordnet_exploration.ipynb',
#  '.ipynb_checkpoints',
#  'venv',
#  'nlp-analysis.ipynb',
#  'sample.txt']

# %%
coll = os.path.join(cwd, 'hughes-txt')
os.listdir(coll)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 2
#       1 coll = os.path.join(cwd, 'hughes-txt')
# ----> 2 os.listdir(coll)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/trinityrose/Documents/github/digit210/python-nlp/hughes-txt'

# %% [markdown]
# ## Processing the directory as one corpus
# What if we want to create an NLTK corpus of these texts and process them as one unit? See the [NLTK book chapter 2 section 1.9](https://www.nltk.org/book/ch02.html#loading-your-own-corpus)

# %%
for file in os.listdir(coll):
   if file.endswith(".txt"):
        filepath = f"{coll}/{file}"
        print(filepath)

# %%
from nltk.corpus import PlaintextCorpusReader
corpus_root = 'hughes-txt'
corpus = PlaintextCorpusReader(corpus_root, '.*')
corpus.fileids()
# Check on one file in the collection
# corpus.words('breakfast.txt')

# %% [markdown]
# ##

# %% [markdown]
# ## For Wednesday April 8: YOUR TURN!
#
# Continue applying what you're learning from this notebook. Take some project files, read and tokenize them, and explore them for Wordnet data.
# What do you need to do to process texts in your directory with NLTK tools?
# You will need to:
# * Turn your text(s) into a list of tokens!
# * Then you can process those tokens with NLTK
#
# ### Your assignment is...
# Split up your texts into a list of tokens, and do some new NLTK processing of them.
# Look Stuff Up: See if you can use NLTK to output a **set** of a certain kind of word: could be...
# * **part of speech** (find out how NLTK can retrieve pos (part-of-speech) information). Retrieve pos information!
# * Pull a **set** of all the tokens that share a specific part of speech. Make a set() because it removes multiple instances: (it's the same as taking distinct-values() in XPath. (Want all the adjectives? All the verbs? etc.)
#
# * Do something interesting with NTLK over that set of words. Try out wordnet synsets, or experiment with frequency distributions, or something else that looks nifty in NLTK.
# * Retrieve info on a limited set of words of your choice (tagged for POS probably, but you can explore!)
# Output ambiguity data on each word by finding the len() of its synsets.

# %%
print("number of tokens:", len(tokenList))

# %%
tags = nltk.pos_tag(tokenList)

print("first 20 tagged words:")
print(tags[:20])
