# %% [markdown]
# ## Words to Network Data
#
# Now that we know some ways to pull an interesting selection of words, let's think about them like a network. Network analysis involves looking at how things relate to each other based on shared properties.
#
# In this notebook, we will address a simple research question: Which **files** (or **chapters**, or **scenes**, or **authors**, or **titles**) share each others' top 5 or 10 **verbs** (or **adjectives**, or **nouns**, or **WordNet synsets**, etc)?
#
# We will try exploring this as a network of data and import it into network visualization software.
#
# ### Installs in your Terminal
# * If you did not do this in the previous notebook: `pip install spacy`
# * We need the **pandas** library to make dataframes: `pip install pandas`
#
# <pre>
#     ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣤⣶⣿⣷⣦⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⣿⣿⣿⣿⣿⡇⠀⠀⠀⠀⠀⠀⠀⣰⣿⣿⣿⣦⡀
# ⠀⠀⠀⠀⢀⠄⠀⠀⠀⠀⢈⣿⣿⣿⠟⠛⠁⠀⠀⠀⠀⠀⠀⠐⢿⣿⣿⣿⣿⣷
# ⠀⠀⢀⡔⠁⠀⠀⠀⢀⣴⡿⠃⠈⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⢿⣿⠟⠁
# ⠀⣠⡟⠀⠀⠀⠀⣰⣿⣿⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⢠⣿⠁⠀⠀⠀⢰⣿⣿⡏⠀⠀⠀⢀⣤⣤⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⣾⣿⠀⠀⠀⠀⢸⣿⣿⡇⠀⠀⢠⣿⣿⣿⣿⠀⠀⠀⠀⣰⣾⣶⣆⠀⠀⠀⠀⡄
# ⣿⣿⡀⠀⠀⠀⢸⣿⣿⣧⠀⠀⢸⣿⣿⡿⠃⠀⠀⠀⠀⢿⣿⣿⣿⡆⠀⠀⢸⣧
# ⢿⣿⣧⠀⠀⠀⢸⣿⣿⣿⣦⡀⠀⠉⠉⠀⠀⠀⠀⠀⠀⠈⠻⣿⠿⠁⠀⢠⣿⣿
# ⢸⣿⣿⣷⣄⠀⣿⣿⣿⣿⣿⣿⣷⣦⣄⠀⠲⣶⣶⣶⠀⠀⠀⠀⠀⣀⣴⣿⣿⣿
# ⢰⣿⣿⣿⣿⣷⣽⣿⣿⣿⣿⣿⣿⣿⣿⣦⡄⣬⣅⣀⣠⣾⣿⣿⣿⣿⣿⣿⣿⡟
# ⠈⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⣤⣤⣾⣿⣿⣿⣿⣿⣿⣿⣿⣿⠇
# ⠀⠹⣿⣿⣿⣿⣿⣿⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡏⠀⠈⣿⣿⣿⣿⣿⣿⣿⡿⠀
# ⠀⠀⠻⣿⣿⣿⣿⣿⡎⢿⣿⣿⣿⣿⣿⣿⣿⣿⡇⠀⠀⣿⣿⣿⣿⣿⣿⣿⠃⠀
# ⠀⠀⠀⠙⠻⠿⣿⣿⠗⠀⢻⣿⣿⣿⣿⣿⣿⣿⡇⠀⢸⣿⣿⣿⣿⣿⡿⠃⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠹⣿⣿⣿⣿⣿⣿⣿⠀⢸⣿⣿⣿⡿⠟⠁⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠛⠿⢿⣿⣿⡿⠇⠀⠈⠉⠁⠀⠀⠀⠀⠀⠀
# </pre>
#
#
#
# Image credit: <https://emojicombos.com/panda-ascii-art>
#
# ### Language Models
# Like NLTK's collections that we downloaded, [spaCy has trained language models](https://spacy.io/usage/models) to download. You download these in your Python script after you import spacy, and after you download once, you don't need to do it again (so you can comment out the download line). We're going to try the medium and large models in English. (It's good to know that both spaCy and NLTK have resources for NLP on other languages, too!)

# %%
import spacy
import os
# Out:
# /Users/trinityrose/Documents/github/digit210/python-nlp/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# ### Downloading language models
# To work with spaCy's pre-trained language models, you need to download them to you virtual environment. There are:
# * en_core_web_sm (smallest--not as much info as the others)
# * **en_core_web_md** (Pretty good date here, size: 34 MB )
# * **en_core_web_lg** (Lots of data here, size: 400 MB.)
# Note that the LARGEST  one will have the most data and probably be the most reliable.

# %%
# CAN YOU SKIP THIS???
# After you download a model into your virtual environment for the first time, you can comment out the download line.
# spaCy's medium and large models will give us the best results for NLP tagging.
# nlp = spacy.cli.download("en_core_web_sm")
# nlp = spacy.cli.download("en_core_web_md")
# changed this 
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# ### Load the model
# Now we redefine the nlp variable to LOAD the model you downloaded.

# %%
nlp = spacy.load("en_core_web_lg")

# %% [markdown]
# ## File Collection
# You can set this to read a collection of text files that you've prepped for natural language processing.
# For this notebook, we'll work with just the dialogue text we pulled from the One Piece project.
# The text is organized as one file for each volume of OnePiece, so we can maybe explore how much the dialogue is relying on certain words, and how it might be changing over the volumes.
#
# We're going to get volume information from OnePiece's filenames (which look like this: `vol-9.txt'. We can use the `os` library to help us isolate the filename from the file extension. Let's try that so we can simplify our references to the volumes when we output our data.

# %%
collPath = 'atTXT'
for file in os.listdir(collPath):
    if file.endswith(".txt"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        print(name)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            lengthFile = len(readFile)
            print(lengthFile)
# We're just printing out the filepaths and lengths of the files as a "smoke test" to see if we're reading the files.
# Out:
# ATE11
# 12897
# ATE10
# 11434
# ATE12
# 8106
# ATE13
# 14038
# ATE17
# 12402
# ATE16
# 11513
# ATE14
# 12161
# ATE15
# 11029
# ATE1
# 13899
# ATE3
# 11505
# ATE2
# 13910
# ATE6
# 12950
# ATE7
# 13061
# ATE5
# 12820
# ATE4
# 10000
# ATE9
# 14545
# ATE8
# 13590
# ATE18
# 11511
# ATE24
# 13519
# ATE25
# 13651
# ATE19
# 14177
# ATE26
# 12495
# ATE22
# 13502
# ATE23
# 11169
# ATE21
# 11371
# ATE20
# 14896

# %% [markdown]
# ## Collect some words with a little help from spaCy
# Let's build this up to go file by file. We'll start by surveying what we have...(Ultimately we want to collect the top 5 or 10 most frequently repeating words of a kind.)

# %%
# SURVEY IT ALL! :-) (Yeah, lots of data...)
for file in os.listdir(collPath):
    if file.endswith(".txt"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        print(name)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            spacyRead = nlp(readFile)
            for token in spacyRead:
                print(token.text, "---->", token.pos_, ":::::", token.lemma_)
# Out:
# ATE11
# [ ----> X ::::: [
# The ----> DET ::::: the
# episode ----> NOUN ::::: episode
# begins ----> VERB ::::: begin
# with ----> ADP ::::: with
# Finn ----> PROPN ::::: Finn
# and ----> CCONJ ::::: and
# Jake ----> PROPN ::::: Jake
# walking ----> VERB ::::: walk
# through ----> ADP ::::: through
# the ----> DET ::::: the
# Grass ----> PROPN ::::: Grass
# Lands ----> PROPN ::::: Lands
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Hey ----> INTJ ::::: hey
# , ----> PUNCT ::::: ,
# Jake ----> PROPN ::::: Jake
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# Yeah ----> INTJ ::::: yeah
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# ever ----> ADV ::::: ever
# wonder ----> VERB ::::: wonder
# what ----> PRON ::::: what
# a ----> DET ::::: a
# demon ----> NOUN ::::: demon
# 's ----> PART ::::: 's
# heart ----> NOUN ::::: heart
# looks ----> VERB ::::: look
# like ----> ADP ::::: like
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# Of ----> ADV ::::: of
# course ----> ADV ::::: course
# , ----> PUNCT ::::: ,
# dude ----> NOUN ::::: dude
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# ever ----> ADV ::::: ever
# wonder ----> VERB ::::: wonder
# what ----> PRON ::::: what
# a ----> DET ::::: a
# demon ----> NOUN ::::: demon
# 's ----> PART ::::: 's
# heart ----> NOUN ::::: heart
# tastes ----> VERB ::::: taste
# like ----> ADP ::::: like
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Reaper ----> PROPN ::::: Reaper
# : ----> PUNCT ::::: :
# Hey ----> INTJ ::::: hey
# , ----> PUNCT ::::: ,
# kid ----> NOUN ::::: kid
# ... ----> PUNCT ::::: ...
# You ----> PRON ::::: you
# want ----> VERB ::::: want
# some ----> DET ::::: some
# magic ----> ADJ ::::: magic
# powers ----> NOUN ::::: power
# ... ----> PUNCT ::::: ...
# ? ----> PUNCT ::::: ?
# Magic ----> NOUN ::::: magic
# powers ----> NOUN ::::: power
# for ----> ADP ::::: for
# absolutely ----> ADV ::::: absolutely
# free ----> ADJ ::::: free
# ... ----> PUNCT ::::: ...
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Heck ----> INTJ ::::: heck
# yeah ----> INTJ ::::: yeah
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# To ----> ADP ::::: to
# Finn ----> PROPN ::::: Finn
# ] ----> PUNCT ::::: ]
# Wait ----> VERB ::::: wait
# ! ----> PUNCT ::::: !
# Let ----> VERB ::::: let
# 's ----> PRON ::::: us
# not ----> PART ::::: not
# be ----> AUX ::::: be
# too ----> ADV ::::: too
# rash ----> ADJ ::::: rash
# ! ----> PUNCT ::::: !
# Just ----> ADV ::::: just
# look ----> VERB ::::: look
# at ----> ADP ::::: at
# this ----> DET ::::: this
# guy ----> NOUN ::::: guy
# ! ----> PUNCT ::::: !
# [ ----> X ::::: [
# The ----> DET ::::: the
# reaper ----> NOUN ::::: reaper
# chuckles ----> VERB ::::: chuckle
# menacingly ----> ADV ::::: menacingly
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
# Check ----> VERB ::::: check
# out ----> ADP ::::: out
# the ----> DET ::::: the
# sunken ----> ADJ ::::: sunken
# , ----> PUNCT ::::: ,
# lifeless ----> ADJ ::::: lifeless
# eyes ----> NOUN ::::: eye
# ... ----> PUNCT ::::: ...
# The ----> DET ::::: the
# foul ----> ADJ ::::: foul
# stench ----> NOUN ::::: stench
# of ----> ADP ::::: of
# decay ----> NOUN ::::: decay
# ... ----> PUNCT ::::: ...
# You ----> PRON ::::: you
# know ----> VERB ::::: know
# what ----> PRON ::::: what
# that ----> PRON ::::: that
# means ----> VERB ::::: mean
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Means ----> VERB ::::: mean
# he ----> PRON ::::: he
# 's ----> AUX ::::: be
# evil ----> ADJ ::::: evil
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# guess ----> VERB ::::: guess
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# Well ----> INTJ ::::: well
# , ----> PUNCT ::::: ,
# evil ----> ADJ ::::: evil
# , ----> PUNCT ::::: ,
# sure ----> ADJ ::::: sure
# ... ----> PUNCT ::::: ...
# but ----> CCONJ ::::: but
# mostly ----> ADV ::::: mostly
# , ----> PUNCT ::::: ,
# he ----> PRON ::::: he
# 's ----> AUX ::::: be
# unattractive ----> ADJ ::::: unattractive
# , ----> PUNCT ::::: ,
# and ----> CCONJ ::::: and
# unattractive ----> ADJ ::::: unattractive
# people ----> NOUN ::::: people
# are ----> AUX ::::: be
# desperate ----> ADJ ::::: desperate
# . ----> PUNCT ::::: .
# You ----> PRON ::::: you
# should ----> AUX ::::: should
# haggle ----> VERB ::::: haggle
# with ----> ADP ::::: with
# him ----> PRON ::::: he
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# To ----> ADP ::::: to
# Reaper ----> PROPN ::::: Reaper
# ] ----> X ::::: ]
# Hey ----> INTJ ::::: hey
# ! ----> PUNCT ::::: !
# I ----> PRON ::::: I
# want ----> VERB ::::: want
# more ----> ADJ ::::: more
# than ----> ADP ::::: than
# just ----> ADV ::::: just
# free ----> ADJ ::::: free
# powers ----> NOUN ::::: power
# ! ----> PUNCT ::::: !
# What ----> PRON ::::: what
# else ----> ADV ::::: else
# ya ----> PRON ::::: ya
# got ----> VERB ::::: get
# ? ----> PUNCT ::::: ?
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Reaper ----> PROPN ::::: Reaper
# : ----> PUNCT ::::: :
# Alright ----> INTJ ::::: alright
# ... ----> PUNCT ::::: ...
# Free ----> ADJ ::::: free
# magical ----> ADJ ::::: magical
# powers ----> NOUN ::::: power
# and ----> CCONJ ::::: and
# ... ----> PUNCT ::::: ...
# [ ----> X ::::: [
# Pulling ----> VERB ::::: pull
# left ----> ADJ ::::: left
# arm ----> NOUN ::::: arm
# off ----> ADP ::::: off
# ] ----> PUNCT ::::: ]
# Eh ----> INTJ ::::: eh
# ! ----> PUNCT ::::: !
# And ----> CCONJ ::::: and
# this ----> DET ::::: this
# keychain ----> NOUN ::::: keychain
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Jumping ----> VERB ::::: jump
# excitedly ----> ADV ::::: excitedly
# ] ----> PUNCT ::::: ]
# OH ----> INTJ ::::: oh
# ! ----> PUNCT ::::: !
# OH ----> INTJ ::::: oh
# ! ----> PUNCT ::::: !
# OH ----> PROPN ::::: OH
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Whispering ----> NOUN ::::: whispering
# ] ----> PUNCT ::::: ]
# Play ----> VERB ::::: play
# it ----> PRON ::::: it
# cool ----> ADJ ::::: cool
# , ----> PUNCT ::::: ,
# Finn ----> PROPN ::::: Finn
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Right ----> INTJ ::::: right
# . ----> PUNCT ::::: .
# [ ----> X ::::: [
# To ----> ADP ::::: to
# Reaper ----> PROPN ::::: Reaper
# , ----> PUNCT ::::: ,
# faking ----> NOUN ::::: faking
# ] ----> PUNCT ::::: ]
# I ----> PRON ::::: I
# begrudgingly ----> ADV ::::: begrudgingly
# accept ----> VERB ::::: accept
# your ----> PRON ::::: your
# offer ----> NOUN ::::: offer
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Storm ----> NOUN ::::: storm
# clouds ----> NOUN ::::: cloud
# begin ----> VERB ::::: begin
# to ----> PART ::::: to
# cluster ----> VERB ::::: cluster
# above ----> ADP ::::: above
# the ----> DET ::::: the
# reaper ----> NOUN ::::: reaper
# . ----> PUNCT ::::: .
# ] ----> X ::::: ]
#
#  ----> SPACE :::::
#
# Reaper ----> PROPN ::::: Reaper
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Menacingly ----> ADV ::::: menacingly
# ] ----> PUNCT ::::: ]
# Yes ----> INTJ ::::: yes
# ... ----> PUNCT ::::: ...
# Then ----> ADV ::::: then
# the ----> DET ::::: the
# deal ----> NOUN ::::: deal
# is ----> AUX ::::: be
# struck ----> VERB ::::: strike
# ! ----> PUNCT ::::: !
# [ ----> X ::::: [
# Lightning ----> NOUN ::::: lightning
# flashes ----> NOUN ::::: flash
# ] ----> PUNCT ::::: ]
# WAHAHAHAHAHA ----> INTJ ::::: wahahahahaha
# ! ----> PUNCT ::::: !
# [ ----> X ::::: [
# Storm ----> NOUN ::::: storm
# clouds ----> NOUN ::::: cloud
# abruptly ----> ADV ::::: abruptly
# go ----> VERB ::::: go
# away ----> ADV ::::: away
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
# You ----> PRON ::::: you
# can ----> AUX ::::: can
# pick ----> VERB ::::: pick
# up ----> ADP ::::: up
# your ----> PRON ::::: your
# powers ----> NOUN ::::: power
# right ----> ADV ::::: right
# through ----> ADP ::::: through
# that ----> DET ::::: that
# door ----> NOUN ::::: door
# . ----> PUNCT ::::: .
# [ ----> X ::::: [
# A ----> DET ::::: a
# mystical ----> ADJ ::::: mystical
# , ----> PUNCT ::::: ,
# dangerous ----> ADJ ::::: dangerous
# - ----> PUNCT ::::: -
# looking ----> VERB ::::: look
# portal ----> NOUN ::::: portal
# suddenly ----> ADV ::::: suddenly
# appears ----> VERB ::::: appear
# next ----> ADV ::::: next
# to ----> ADP ::::: to
# him ----> PRON ::::: he
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
# [ ----> X ::::: [
# Holding ----> VERB ::::: hold
# up ----> ADP ::::: up
# a ----> DET ::::: a
# sign ----> NOUN ::::: sign
# that ----> PRON ::::: that
# says ----> VERB ::::: say
# " ----> PUNCT ::::: "
# FREE ----> PROPN ::::: FREE
# MAGICK ----> PROPN ::::: MAGICK
# " ----> PUNCT ::::: "
# ] ----> PUNCT ::::: ]
# This ----> DET ::::: this
# way ----> NOUN ::::: way
# ... ----> PUNCT ::::: ...
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# The ----> DET ::::: the
# Adventure ----> PROPN ::::: Adventure
# Time ----> PROPN ::::: Time
# logo ----> NOUN ::::: logo
# spins ----> VERB ::::: spin
# onto ----> ADP ::::: onto
# the ----> DET ::::: the
# screen ----> NOUN ::::: screen
# . ----> PUNCT ::::: .
# The ----> DET ::::: the
# sword ----> NOUN ::::: sword
# goes ----> VERB ::::: go
# through ----> ADP ::::: through
# the ----> DET ::::: the
# logo ----> NOUN ::::: logo
# . ----> PUNCT ::::: .
# The ----> DET ::::: the
# scene ----> NOUN ::::: scene
# shifts ----> VERB ::::: shift
# to ----> ADP ::::: to
# a ----> DET ::::: a
# realm ----> NOUN ::::: realm
# in ----> ADP ::::: in
# which ----> PRON ::::: which
# there ----> PRON ::::: there
# is ----> VERB ::::: be
# a ----> DET ::::: a
# wizard ----> NOUN ::::: wizard
# training ----> NOUN ::::: training
# facility ----> NOUN ::::: facility
# . ----> PUNCT ::::: .
# Finn ----> PROPN ::::: Finn
# and ----> CCONJ ::::: and
# Jake ----> PROPN ::::: Jake
# fall ----> VERB ::::: fall
# from ----> ADP ::::: from
# the ----> DET ::::: the
# portal ----> NOUN ::::: portal
# and ----> CCONJ ::::: and
# land ----> NOUN ::::: land
# here ----> ADV ::::: here
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# This ----> DET ::::: this
# place ----> NOUN ::::: place
# looks ----> VERB ::::: look
# magical ----> ADJ ::::: magical
# . ----> PUNCT ::::: .
# You ----> PRON ::::: you
# think ----> VERB ::::: think
# this ----> PRON ::::: this
# is ----> AUX ::::: be
# where ----> SCONJ ::::: where
# we ----> PRON ::::: we
# get ----> VERB ::::: get
# the ----> DET ::::: the
# powers ----> NOUN ::::: power
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Door ----> PROPN ::::: Door
# opens ----> VERB ::::: open
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Host ----> NOUN ::::: host
# : ----> PUNCT ::::: :
# Yes ----> INTJ ::::: yes
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# do ----> VERB ::::: do
# . ----> PUNCT ::::: .
# [ ----> X ::::: [
# Emerging ----> VERB ::::: emerge
# from ----> ADP ::::: from
# door ----> NOUN ::::: door
# ] ----> PUNCT ::::: ]
# Free ----> ADJ ::::: free
# powers ----> NOUN ::::: power
# for ----> ADP ::::: for
# all ----> PRON ::::: all
# . ----> PUNCT ::::: .
# Want ----> VERB ::::: want
# some ----> PRON ::::: some
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Yeah ----> INTJ ::::: yeah
# ! ----> PUNCT ::::: !
# Are ----> AUX ::::: be
# you ----> PRON ::::: you
# the ----> DET ::::: the
# guy ----> NOUN ::::: guy
# handing ----> VERB ::::: hand
# 'em ----> PRON ::::: them
# out ----> ADP ::::: out
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Host ----> NOUN ::::: host
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# seek ----> VERB ::::: seek
# Bufo ----> PROPN ::::: Bufo
# , ----> PUNCT ::::: ,
# the ----> DET ::::: the
# wizard ----> NOUN ::::: wizard
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# So ----> ADV ::::: so
# , ----> PUNCT ::::: ,
# where ----> SCONJ ::::: where
# 's ----> AUX ::::: be
# that ----> DET ::::: that
# guy ----> NOUN ::::: guy
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Host ----> NOUN ::::: host
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Indicating ----> VERB ::::: indicate
# his ----> PRON ::::: his
# person ----> NOUN ::::: person
# ] ----> PUNCT ::::: ]
# He ----> PRON ::::: he
# is ----> AUX ::::: be
# here ----> ADV ::::: here
# , ----> PUNCT ::::: ,
# of ----> ADP ::::: of
# course ----> NOUN ::::: course
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Uh ----> INTJ ::::: uh
# ... ----> PUNCT ::::: ...
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# He ----> PRON ::::: he
# 's ----> AUX ::::: be
# here ----> ADV ::::: here
# ... ----> PUNCT ::::: ...
# but ----> CCONJ ::::: but
# he ----> PRON ::::: he
# 's ----> AUX ::::: be
# not ----> PART ::::: not
# you ----> PRON ::::: you
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Host ----> NOUN ::::: host
# : ----> PUNCT ::::: :
# That ----> PRON ::::: that
# 's ----> AUX ::::: be
# right ----> ADJ ::::: right
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Making ----> VERB ::::: make
# his ----> PRON ::::: his
# fist ----> NOUN ::::: fist
# bigger ----> ADJ ::::: big
# ] ----> PUNCT ::::: ]
# We ----> PRON ::::: we
# should ----> AUX ::::: should
# beat ----> VERB ::::: beat
# ' ----> PUNCT ::::: '
# i ----> PRON ::::: I
# m ----> VERB ::::: m
# up ----> ADV ::::: up
# until ----> SCONJ ::::: until
# he ----> PRON ::::: he
# starts ----> VERB ::::: start
# makin ----> NOUN ::::: makin
# ' ----> PART ::::: '
# sense ----> NOUN ::::: sense
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# The ----> DET ::::: the
# host ----> NOUN ::::: host
# shrinks ----> VERB ::::: shrink
# in ----> ADP ::::: in
# fear ----> NOUN ::::: fear
# and ----> CCONJ ::::: and
# expands ----> VERB ::::: expand
# his ----> PRON ::::: his
# neck ----> NOUN ::::: neck
# . ----> PUNCT ::::: .
# Tadpoles ----> NOUN ::::: tadpole
# emerge ----> VERB ::::: emerge
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Bufo ----> PROPN ::::: Bufo
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# All ----> PRON ::::: all
# speaking ----> VERB ::::: speak
# simultaneously ----> ADV ::::: simultaneously
# ] ----> PUNCT ::::: ]
# We ----> PRON ::::: we
# are ----> AUX ::::: be
# Bufo ----> PROPN ::::: Bufo
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Ohhhh ----> PROPN ::::: Ohhhh
# ... ----> PUNCT ::::: ...
#
#  ----> SPACE :::::
#
# Bufo ----> PROPN ::::: Bufo
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# One ----> NUM ::::: one
# tadpole ----> NOUN ::::: tadpole
# , ----> PUNCT ::::: ,
# Leonard ----> PROPN ::::: Leonard
# , ----> PUNCT ::::: ,
# is ----> AUX ::::: be
# lagging ----> VERB ::::: lag
# behind ----> ADP ::::: behind
# this ----> DET ::::: this
# time ----> NOUN ::::: time
# ] ----> PUNCT ::::: ]
# So ----> ADV ::::: so
# ... ----> PUNCT ::::: ...
# you ----> PRON ::::: you
# wish ----> VERB ::::: wish
# to ----> PART ::::: to
# be ----> AUX ::::: be
# inducted ----> VERB ::::: induct
# into ----> ADP ::::: into
# the ----> DET ::::: the
# ancient ----> ADJ ::::: ancient
# order ----> NOUN ::::: order
# of ----> ADP ::::: of
# — ----> PUNCT ::::: —
#
#  ----> SPACE :::::
#
# Tadpole ----> PROPN ::::: Tadpole
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# The ----> DET ::::: the
# tadpoles ----> NOUN ::::: tadpole
# turn ----> VERB ::::: turn
# to ----> ADP ::::: to
# Leonard ----> PROPN ::::: Leonard
# ] ----> PUNCT ::::: ]
# Dang ----> PROPN ::::: Dang
# it ----> PRON ::::: it
# , ----> PUNCT ::::: ,
# Leonard ----> PROPN ::::: Leonard
# ! ----> PUNCT ::::: !
# ! ----> PUNCT ::::: !
# If ----> SCONJ ::::: if
# we ----> PRON ::::: we
# do ----> AUX ::::: do
# n't ----> PART ::::: not
# talk ----> VERB ::::: talk
# at ----> ADP ::::: at
# the ----> DET ::::: the
# same ----> ADJ ::::: same
# time ----> NOUN ::::: time
# , ----> PUNCT ::::: ,
# nobody ----> PRON ::::: nobody
# can ----> AUX ::::: can
# understand ----> VERB ::::: understand
# us ----> PRON ::::: we
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Leonard ----> PROPN ::::: Leonard
# : ----> PUNCT ::::: :
# Sorry ----> INTJ ::::: sorry
# ... ----> PUNCT ::::: ...
# geez ----> PROPN ::::: geez
# ... ----> PUNCT ::::: ...
#
#  ----> SPACE :::::
#
# Bufo ----> PROPN ::::: Bufo
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# All ----> PRON ::::: all
# speaking ----> VERB ::::: speak
# simultaneously ----> ADV ::::: simultaneously
# ] ----> PUNCT ::::: ]
# Ahem ----> INTJ ::::: ahem
# ... ----> PUNCT ::::: ...
# So ----> ADV ::::: so
# ... ----> PUNCT ::::: ...
# You ----> PRON ::::: you
# want ----> VERB ::::: want
# free ----> ADJ ::::: free
# wizard ----> NOUN ::::: wizard
# powers ----> NOUN ::::: power
# ... ----> PUNCT ::::: ...
# Powers ----> NOUN ::::: power
# like ----> VERB ::::: like
# ... ----> PUNCT ::::: ...
# [ ----> X ::::: [
# Creating ----> VERB ::::: create
# mystical ----> ADJ ::::: mystical
# energy ----> NOUN ::::: energy
# blasts ----> NOUN ::::: blast
# from ----> ADP ::::: from
# the ----> DET ::::: the
# host ----> NOUN ::::: host
# 's ----> PART ::::: 's
# hands ----> NOUN ::::: hand
# ] ----> PUNCT ::::: ]
# these ----> PRON ::::: these
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# & ----> CCONJ ::::: &
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Excitedly ----> ADV ::::: excitedly
# ] ----> PUNCT ::::: ]
# Hahaha ----> INTJ ::::: hahaha
# ! ----> PUNCT ::::: !
# Yeah ----> INTJ ::::: yeah
# ! ----> PUNCT ::::: !
# We ----> PRON ::::: we
# want ----> VERB ::::: want
# 'em ----> PRON ::::: them
# ! ----> PUNCT ::::: !
# Give ----> VERB ::::: give
# us ----> PRON ::::: we
# the ----> DET ::::: the
# stuff ----> NOUN ::::: stuff
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# Oh ----> INTJ ::::: oh
# , ----> PUNCT ::::: ,
# boy ----> NOUN ::::: boy
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Yes ----> INTJ ::::: yes
# , ----> PUNCT ::::: ,
# we ----> PRON ::::: we
# do ----> VERB ::::: do
# ! ----> PUNCT ::::: !
# Ca ----> AUX ::::: can
# n't ----> PART ::::: not
# wait ----> VERB ::::: wait
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Bufo ----> PROPN ::::: Bufo
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Slowly ----> ADV ::::: slowly
# retreating ----> VERB ::::: retreat
# to ----> ADP ::::: to
# the ----> DET ::::: the
# building ----> NOUN ::::: building
# ] ----> PUNCT ::::: ]
# [ ----> X ::::: [
# Mysteriously ----> ADV ::::: mysteriously
# ] ----> PUNCT ::::: ]
# Then ----> ADV ::::: then
# follow ----> VERB ::::: follow
# .... ----> PUNCT ::::: ....
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Finn ----> PROPN ::::: Finn
# and ----> CCONJ ::::: and
# Jake ----> PROPN ::::: Jake
# enthusiastically ----> ADV ::::: enthusiastically
# follow ----> VERB ::::: follow
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Whoo ----> PROPN ::::: Whoo
# - ----> PUNCT ::::: -
# hoo ----> NOUN ::::: hoo
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# Whoo ----> PROPN ::::: Whoo
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Bufo ----> PROPN ::::: Bufo
# : ----> PUNCT ::::: :
# Behold ----> VERB ::::: behold
# the ----> DET ::::: the
# Grand ----> PROPN ::::: Grand
# Hall ----> PROPN ::::: Hall
# of ----> ADP ::::: of
# Wizardry ----> PROPN ::::: Wizardry
# ! ----> PUNCT ::::: !
# [ ----> X ::::: [
# Camera ----> NOUN ::::: camera
# pans ----> NOUN ::::: pan
# to ----> PART ::::: to
# show ----> VERB ::::: show
# wizard ----> NOUN ::::: wizard
# students ----> NOUN ::::: student
# training ----> VERB ::::: train
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
# This ----> PRON ::::: this
# is ----> AUX ::::: be
# where ----> SCONJ ::::: where
# young ----> ADJ ::::: young
# potentials ----> NOUN ::::: potential
# train ----> VERB ::::: train
# to ----> PART ::::: to
# become ----> VERB ::::: become
# Ultimate ----> PROPN ::::: Ultimate
# Wizards ----> PROPN ::::: Wizards
# ! ----> PUNCT ::::: !
# Most ----> ADJ ::::: Most
# are ----> AUX ::::: be
# not ----> PART ::::: not
# ready ----> ADJ ::::: ready
# for ----> ADP ::::: for
# the ----> DET ::::: the
# responsibility ----> NOUN ::::: responsibility
# that ----> PRON ::::: that
# comes ----> VERB ::::: come
# with ----> ADP ::::: with
# it ----> PRON ::::: it
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Cheerfully ----> ADV ::::: cheerfully
# ] ----> PUNCT ::::: ]
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# responsible ----> ADJ ::::: responsible
# , ----> PUNCT ::::: ,
# dude ----> NOUN ::::: dude
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# Yeah ----> INTJ ::::: yeah
# ! ----> PUNCT ::::: !
# So ----> ADV ::::: so
# am ----> AUX ::::: be
# I ----> PRON ::::: I
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Still ----> ADV ::::: still
# cheerfully ----> ADV ::::: cheerfully
# ] ----> PUNCT ::::: ]
# That ----> PRON ::::: that
# 's ----> AUX ::::: be
# a ----> DET ::::: a
# lie ----> NOUN ::::: lie
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# It ----> PRON ::::: it
# is ----> AUX ::::: be
# a ----> DET ::::: a
# lie ----> NOUN ::::: lie
# ... ----> PUNCT ::::: ...
# and ----> CCONJ ::::: and
# I ----> PRON ::::: I
# take ----> VERB ::::: take
# full ----> ADJ ::::: full
# responsibility ----> NOUN ::::: responsibility
# for ----> ADP ::::: for
# it ----> PRON ::::: it
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Bufo ----> PROPN ::::: Bufo
# : ----> PUNCT ::::: :
# Yes ----> INTJ ::::: yes
# , ----> PUNCT ::::: ,
# yes ----> INTJ ::::: yes
# ... ----> PUNCT ::::: ...
# very ----> ADV ::::: very
# responsible ----> ADJ ::::: responsible
# . ----> PUNCT ::::: .
# Now ----> ADV ::::: now
# I ----> PRON ::::: I
# bestow ----> VERB ::::: bestow
# upon ----> SCONJ ::::: upon
# you ----> PRON ::::: you
# these ----> DET ::::: these
# wizard ----> NOUN ::::: wizard
# cloaks ----> NOUN ::::: cloak
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# & ----> CCONJ ::::: &
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# Whoa ----> INTJ ::::: whoa
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# They ----> PRON ::::: they
# don ----> VERB ::::: don
# the ----> DET ::::: the
# cloaks ----> NOUN ::::: cloak
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Hey ----> INTJ ::::: hey
# ! ----> PUNCT ::::: !
# This ----> PRON ::::: this
# is ----> AUX ::::: be
# a ----> DET ::::: a
# dress ----> NOUN ::::: dress
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# Yeah ----> INTJ ::::: yeah
# ! ----> PUNCT ::::: !
# And ----> CCONJ ::::: and
# I ----> PRON ::::: I
# am ----> AUX ::::: be
# into ----> ADP ::::: into
# it ----> PRON ::::: it
# ! ----> PUNCT ::::: !
# It ----> PRON ::::: it
# 's ----> AUX ::::: be
# , ----> PUNCT ::::: ,
# like ----> INTJ ::::: like
# , ----> PUNCT ::::: ,
# gossamer ----> NOUN ::::: gossamer
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# He ----> PRON ::::: he
# stuffs ----> VERB ::::: stuff
# the ----> DET ::::: the
# bottom ----> NOUN ::::: bottom
# of ----> ADP ::::: of
# the ----> DET ::::: the
# cloak ----> NOUN ::::: cloak
# into ----> ADP ::::: into
# his ----> PRON ::::: his
# shorts ----> NOUN ::::: short
# and ----> CCONJ ::::: and
# unhoods ----> NOUN ::::: unhood
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
# This ----> DET ::::: this
# way ----> NOUN ::::: way
# I ----> PRON ::::: I
# wo ----> AUX ::::: will
# n't ----> PART ::::: not
# be ----> AUX ::::: be
# embarrassed ----> ADJ ::::: embarrassed
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Bufo ----> PROPN ::::: Bufo
# : ----> PUNCT ::::: :
# Fine ----> ADJ ::::: fine
# , ----> PUNCT ::::: ,
# fine ----> ADJ ::::: fine
# . ----> PUNCT ::::: .
# Now ----> ADV ::::: now
# for ----> ADP ::::: for
# every ----> DET ::::: every
# power ----> NOUN ::::: power
# that ----> PRON ::::: that
# you ----> PRON ::::: you
# accrue ----> VERB ::::: accrue
# , ----> PUNCT ::::: ,
# [ ----> X ::::: [
# Creating ----> VERB ::::: create
# star ----> ADJ ::::: star
# badges ----> NOUN ::::: badge
# on ----> ADP ::::: on
# cloak ----> NOUN ::::: cloak
# ] ----> X ::::: ]
# you ----> PRON ::::: you
# shall ----> AUX ::::: shall
# receive ----> VERB ::::: receive
# a ----> DET ::::: a
# star ----> NOUN ::::: star
# badge ----> NOUN ::::: badge
# like ----> ADP ::::: like
# these ----> PRON ::::: these
# . ----> PUNCT ::::: .
# [ ----> X ::::: [
# Pointing ----> VERB ::::: point
# to ----> ADP ::::: to
# big ----> ADJ ::::: big
# star ----> NOUN ::::: star
# on ----> ADP ::::: on
# cloak ----> NOUN ::::: cloak
# ] ----> X ::::: ]
# This ----> DET ::::: this
# final ----> ADJ ::::: final
# star ----> NOUN ::::: star
# betokens ----> VERB ::::: betoken
# the ----> DET ::::: the
# rank ----> NOUN ::::: rank
# of ----> ADP ::::: of
# Ultimate ----> PROPN ::::: Ultimate
# Wizard ----> PROPN ::::: Wizard
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Finn ----> PROPN ::::: Finn
# and ----> CCONJ ::::: and
# Jake ----> PROPN ::::: Jake
# gasp ----> VERB ::::: gasp
# in ----> ADP ::::: in
# awe ----> NOUN ::::: awe
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Mark ----> PROPN ::::: Mark
# me ----> PRON ::::: I
# , ----> PUNCT ::::: ,
# Jake ----> PROPN ::::: Jake
# . ----> PUNCT ::::: .
# I ----> PRON ::::: I
# shall ----> AUX ::::: shall
# have ----> VERB ::::: have
# that ----> DET ::::: that
# final ----> ADJ ::::: final
# star ----> NOUN ::::: star
# ! ----> PUNCT ::::: !
# [ ----> X ::::: [
# To ----> ADP ::::: to
# Bufo ----> PROPN ::::: Bufo
# ] ----> X ::::: ]
# Where ----> SCONJ ::::: where
# do ----> AUX ::::: do
# we ----> PRON ::::: we
# start ----> VERB ::::: start
# ? ----> PUNCT ::::: ?
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Bufo ----> PROPN ::::: Bufo
# : ----> PUNCT ::::: :
# Level ----> NOUN ::::: level
# 1 ----> NUM ::::: 1
# — ----> PUNCT ::::: —
# Dustomancy ----> PROPN ::::: Dustomancy
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Yeah ----> INTJ ::::: yeah
# ! ----> PUNCT ::::: !
# Dustomancy ----> PROPN ::::: Dustomancy
# ! ----> PUNCT ::::: !
# Whatever ----> PRON ::::: whatever
# that ----> PRON ::::: that
# is ----> AUX ::::: be
# ! ----> PUNCT ::::: !
# Gimme ----> PROPN ::::: Gimme
# gimme ----> PROPN ::::: gimme
# gimme ----> PROPN ::::: gimme
# gimme ----> PROPN ::::: gimme
# gimme ----> PROPN ::::: gimme
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Bufo ----> PROPN ::::: Bufo
# : ----> PUNCT ::::: :
# To ----> PART ::::: to
# receive ----> VERB ::::: receive
# this ----> DET ::::: this
# power ----> NOUN ::::: power
# , ----> PUNCT ::::: ,
# you ----> PRON ::::: you
# must ----> AUX ::::: must
# first ----> ADV ::::: first
# ... ----> PUNCT ::::: ...
# [ ----> X ::::: [
# Making ----> VERB ::::: make
# two ----> NUM ::::: two
# brooms ----> NOUN ::::: broom
# appear ----> VERB ::::: appear
# ] ----> PUNCT ::::: ]
# eat ----> VERB ::::: eat
# these ----> DET ::::: these
# brooms ----> NOUN ::::: broom
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# He ----> PRON ::::: he
# gives ----> VERB ::::: give
# the ----> DET ::::: the
# brooms ----> NOUN ::::: broom
# to ----> ADP ::::: to
# Finn ----> PROPN ::::: Finn
# and ----> CCONJ ::::: and
# Jake ----> PROPN ::::: Jake
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Alright ----> INTJ ::::: alright
# . ----> PUNCT ::::: .
# [ ----> X ::::: [
# He ----> PRON ::::: he
# and ----> CCONJ ::::: and
# Jake ----> PROPN ::::: Jake
# begin ----> VERB ::::: begin
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
# Ah ----> INTJ ::::: ah
# , ----> PUNCT ::::: ,
# wait ----> VERB ::::: wait
# ! ----> PUNCT ::::: !
# [ ----> X ::::: [
# Spits ----> VERB ::::: spit
# out ----> ADP ::::: out
# splinters ----> NOUN ::::: splinter
# and ----> CCONJ ::::: and
# sticks ----> VERB ::::: stick
# tongue ----> NOUN ::::: tongue
# out ----> ADP ::::: out
# , ----> PUNCT ::::: ,
# showing ----> VERB ::::: show
# splinters ----> NOUN ::::: splinter
# on ----> ADP ::::: on
# tongue ----> NOUN ::::: tongue
# ] ----> PUNCT ::::: ]
# This ----> PRON ::::: this
# is ----> AUX ::::: be
# gross ----> ADJ ::::: gross
# ! ----> PUNCT ::::: !
# ! ----> PUNCT ::::: !
# Man ----> NOUN ::::: man
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# ca ----> AUX ::::: can
# n't ----> PART ::::: not
# eat ----> VERB ::::: eat
# this ----> PRON ::::: this
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# Yeah ----> INTJ ::::: yeah
# , ----> PUNCT ::::: ,
# you ----> PRON ::::: you
# can ----> AUX ::::: can
# ! ----> PUNCT ::::: !
# Do ----> VERB ::::: do
# what ----> PRON ::::: what
# I ----> PRON ::::: I
# do ----> VERB ::::: do
# ! ----> PUNCT ::::: !
# RAAAAWR ----> PROPN ::::: RAAAAWR
# ! ----> PUNCT ::::: !
# ! ----> PUNCT ::::: !
# [ ----> X ::::: [
# Increases ----> NOUN ::::: increase
# size ----> NOUN ::::: size
# then ----> ADV ::::: then
# eats ----> VERB ::::: eat
# broom ----> NOUN ::::: broom
# with ----> ADP ::::: with
# ease ----> NOUN ::::: ease
# . ----> PUNCT ::::: .
# He ----> PRON ::::: he
# shrinks ----> VERB ::::: shrink
# back ----> ADV ::::: back
# to ----> ADP ::::: to
# his ----> PRON ::::: his
# normal ----> ADJ ::::: normal
# size ----> NOUN ::::: size
# , ----> PUNCT ::::: ,
# but ----> CCONJ ::::: but
# the ----> DET ::::: the
# broom ----> NOUN ::::: broom
# remains ----> VERB ::::: remain
# the ----> DET ::::: the
# same ----> ADJ ::::: same
# size ----> NOUN ::::: size
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
# Oops ----> INTJ ::::: oops
# . ----> PUNCT ::::: .
# [ ----> X ::::: [
# Slightly ----> ADV ::::: slightly
# increases ----> VERB ::::: increase
# size ----> NOUN ::::: size
# ] ----> X ::::: ]
# Ah ----> INTJ ::::: ah
# , ----> PUNCT ::::: ,
# there ----> ADV ::::: there
# we ----> PRON ::::: we
# go ----> VERB ::::: go
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# A ----> DET ::::: a
# star ----> NOUN ::::: star
# forms ----> NOUN ::::: form
# on ----> ADP ::::: on
# Jake ----> PROPN ::::: Jake
# 's ----> PART ::::: 's
# cloak ----> NOUN ::::: cloak
# . ----> PUNCT ::::: .
# Finn ----> PROPN ::::: Finn
# and ----> CCONJ ::::: and
# Jake ----> PROPN ::::: Jake
# make ----> VERB ::::: make
# amazed ----> ADJ ::::: amazed
# noises ----> NOUN ::::: noise
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Whoooaaa ----> PROPN ::::: Whoooaaa
# ! ----> PUNCT ::::: !
# You ----> PRON ::::: you
# got ----> VERB ::::: get
# a ----> DET ::::: a
# star ----> NOUN ::::: star
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# Haha ----> INTJ ::::: haha
# ! ----> PUNCT ::::: !
# Observe ----> VERB ::::: observe
# my ----> PRON ::::: my
# magics ----> NOUN ::::: magic
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Wait ----> VERB ::::: wait
# , ----> PUNCT ::::: ,
# Jake ----> PROPN ::::: Jake
# ! ----> PUNCT ::::: !
# Do ----> AUX ::::: do
# n't ----> PART ::::: not
# use ----> VERB ::::: use
# 'em ----> PRON ::::: them
# until ----> SCONJ ::::: until
# I ----> PRON ::::: I
# finish ----> VERB ::::: finish
# my ----> PRON ::::: my
# broom ----> NOUN ::::: broom
# ! ----> PUNCT ::::: !
# [ ----> X ::::: [
# Gnaws ----> NOUN ::::: gnaws
# furiously ----> ADV ::::: furiously
# on ----> ADP ::::: on
# broom ----> NOUN ::::: broom
# . ----> PUNCT ::::: .
# Scene ----> PROPN ::::: Scene
# transition ----> NOUN ::::: transition
# ; ----> PUNCT ::::: ;
# Finn ----> PROPN ::::: Finn
# and ----> CCONJ ::::: and
# Jake ----> PROPN ::::: Jake
# are ----> AUX ::::: be
# sitting ----> VERB ::::: sit
# on ----> ADP ::::: on
# the ----> DET ::::: the
# floor ----> NOUN ::::: floor
# . ----> PUNCT ::::: .
# Finn ----> PROPN ::::: Finn
# 's ----> PART ::::: 's
# broom ----> NOUN ::::: broom
# is ----> AUX ::::: be
# almost ----> ADV ::::: almost
# completely ----> ADV ::::: completely
# eaten ----> VERB ::::: eat
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
# [ ----> X ::::: [
# Weakly ----> ADV ::::: weakly
# ] ----> X ::::: ]
# Last ----> ADJ ::::: last
# ... ----> PUNCT ::::: ...
# bite ----> NOUN ::::: bite
# ... ----> PUNCT ::::: ...
# [ ----> X ::::: [
# Eats ----> VERB ::::: eat
# it ----> PRON ::::: it
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# A ----> DET ::::: a
# star ----> NOUN ::::: star
# appears ----> VERB ::::: appear
# on ----> ADP ::::: on
# Finn ----> PROPN ::::: Finn
# 's ----> PART ::::: 's
# cloak ----> NOUN ::::: cloak
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Rising ----> VERB ::::: rise
# up ----> ADP ::::: up
# ] ----> PUNCT ::::: ]
# Dude ----> NOUN ::::: dude
# , ----> PUNCT ::::: ,
# you ----> PRON ::::: you
# got ----> VERB ::::: get
# your ----> PRON ::::: your
# star ----> NOUN ::::: star
# , ----> PUNCT ::::: ,
# too ----> ADV ::::: too
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Rising ----> VERB ::::: rise
# up ----> ADP ::::: up
# ] ----> PUNCT ::::: ]
# WE'RE ----> INTJ ::::: we're
# DUSTOMANCERS ----> PROPN ::::: DUSTOMANCERS
# ! ----> PUNCT ::::: !
# [ ----> X ::::: [
# Strains ----> NOUN ::::: strain
# trying ----> VERB ::::: try
# to ----> PART ::::: to
# use ----> VERB ::::: use
# powers ----> NOUN ::::: power
# ] ----> PUNCT ::::: ]
# Nothing ----> PRON ::::: nothing
# happened ----> VERB ::::: happen
# ! ----> PUNCT ::::: !
# This ----> PRON ::::: this
# is ----> AUX ::::: be
# a ----> DET ::::: a
# total ----> ADJ ::::: total
# ripoff ----> NOUN ::::: ripoff
# ! ----> PUNCT ::::: !
# ! ----> PUNCT ::::: !
# Bufo ----> PROPN ::::: Bufo
# ! ----> PUNCT ::::: !
# You ----> PRON ::::: you
# tricked ----> VERB ::::: trick
# us ----> PRON ::::: we
# ! ----> PUNCT ::::: !
# Stupid ----> ADJ ::::: stupid
# power ----> NOUN ::::: power
# does ----> AUX ::::: do
# n't ----> PART ::::: not
# even ----> ADV ::::: even
# work ----> VERB ::::: work
# ! ----> PUNCT ::::: !
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Bufo ----> PROPN ::::: Bufo
# : ----> PUNCT ::::: :
# Calm ----> VERB ::::: calm
# yourself ----> PRON ::::: yourself
# , ----> PUNCT ::::: ,
# boy ----> INTJ ::::: boy
# . ----> PUNCT ::::: .
# [ ----> X ::::: [
# Strikes ----> PROPN ::::: Strikes
# Finn ----> PROPN ::::: Finn
# ] ----> PUNCT ::::: ]
# You ----> PRON ::::: you
# are ----> AUX ::::: be
# acting ----> VERB ::::: act
# hysterical ----> ADJ ::::: hysterical
# . ----> PUNCT ::::: .
# Do ----> AUX ::::: do
# you ----> PRON ::::: you
# not ----> PART ::::: not
# see ----> VERB ::::: see
# that ----> SCONJ ::::: that
# you ----> PRON ::::: you
# are ----> AUX ::::: be
# using ----> VERB ::::: use
# Dustomancy ----> PROPN ::::: Dustomancy
# ? ----> PUNCT ::::: ?
# Behold ----> ADV ::::: behold
# ... ----> PUNCT ::::: ...
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# A ----> DET ::::: a
# dust ----> NOUN ::::: dust
# mote ----> NOUN ::::: mote
# appears ----> VERB ::::: appear
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# doing ----> VERB ::::: do
# this ----> PRON ::::: this
# ? ----> PUNCT ::::: ?
# So ----> ADV ::::: so
# ... ----> PUNCT ::::: ...
# I ----> PRON ::::: I
# have ----> VERB ::::: have
# — ----> PUNCT ::::: —
#
#  ----> SPACE :::::
#
# Bufo ----> PROPN ::::: Bufo
# : ----> PUNCT ::::: :
# Yes ----> INTJ ::::: yes
# . ----> PUNCT ::::: .
# Mastery ----> PROPN ::::: Mastery
# over ----> ADP ::::: over
# all ----> DET ::::: all
# dust ----> NOUN ::::: dust
# motes ----> NOUN ::::: mote
# . ----> PUNCT ::::: .
# You ----> PRON ::::: you
# can ----> AUX ::::: can
# also ----> ADV ::::: also
# read ----> VERB ::::: read
# their ----> PRON ::::: their
# emotions ----> NOUN ::::: emotion
# . ----> PUNCT ::::: .
# For ----> ADP ::::: for
# instance ----> NOUN ::::: instance
# , ----> PUNCT ::::: ,
# this ----> DET ::::: this
# mote ----> NOUN ::::: mote
# is ----> AUX ::::: be
# very ----> ADV ::::: very
# unhappy ----> ADJ ::::: unhappy
# in ----> ADP ::::: in
# his ----> PRON ::::: his
# marriage ----> NOUN ::::: marriage
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# Well ----> INTJ ::::: well
# , ----> PUNCT ::::: ,
# that ----> PRON ::::: that
# 's ----> AUX ::::: be
# ... ----> PUNCT ::::: ...
# sorta ----> ADV ::::: sorta
# cool ----> ADJ ::::: cool
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# " ----> PUNCT ::::: "
# Sorta ----> ADV ::::: sorta
# " ----> PUNCT ::::: "
# cool ----> ADJ ::::: cool
# ? ----> PUNCT ::::: ?
# ! ----> PUNCT ::::: !
# ? ----> PUNCT ::::: ?
# THIS ----> PRON ::::: this
# IS ----> AUX ::::: be
# RADICAL ----> ADJ ::::: radical
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# Whoo ----> PROPN ::::: Whoo
# , ----> PUNCT ::::: ,
# yeah ----> INTJ ::::: yeah
# ! ----> PUNCT ::::: !
# Force ----> VERB ::::: force
# that ----> DET ::::: that
# enthusiasm ----> NOUN ::::: enthusiasm
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Bufo ----> PROPN ::::: Bufo
# : ----> PUNCT ::::: :
# Are ----> AUX ::::: be
# you ----> PRON ::::: you
# ready ----> ADJ ::::: ready
# for ----> ADP ::::: for
# more ----> ADJ ::::: more
# magic ----> NOUN ::::: magic
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# We ----> PRON ::::: we
# get ----> VERB ::::: get
# more ----> ADJ ::::: more
# ? ----> PUNCT ::::: ?
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Bufo ----> PROPN ::::: Bufo
# : ----> PUNCT ::::: :
# So ----> ADV ::::: so
# much ----> ADV ::::: much
# more ----> ADJ ::::: more
# ... ----> PUNCT ::::: ...
# like ----> ADP ::::: like
# Level ----> PROPN ::::: Level
# 2 ----> NUM ::::: 2
# ... ----> PUNCT ::::: ...
# the ----> DET ::::: the
# power ----> NOUN ::::: power
# of ----> ADP ::::: of
# ... ----> PUNCT ::::: ...
# Shadowcery ----> PROPN ::::: Shadowcery
# ! ----> PUNCT ::::: !
# [ ----> X ::::: [
# Makes ----> VERB ::::: make
# blindfolds ----> NOUN ::::: blindfold
# appear ----> VERB ::::: appear
# over ----> ADP ::::: over
# Finn ----> PROPN ::::: Finn
# and ----> CCONJ ::::: and
# Jake ----> PROPN ::::: Jake
# 's ----> PART ::::: 's
# eyes ----> NOUN ::::: eye
# ] ----> PUNCT ::::: ]
# You ----> PRON ::::: you
# ca ----> AUX ::::: can
# n't ----> PART ::::: not
# see ----> VERB ::::: see
# through ----> ADP ::::: through
# those ----> PRON ::::: those
# , ----> PUNCT ::::: ,
# right ----> ADJ ::::: right
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Nope ----> INTJ ::::: nope
# ... ----> PUNCT ::::: ...
# Not ----> PART ::::: not
# at ----> ADV ::::: at
# all ----> ADV ::::: all
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Bufo ----> PROPN ::::: Bufo
# : ----> PUNCT ::::: :
# To ----> PART ::::: to
# gain ----> VERB ::::: gain
# provenance ----> NOUN ::::: provenance
# over ----> ADP ::::: over
# the ----> DET ::::: the
# shadows ----> NOUN ::::: shadow
# , ----> PUNCT ::::: ,
# place ----> VERB ::::: place
# your ----> PRON ::::: your
# hands ----> NOUN ::::: hand
# into ----> ADP ::::: into
# [ ----> PUNCT ::::: [
# Making ----> VERB ::::: make
# bowl ----> NOUN ::::: bowl
# of ----> ADP ::::: of
# peeled ----> VERB ::::: peel
# grapes ----> NOUN ::::: grape
# appear ----> VERB ::::: appear
# ] ----> PUNCT ::::: ]
# this ----> DET ::::: this
# bowl ----> NOUN ::::: bowl
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Slightly ----> ADV ::::: slightly
# removing ----> VERB ::::: remove
# blindfold ----> NOUN ::::: blindfold
# ] ----> X ::::: ]
# What ----> DET ::::: what
# bowl ----> NOUN ::::: bowl
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Bufo ----> PROPN ::::: Bufo
# : ----> PUNCT ::::: :
# No ----> INTJ ::::: no
# ! ----> PUNCT ::::: !
# Cover ----> VERB ::::: cover
# your ----> PRON ::::: your
# eyes ----> NOUN ::::: eye
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# Annoyed ----> X ::::: annoyed
# ] ----> PUNCT ::::: ]
# Mmmm ----> INTJ ::::: mmmm
# , ----> PUNCT ::::: ,
# fine ----> ADJ ::::: fine
# ... ----> PUNCT ::::: ...
#
#  ----> SPACE :::::
#
# Bufo ----> PROPN ::::: Bufo
# : ----> PUNCT ::::: :
# Thrust ----> PROPN ::::: Thrust
# your ----> PRON ::::: your
# hands ----> NOUN ::::: hand
# into ----> ADP ::::: into
# this ----> DET ::::: this
# bowl ----> NOUN ::::: bowl
# ... ----> PUNCT ::::: ...
# of ----> ADP ::::: of
# eyeballs ----> NOUN ::::: eyeball
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Eyeballs ----> NOUN ::::: eyeball
# ? ----> PUNCT ::::: ?
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# Dude ----> NOUN ::::: dude
# , ----> PUNCT ::::: ,
# it ----> PRON ::::: it
# 's ----> AUX ::::: be
# okay ----> ADJ ::::: okay
# . ----> PUNCT ::::: .
# They ----> PRON ::::: they
# 're ----> AUX ::::: be
# just ----> ADV ::::: just
# peeled ----> VERB ::::: peel
# grapes ----> NOUN ::::: grape
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Bufo ----> PROPN ::::: Bufo
# : ----> PUNCT ::::: :
# No ----> INTJ ::::: no
# ! ----> PUNCT ::::: !
# They ----> PRON ::::: they
# 're ----> AUX ::::: be
# eyeballs ----> NOUN ::::: eyeball
# ... ----> PUNCT ::::: ...
# [ ----> X ::::: [
# Giggles ----> VERB ::::: giggle
# mischievously ----> ADV ::::: mischievously
# . ----> PUNCT ::::: .
# Finn ----> PROPN ::::: Finn
# and ----> CCONJ ::::: and
# Jake ----> PROPN ::::: Jake
# feel ----> VERB ::::: feel
# the ----> DET ::::: the
# grapes ----> NOUN ::::: grape
# and ----> CCONJ ::::: and
# make ----> VERB ::::: make
# disgusted ----> ADJ ::::: disgusted
# noises ----> NOUN ::::: noise
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
# Well ----> INTJ ::::: well
# done ----> VERB ::::: do
# . ----> PUNCT ::::: .
# You ----> PRON ::::: you
# have ----> AUX ::::: have
# groped ----> VERB ::::: grope
# the ----> DET ::::: the
# eyeballs ----> NOUN ::::: eyeball
# fearlessly ----> ADV ::::: fearlessly
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Finn ----> PROPN ::::: Finn
# and ----> CCONJ ::::: and
# Jake ----> PROPN ::::: Jake
# each ----> PRON ::::: each
# get ----> VERB ::::: get
# a ----> DET ::::: a
# new ----> ADJ ::::: new
# star ----> NOUN ::::: star
# on ----> ADP ::::: on
# their ----> PRON ::::: their
# cloaks ----> NOUN ::::: cloak
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Another ----> DET ::::: another
# star ----> NOUN ::::: star
# ! ----> PUNCT ::::: !
# Yeah ----> INTJ ::::: yeah
# ! ----> PUNCT ::::: !
# Shadowcery ----> PROPN ::::: Shadowcery
# ... ----> PUNCT ::::: ...
# [ ----> X ::::: [
# He ----> PRON ::::: he
# morphs ----> VERB ::::: morph
# his ----> PRON ::::: his
# shadow ----> NOUN ::::: shadow
# into ----> ADP ::::: into
# a ----> DET ::::: a
# three ----> NUM ::::: three
# - ----> PUNCT ::::: -
# dimensional ----> ADJ ::::: dimensional
# form ----> NOUN ::::: form
# of ----> ADP ::::: of
# a ----> DET ::::: a
# horse ----> NOUN ::::: horse
# . ----> PUNCT ::::: .
# The ----> DET ::::: the
# horse ----> NOUN ::::: horse
# neighs ----> VERB ::::: neigh
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
# Onward ----> ADV ::::: onward
# , ----> PUNCT ::::: ,
# my ----> PRON ::::: my
# shadow ----> NOUN ::::: shadow
# steed ----> NOUN ::::: steed
# ! ----> PUNCT ::::: !
# [ ----> X ::::: [
# Tries ----> VERB ::::: try
# to ----> PART ::::: to
# jump ----> VERB ::::: jump
# on ----> ADP ::::: on
# horse ----> NOUN ::::: horse
# but ----> CCONJ ::::: but
# phases ----> NOUN ::::: phase
# through ----> ADP ::::: through
# it ----> PRON ::::: it
# ] ----> PUNCT ::::: ]
# Huh ----> INTJ ::::: huh
# ? ----> PROPN ::::: ?
#
#  ----> SPACE :::::
#
# Shadow ----> PROPN ::::: Shadow
# Horse ----> NOUN ::::: horse
# : ----> PUNCT ::::: :
# No ----> DET ::::: no
# touchies ----> NOUN ::::: touchie
# . ----> PUNCT ::::: .
# [ ----> X ::::: [
# Disappears ----> VERB ::::: disappear
# ] ----> SYM ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Wizard ----> PROPN ::::: Wizard
# powers ----> NOUN ::::: power
# are ----> AUX ::::: be
# so ----> ADV ::::: so
# cool ----> ADJ ::::: cool
# ... ----> PUNCT ::::: ...
# I ----> PRON ::::: I
# want ----> VERB ::::: want
# ALL ----> DET ::::: all
# THE ----> DET ::::: the
# STAR ----> PROPN ::::: STAR
# BADGES ----> NOUN ::::: badge
# ! ----> PUNCT ::::: !
# ! ----> PUNCT ::::: !
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# A ----> DET ::::: a
# montage ----> NOUN ::::: montage
# begins ----> VERB ::::: begin
# . ----> PUNCT ::::: .
# On ----> ADP ::::: on
# Level ----> PROPN ::::: Level
# 3 ----> NUM ::::: 3
# , ----> PUNCT ::::: ,
# Finn ----> PROPN ::::: Finn
# and ----> CCONJ ::::: and
# Jake ----> PROPN ::::: Jake
# must ----> AUX ::::: must
# balance ----> VERB ::::: balance
# pencils ----> NOUN ::::: pencil
# on ----> ADP ::::: on
# their ----> PRON ::::: their
# lips ----> NOUN ::::: lip
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Bufo ----> PROPN ::::: Bufo
# : ----> PUNCT ::::: :
# Excellent ----> ADJ ::::: excellent
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Finn ----> PROPN ::::: Finn
# and ----> CCONJ ::::: and
# Jake ----> PROPN ::::: Jake
# are ----> AUX ::::: be
# rewarded ----> VERB ::::: reward
# with ----> ADP ::::: with
# their ----> PRON ::::: their
# third ----> ADJ ::::: third
# stars ----> NOUN ::::: star
# and ----> CCONJ ::::: and
# the ----> DET ::::: the
# power ----> NOUN ::::: power
# of ----> ADP ::::: of
# hair ----> NOUN ::::: hair
# creation ----> NOUN ::::: creation
# . ----> PUNCT ::::: .
# Jake ----> PROPN ::::: Jake
# chuckles ----> VERB ::::: chuckle
# and ----> CCONJ ::::: and
# makes ----> VERB ::::: make
# himself ----> PRON ::::: himself
# a ----> DET ::::: a
# mustache ----> NOUN ::::: mustache
# . ----> PUNCT ::::: .
# On ----> ADP ::::: on
# Level ----> PROPN ::::: Level
# 8 ----> NUM ::::: 8
# , ----> PUNCT ::::: ,
# Finn ----> PROPN ::::: Finn
# and ----> CCONJ ::::: and
# Jake ----> PROPN ::::: Jake
# spin ----> VERB ::::: spin
# coins ----> NOUN ::::: coin
# by ----> ADP ::::: by
# flicking ----> VERB ::::: flick
# them ----> PRON ::::: they
# . ----> PUNCT ::::: .
# Stars ----> NOUN ::::: star
# are ----> AUX ::::: be
# rewarded ----> VERB ::::: reward
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Bufo ----> PROPN ::::: Bufo
# : ----> PUNCT ::::: :
# Well ----> INTJ ::::: well
# done ----> VERB ::::: do
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Finn ----> PROPN ::::: Finn
# and ----> CCONJ ::::: and
# Jake ----> PROPN ::::: Jake
# are ----> AUX ::::: be
# rewarded ----> VERB ::::: reward
# with ----> ADP ::::: with
# the ----> DET ::::: the
# power ----> NOUN ::::: power
# of ----> ADP ::::: of
# mayonnaise ----> NOUN ::::: mayonnaise
# creation ----> NOUN ::::: creation
# . ----> PUNCT ::::: .
# They ----> PRON ::::: they
# feed ----> VERB ::::: feed
# themselves ----> PRON ::::: themselves
# with ----> ADP ::::: with
# mayonnaise ----> NOUN ::::: mayonnaise
# . ----> PUNCT ::::: .
# On ----> ADP ::::: on
# the ----> DET ::::: the
# next ----> ADJ ::::: next
# challenge ----> NOUN ::::: challenge
# , ----> PUNCT ::::: ,
# Finn ----> PROPN ::::: Finn
# flips ----> VERB ::::: flip
# a ----> DET ::::: a
# hammer ----> NOUN ::::: hammer
# and ----> CCONJ ::::: and
# is ----> AUX ::::: be
# rewarded ----> VERB ::::: reward
# with ----> ADP ::::: with
# a ----> DET ::::: a
# star ----> NOUN ::::: star
# ; ----> PUNCT ::::: ;
# on ----> ADP ::::: on
# the ----> DET ::::: the
# succeeding ----> VERB ::::: succeed
# challenge ----> NOUN ::::: challenge
# , ----> PUNCT ::::: ,
# Jake ----> PROPN ::::: Jake
# puts ----> VERB ::::: put
# an ----> DET ::::: an
# orange ----> ADJ ::::: orange
# slice ----> NOUN ::::: slice
# in ----> ADP ::::: in
# his ----> PRON ::::: his
# mouth ----> NOUN ::::: mouth
# to ----> PART ::::: to
# create ----> VERB ::::: create
# a ----> DET ::::: a
# fake ----> ADJ ::::: fake
# smile ----> NOUN ::::: smile
# and ----> CCONJ ::::: and
# is ----> AUX ::::: be
# rewarded ----> VERB ::::: reward
# with ----> ADP ::::: with
# a ----> DET ::::: a
# star ----> NOUN ::::: star
# . ----> PUNCT ::::: .
# On ----> ADP ::::: on
# the ----> DET ::::: the
# next ----> ADJ ::::: next
# challenge ----> NOUN ::::: challenge
# , ----> PUNCT ::::: ,
# Finn ----> PROPN ::::: Finn
# and ----> CCONJ ::::: and
# Jake ----> PROPN ::::: Jake
# both ----> PRON ::::: both
# balance ----> VERB ::::: balance
# themselves ----> PRON ::::: themselves
# on ----> ADP ::::: on
# tilted ----> ADJ ::::: tilted
# chairs ----> NOUN ::::: chair
# . ----> PUNCT ::::: .
# On ----> ADP ::::: on
# Level ----> PROPN ::::: Level
# 15 ----> NUM ::::: 15
# , ----> PUNCT ::::: ,
# Jake ----> PROPN ::::: Jake
# is ----> AUX ::::: be
# rewarded ----> VERB ::::: reward
# with ----> ADP ::::: with
# Beauteous ----> PROPN ::::: Beauteous
# Wings ----> PROPN ::::: Wings
# ...
# their ----> PRON ::::: their
# way ----> NOUN ::::: way
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
# Zap ----> VERB ::::: zap
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# They ----> PRON ::::: they
# all ----> PRON ::::: all
# shout ----> VERB ::::: shout
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Magic ----> PROPN ::::: Magic
# Man ----> PROPN ::::: Man
# : ----> PUNCT ::::: :
# Come ----> VERB ::::: come
# on ----> ADP ::::: on
# , ----> PUNCT ::::: ,
# apple ----> NOUN ::::: apple
# grease ----> NOUN ::::: grease
# ! ----> PUNCT ::::: !
# What ----> PRON ::::: what
# are ----> AUX ::::: be
# you ----> PRON ::::: you
# gon ----> VERB ::::: go
# na ----> PART ::::: to
# do ----> VERB ::::: do
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Zap ----> VERB ::::: zap
# punches ----> NOUN ::::: punch
# Magic ----> PROPN ::::: Magic
# Man ----> PROPN ::::: Man
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Magic ----> PROPN ::::: Magic
# Man ----> PROPN ::::: Man
# : ----> PUNCT ::::: :
# Ohh ----> INTJ ::::: ohh
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Zap ----> VERB ::::: zap
# : ----> PUNCT ::::: :
# We ----> PRON ::::: we
# 're ----> AUX ::::: be
# not ----> PART ::::: not
# afraid ----> ADJ ::::: afraid
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Magic ----> PROPN ::::: Magic
# Man ----> PROPN ::::: Man
# : ----> PUNCT ::::: :
# Are ----> AUX ::::: be
# you ----> PRON ::::: you
# sure ----> ADJ ::::: sure
# about ----> ADP ::::: about
# that ----> PRON ::::: that
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# 're ----> AUX ::::: be
# darn ----> ADJ ::::: darn
# right ----> ADJ ::::: right
# we ----> PRON ::::: we
# are ----> AUX ::::: be
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Gork ----> PROPN ::::: Gork
# vomits ----> VERB ::::: vomit
# lava ----> NOUN ::::: lava
# at ----> ADP ::::: at
# Magic ----> PROPN ::::: Magic
# Man ----> PROPN ::::: Man
# but ----> CCONJ ::::: but
# it ----> PRON ::::: it
# is ----> AUX ::::: be
# deflected ----> VERB ::::: deflect
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Give ----> VERB ::::: give
# us ----> PRON ::::: we
# our ----> PRON ::::: our
# bodies ----> NOUN ::::: body
# back ----> ADV ::::: back
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Finn ----> PROPN ::::: Finn
# kicks ----> VERB ::::: kick
# Magic ----> PROPN ::::: Magic
# Man ----> PROPN ::::: Man
# into ----> ADP ::::: into
# a ----> DET ::::: a
# pile ----> NOUN ::::: pile
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Magic ----> PROPN ::::: Magic
# Man ----> PROPN ::::: Man
# : ----> PUNCT ::::: :
# Why ----> SCONJ ::::: why
# should ----> AUX ::::: should
# I ----> PRON ::::: I
# ? ----> PUNCT ::::: ?
# You ----> PRON ::::: you
# still ----> ADV ::::: still
# act ----> VERB ::::: act
# like ----> ADP ::::: like
# a ----> DET ::::: a
# hero ----> NOUN ::::: hero
# only ----> ADV ::::: only
# so ----> SCONJ ::::: so
# you ----> PRON ::::: you
# can ----> AUX ::::: can
# get ----> VERB ::::: get
# what ----> PRON ::::: what
# you ----> PRON ::::: you
# want ----> VERB ::::: want
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Oh ----> INTJ ::::: oh
# . ----> PUNCT ::::: .
# You ----> PRON ::::: you
# were ----> AUX ::::: be
# trying ----> VERB ::::: try
# to ----> PART ::::: to
# teach ----> VERB ::::: teach
# us ----> PRON ::::: we
# to ----> PART ::::: to
# be ----> AUX ::::: be
# kind ----> ADJ ::::: kind
# without ----> ADP ::::: without
# expecting ----> VERB ::::: expect
# anything ----> PRON ::::: anything
# return ----> NOUN ::::: return
# . ----> PUNCT ::::: .
# I ----> PRON ::::: I
# should ----> AUX ::::: should
# 've ----> AUX ::::: 've
# given ----> VERB ::::: give
# you ----> PRON ::::: you
# that ----> SCONJ ::::: that
# sugar ----> NOUN ::::: sugar
# cube ----> NOUN ::::: cube
# without ----> ADP ::::: without
# even ----> ADV ::::: even
# thinking ----> VERB ::::: think
# about ----> ADP ::::: about
# a ----> DET ::::: a
# reward ----> NOUN ::::: reward
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Magic ----> PROPN ::::: Magic
# Man ----> PROPN ::::: Man
# : ----> PUNCT ::::: :
# Wrong ----> PROPN ::::: Wrong
# ! ----> PUNCT ::::: !
# [ ----> X ::::: [
# Hurls ----> VERB ::::: hurl
# magic ----> NOUN ::::: magic
# at ----> ADP ::::: at
# them ----> PRON ::::: they
# again ----> ADV ::::: again
# . ----> PUNCT ::::: .
# It ----> PRON ::::: it
# hits ----> VERB ::::: hit
# Finn ----> PROPN ::::: Finn
# in ----> ADP ::::: in
# the ----> DET ::::: the
# face ----> NOUN ::::: face
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Ah ----> INTJ ::::: ah
# , ----> PUNCT ::::: ,
# geez ----> INTJ ::::: geez
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# worried ----> VERB ::::: worry
# ] ----> X ::::: ]
# Finn ----> PROPN ::::: Finn
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# angry ----> ADJ ::::: angry
# ] ----> PUNCT ::::: ]
# You ----> PRON ::::: you
# 've ----> AUX ::::: have
# gifted ----> VERB ::::: gift
# us ----> PRON ::::: we
# nothing ----> PRON ::::: nothing
# but ----> SCONJ ::::: but
# heartache ----> NOUN ::::: heartache
# , ----> PUNCT ::::: ,
# Magic ----> PROPN ::::: Magic
# Man ----> PROPN ::::: Man
# ! ----> PUNCT ::::: !
# What ----> PRON ::::: what
# is ----> AUX ::::: be
# the ----> DET ::::: the
# life ----> NOUN ::::: life
# lesson ----> NOUN ::::: lesson
# in ----> ADP ::::: in
# that ----> PRON ::::: that
# ? ----> PUNCT ::::: ?
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Magic ----> PROPN ::::: Magic
# Man ----> PROPN ::::: Man
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# laughs ----> VERB ::::: laugh
# maniacally ----> ADV ::::: maniacally
# ] ----> PUNCT ::::: ]
# Yes ----> INTJ ::::: yes
# , ----> PUNCT ::::: ,
# my ----> PRON ::::: my
# children ----> NOUN ::::: child
# , ----> PUNCT ::::: ,
# you ----> PRON ::::: you
# are ----> AUX ::::: be
# so ----> ADV ::::: so
# close ----> ADJ ::::: close
# to ----> ADP ::::: to
# the ----> DET ::::: the
# answer ----> NOUN ::::: answer
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Answer ----> VERB ::::: answer
# this ----> PRON ::::: this
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# They ----> PRON ::::: they
# jump ----> VERB ::::: jump
# on ----> ADP ::::: on
# top ----> NOUN ::::: top
# of ----> ADP ::::: of
# Magic ----> PROPN ::::: Magic
# Man ----> PROPN ::::: Man
# . ----> PUNCT ::::: .
# He ----> PRON ::::: he
# is ----> AUX ::::: be
# stuck ----> VERB ::::: stick
# underneath ----> ADP ::::: underneath
# Finn ----> PROPN ::::: Finn
# 's ----> PART ::::: 's
# foot ----> NOUN ::::: foot
# body ----> NOUN ::::: body
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Kim ----> PROPN ::::: Kim
# : ----> PUNCT ::::: :
# Get ----> VERB ::::: get
# his ----> PRON ::::: his
# eyes ----> NOUN ::::: eye
# ! ----> PUNCT ::::: !
# Cut ----> VERB ::::: cut
# him ----> PRON ::::: he
# in ----> ADP ::::: in
# the ----> DET ::::: the
# eyes ----> NOUN ::::: eye
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# wish ----> VERB ::::: wish
# I ----> PRON ::::: I
# 'd ----> AUX ::::: would
# never ----> ADV ::::: never
# been ----> AUX ::::: be
# nice ----> ADJ ::::: nice
# to ----> ADP ::::: to
# you ----> PRON ::::: you
# 'cause ----> SCONJ ::::: 'cause
# you ----> PRON ::::: you
# 're ----> AUX ::::: be
# just ----> ADV ::::: just
# a ----> DET ::::: a
# big ----> ADJ ::::: big
# jerk ----> NOUN ::::: jerk
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Magic ----> PROPN ::::: Magic
# Man ----> PROPN ::::: Man
# : ----> PUNCT ::::: :
# Oh ----> INTJ ::::: oh
# , ----> PUNCT ::::: ,
# yes ----> INTJ ::::: yes
# , ----> PUNCT ::::: ,
# that ----> PRON ::::: that
# 's ----> AUX ::::: be
# it ----> PRON ::::: it
# ! ----> PUNCT ::::: !
# [ ----> X ::::: [
# Slips ----> VERB ::::: slip
# from ----> ADP ::::: from
# under ----> ADP ::::: under
# Finn ----> PROPN ::::: Finn
# 's ----> PART ::::: 's
# foot ----> NOUN ::::: foot
# body ----> NOUN ::::: body
# ] ----> PUNCT ::::: ]
# You ----> PRON ::::: you
# 've ----> AUX ::::: have
# finally ----> ADV ::::: finally
# learned ----> VERB ::::: learn
# your ----> PRON ::::: your
# lesson ----> NOUN ::::: lesson
# . ----> PUNCT ::::: .
# [ ----> X ::::: [
# Zaps ----> VERB ::::: zap
# them ----> PRON ::::: they
# with ----> ADP ::::: with
# magic ----> NOUN ::::: magic
# that ----> PRON ::::: that
# returns ----> VERB ::::: return
# them ----> PRON ::::: they
# back ----> ADV ::::: back
# to ----> ADP ::::: to
# normal ----> ADJ ::::: normal
# ] ----> PUNCT ::::: ]
# And ----> CCONJ ::::: and
# now ----> ADV ::::: now
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# off ----> ADV ::::: off
# spread ----> VERB ::::: spread
# my ----> PRON ::::: my
# teachings ----> NOUN ::::: teaching
# to ----> ADP ::::: to
# more ----> ADJ ::::: more
# sissy ----> NOUN ::::: sissy
# do ----> NOUN ::::: do
# - ----> PUNCT ::::: -
# gooders ----> NOUN ::::: gooder
# . ----> PUNCT ::::: .
# [ ----> X ::::: [
# Opens ----> VERB ::::: open
# a ----> DET ::::: a
# portal ----> NOUN ::::: portal
# to ----> PART ::::: to
# escape ----> VERB ::::: escape
# ] ----> PUNCT ::::: ]
# You ----> PRON ::::: you
# 're ----> AUX ::::: be
# welcome ----> ADJ ::::: welcome
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Man ----> NOUN ::::: man
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# frickin ----> ADJ ::::: frickin
# ' ----> PUNCT ::::: '
# hate ----> VERB ::::: hate
# that ----> DET ::::: that
# guy ----> NOUN ::::: guy
# . ----> PUNCT ::::: .
# But ----> CCONJ ::::: but
# at ----> ADP ::::: at
# least ----> ADJ ::::: least
# now ----> ADV ::::: now
# we ----> PRON ::::: we
# can ----> AUX ::::: can
# all ----> ADV ::::: all
# go ----> VERB ::::: go
# back ----> ADV ::::: back
# to ----> ADP ::::: to
# our ----> PRON ::::: our
# regular ----> ADJ ::::: regular
# lives ----> NOUN ::::: life
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Gork ----> PROPN ::::: Gork
# , ----> PUNCT ::::: ,
# Kim ----> PROPN ::::: Kim
# , ----> PUNCT ::::: ,
# Trudy ----> PROPN ::::: Trudy
# , ----> PUNCT ::::: ,
# Wee ----> PROPN ::::: Wee
# Wee ----> PROPN ::::: Wee
# and ----> CCONJ ::::: and
# Gorflax ----> PROPN ::::: Gorflax
# are ----> AUX ::::: be
# still ----> ADV ::::: still
# voluntarily ----> ADV ::::: voluntarily
# linked ----> VERB ::::: link
# as ----> ADP ::::: as
# a ----> DET ::::: a
# single ----> ADJ ::::: single
# body ----> NOUN ::::: body
# – ----> PUNCT ::::: –
# even ----> ADV ::::: even
# though ----> SCONJ ::::: though
# they ----> PRON ::::: they
# have ----> VERB ::::: have
# their ----> PRON ::::: their
# original ----> ADJ ::::: original
# bodies ----> NOUN ::::: body
# back ----> ADV ::::: back
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Gork ----> PROPN ::::: Gork
# : ----> PUNCT ::::: :
# Well ----> INTJ ::::: well
# , ----> PUNCT ::::: ,
# actually ----> ADV ::::: actually
# , ----> PUNCT ::::: ,
# we ----> PRON ::::: we
# like ----> VERB ::::: like
# being ----> AUX ::::: be
# like ----> ADP ::::: like
# this ----> DET ::::: this
#
#  ----> SPACE :::::
#
# Zap ----> VERB ::::: zap
# : ----> PUNCT ::::: :
# Yeah ----> INTJ ::::: yeah
# , ----> PUNCT ::::: ,
# we ----> PRON ::::: we
# 're ----> AUX ::::: be
# strong ----> ADJ ::::: strong
# together ----> ADV ::::: together
#
#  ----> SPACE :::::
#
# All ----> PRON ::::: all
# : ----> PUNCT ::::: :
# Bye ----> PROPN ::::: Bye
# , ----> PUNCT ::::: ,
# Finn ----> PROPN ::::: Finn
# ! ----> PUNCT ::::: !
# Thank ----> VERB ::::: thank
# you ----> PRON ::::: you
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# They ----> PRON ::::: they
# wave ----> VERB ::::: wave
# and ----> CCONJ ::::: and
# walk ----> VERB ::::: walk
# off ----> ADP ::::: off
# - ----> PUNCT ::::: -
# screen ----> NOUN ::::: screen
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Oh ----> INTJ ::::: oh
# , ----> PUNCT ::::: ,
# okay ----> INTJ ::::: okay
# . ----> PUNCT ::::: .
# Bye ----> INTJ ::::: bye
# , ----> PUNCT ::::: ,
# guys ----> NOUN ::::: guy
# . ----> PUNCT ::::: .
# See ----> VERB ::::: see
# you ----> PRON ::::: you
# , ----> PUNCT ::::: ,
# later ----> ADV ::::: later
# . ----> PUNCT ::::: .
# [ ----> X ::::: [
# Waves ----> NOUN ::::: wave
# back ----> ADV ::::: back
# at ----> ADP ::::: at
# them ----> PRON ::::: they
# ] ----> PUNCT ::::: ]
# Wait ----> VERB ::::: wait
# , ----> PUNCT ::::: ,
# so ----> ADV ::::: so
# , ----> PUNCT ::::: ,
# what ----> PRON ::::: what
# was ----> AUX ::::: be
# the ----> DET ::::: the
# lesson ----> NOUN ::::: lesson
# we ----> PRON ::::: we
# just ----> ADV ::::: just
# learned ----> VERB ::::: learn
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# shrugs ----> VERB ::::: shrug
# ] ----> X ::::: ]
# Maybe ----> ADV ::::: maybe
# it ----> PRON ::::: it
# was ----> AUX ::::: be
# , ----> PUNCT ::::: ,
# do ----> AUX ::::: do
# n't ----> PART ::::: not
# give ----> VERB ::::: give
# your ----> PRON ::::: your
# sugar ----> NOUN ::::: sugar
# to ----> ADP ::::: to
# jerks ----> NOUN ::::: jerk
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# Speaking ----> VERB ::::: speak
# of ----> ADP ::::: of
# jerks ----> NOUN ::::: jerk
# , ----> PUNCT ::::: ,
# what ----> PRON ::::: what
# the ----> DET ::::: the
# blubbins ----> NOUN ::::: blubbin
# , ----> PUNCT ::::: ,
# man ----> NOUN ::::: man
# ? ----> PUNCT ::::: ?
# ! ----> PUNCT ::::: !
# Why ----> SCONJ ::::: why
# would ----> AUX ::::: would
# n't ----> PART ::::: not
# you ----> PRON ::::: you
# help ----> VERB ::::: help
# me ----> PRON ::::: I
# turn ----> VERB ::::: turn
# back ----> ADV ::::: back
# into ----> ADP ::::: into
# a ----> DET ::::: a
# boy ----> NOUN ::::: boy
# ? ----> PUNCT ::::: ?
# ! ----> PUNCT ::::: !
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# Well ----> INTJ ::::: well
# , ----> PUNCT ::::: ,
# because ----> SCONJ ::::: because
# I ----> PRON ::::: I
# kind ----> ADV ::::: kind
# of ----> ADV ::::: of
# always ----> ADV ::::: always
# wanted ----> VERB ::::: want
# [ ----> X ::::: [
# mumbles ----> X ::::: mumbles
# ] ----> SYM ::::: ]
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# What ----> PRON ::::: what
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# [ ----> X ::::: [
# embarrassed ----> ADJ ::::: embarrassed
# ] ----> PUNCT ::::: ]
# I ----> PRON ::::: I
# said ----> VERB ::::: say
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# kind ----> ADV ::::: kind
# of ----> ADV ::::: of
# always ----> ADV ::::: always
# wanted ----> VERB ::::: want
# to ----> PART ::::: to
# be ----> AUX ::::: be
# a ----> DET ::::: a
# foot ----> NOUN ::::: foot
# myself ----> PRON ::::: myself
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Finn ----> PROPN ::::: Finn
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# could ----> AUX ::::: could
# be ----> AUX ::::: be
# a ----> DET ::::: a
# foot ----> NOUN ::::: foot
# right ----> ADV ::::: right
# now ----> ADV ::::: now
# . ----> PUNCT ::::: .
# I ----> PRON ::::: I
# saw ----> VERB ::::: see
# you ----> PRON ::::: you
# change ----> VERB ::::: change
# into ----> ADP ::::: into
# a ----> DET ::::: a
# foot ----> NOUN ::::: foot
# twice ----> ADV ::::: twice
# yesterday ----> NOUN ::::: yesterday
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Finn ----> PROPN ::::: Finn
# and ----> CCONJ ::::: and
# Jake ----> PROPN ::::: Jake
# start ----> VERB ::::: start
# walking ----> VERB ::::: walk
# away ----> ADV ::::: away
# . ----> PUNCT ::::: .
# ] ----> PUNCT ::::: ]
#
#  ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# : ----> PUNCT ::::: :
# It ----> PRON ::::: it
# 's ----> AUX ::::: be
# complicated ----> ADJ ::::: complicated
# , ----> PUNCT ::::: ,
# man ----> NOUN ::::: man
# . ----> PUNCT ::::: .
# You ----> PRON ::::: you
# 'll ----> AUX ::::: will
# understand ----> VERB ::::: understand
# when ----> SCONJ ::::: when
# you ----> PRON ::::: you
# 're ----> AUX ::::: be
# older ----> ADJ ::::: old
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# [ ----> X ::::: [
# Episode ----> NOUN ::::: episode
# ends ----> VERB ::::: end
# ] ----> PUNCT ::::: ]

# %%
# Remember, we can request an explanation from spaCy of its tags: 
spacy.explain("DET")
# Out:
# 'determiner'

# %% [markdown]
# ### Okay, let's select something interesting
#  ...and maybe only collect the lemmas.
#
# Let's do this with a **function** call. We can easily switch the kind of word we want to output this way.
# Here we are starting to associate words wtih volumes...we're going to refine that by making a dataframe next.

# %%
def wordCollector(words, unit):
    wordList = []
    for token in words:
        if token.pos_ == "ADJ":
            wordList.append((token.lemma_, unit))
    uniqueLems = set(wordList)
    return uniqueLems

for file in os.listdir(collPath):
    if file.endswith(".txt"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            spacyRead = nlp(readFile)
            myWords = wordCollector(spacyRead, name)
            print(myWords)
# Out:
# {('nice', 'ATE11'), ('ancient', 'ATE11'), ('ready', 'ATE11'), ('good', 'ATE11'), ('limitless', 'ATE11'), ('left', 'ATE11'), ('alive', 'ATE11'), ('free', 'ATE11'), ('very', 'ATE11'), ('full', 'ATE11'), ('lame', 'ATE11'), ('dimensional', 'ATE11'), ('true', 'ATE11'), ('total', 'ATE11'), ('annoyed', 'ATE11'), ('magical', 'ATE11'), ('normal', 'ATE11'), ('radical', 'ATE11'), ('mystical', 'ATE11'), ('entire', 'ATE11'), ('desperate', 'ATE11'), ('big', 'ATE11'), ('last', 'ATE11'), ('responsible', 'ATE11'), ('more', 'ATE11'), ('same', 'ATE11'), ('next', 'ATE11'), ('hysterical', 'ATE11'), ('crazy', 'ATE11'), ('ultimate', 'ATE11'), ('few', 'ATE11'), ('naked', 'ATE11'), ('fake', 'ATE11'), ('evil', 'ATE11'), ('close', 'ATE11'), ('dangerous', 'ATE11'), ('star', 'ATE11'), ('foul', 'ATE11'), ('right', 'ATE11'), ('magic', 'ATE11'), ('third', 'ATE11'), ('animate', 'ATE11'), ('orange', 'ATE11'), ('new', 'ATE11'), ('asleep', 'ATE11'), ('disgusted', 'ATE11'), ('easy', 'ATE11'), ('well', 'ATE11'), ('main', 'ATE11'), ('lifeless', 'ATE11'), ('embarrassed', 'ATE11'), ('old', 'ATE11'), ('natural', 'ATE11'), ('tilted', 'ATE11'), ('gross', 'ATE11'), ('frustrated', 'ATE11'), ('familiar', 'ATE11'), ('sure', 'ATE11'), ('unattractive', 'ATE11'), ('unhappy', 'ATE11'), ('bouncy', 'ATE11'), ('young', 'ATE11'), ('eld', 'ATE11'), ('Most', 'ATE11'), ('newfangled', 'ATE11'), ('excellent', 'ATE11'), ('amazed', 'ATE11'), ('giant', 'ATE11'), ('glorious', 'ATE11'), ('final', 'ATE11'), ('rash', 'ATE11'), ('powerful', 'ATE11'), ('stupid', 'ATE11'), ('cool', 'ATE11'), ('sunken', 'ATE11'), ('other', 'ATE11'), ('okay', 'ATE11'), ('glad', 'ATE11'), ('fine', 'ATE11')}
# {('beautiful', 'ATE10'), ('stuck', 'ATE10'), ('maddening', 'ATE10'), ('entire', 'ATE10'), ('own', 'ATE10'), ('many', 'ATE10'), ('ohhhhhhhh', 'ATE10'), ('healthy', 'ATE10'), ('dirty', 'ATE10'), ('right', 'ATE10'), ('sorry', 'ATE10'), ('raw', 'ATE10'), ('cold', 'ATE10'), ('sure', 'ATE10'), ('cool', 'ATE10'), ('little', 'ATE10'), ('happy', 'ATE10'), ('other', 'ATE10'), ('different', 'ATE10'), ('first', 'ATE10'), ('several', 'ATE10'), ('squid', 'ATE10'), ('great', 'ATE10'), ('okay', 'ATE10'), ('second', 'ATE10'), ('well', 'ATE10'), ('fine', 'ATE10'), ('soooo', 'ATE10'), ('itchy', 'ATE10'), ('tough', 'ATE10'), ('rough', 'ATE10'), ('bad', 'ATE10'), ('terrible', 'ATE10'), ('gorgeous', 'ATE10'), ('ready', 'ATE10'), ('good', 'ATE10'), ('raunchy', 'ATE10'), ('small', 'ATE10'), ('old', 'ATE10'), ('disgusting', 'ATE10'), ('more', 'ATE10'), ('pet', 'ATE10'), ('human', 'ATE10'), ('awesome', 'ATE10'), ('crazy', 'ATE10'), ('half', 'ATE10'), ('smooth', 'ATE10'), ('wrong', 'ATE10'), ('corny', 'ATE10'), ('hearted', 'ATE10'), ('rashy', 'ATE10'), ('real', 'ATE10'), ('serious', 'ATE10'), ('long', 'ATE10'), ('sad', 'ATE10'), ('quiet', 'ATE10'), ('fair', 'ATE10'), ('slight', 'ATE10'), ('least', 'ATE10'), ('naked', 'ATE10'), ('fantastic', 'ATE10'), ('perfect', 'ATE10')}
# {('good', 'ATE12'), ('wonderful', 'ATE12'), ('old', 'ATE12'), ('lucky', 'ATE12'), ('bla', 'ATE12'), ('awesome', 'ATE12'), ('fun', 'ATE12'), ('wrong', 'ATE12'), ('very', 'ATE12'), ('full', 'ATE12'), ('nuts', 'ATE12'), ('weak', 'ATE12'), ('exhausted', 'ATE12'), ('reliable', 'ATE12'), ('honest', 'ATE12'), ('true', 'ATE12'), ('total', 'ATE12'), ('giant', 'ATE12'), ('pretty', 'ATE12'), ('scary', 'ATE12'), ('hardcore', 'ATE12'), ('gross', 'ATE12'), ('satisfied', 'ATE12'), ('right', 'ATE12'), ('wild', 'ATE12'), ('unprepared', 'ATE12'), ('feelin', 'ATE12'), ('ready', 'ATE12'), ('scared', 'ATE12'), ('goldfish', 'ATE12'), ('convinced', 'ATE12'), ('new', 'ATE12'), ('pathetic', 'ATE12'), ('little', 'ATE12'), ('cool', 'ATE12'), ('vaporized', 'ATE12'), ('warm', 'ATE12'), ('great', 'ATE12'), ('ble', 'ATE12'), ('dead', 'ATE12'), ('well', 'ATE12'), ('afraid', 'ATE12'), ('ordinary', 'ATE12'), ('tired', 'ATE12'), ('open', 'ATE12'), ('mysterious', 'ATE12')}
# {('asleep', 'ATE13'), ('different', 'ATE13'), ('top', 'ATE13'), ('other', 'ATE13'), ('black', 'ATE13'), ('okay', 'ATE13'), ('great', 'ATE13'), ('easy', 'ATE13'), ('dead', 'ATE13'), ('second', 'ATE13'), ('afraid', 'ATE13'), ('hopeless', 'ATE13'), ('about', 'ATE13'), ('light', 'ATE13'), ('much', 'ATE13'), ('wicked', 'ATE13'), ('clean', 'ATE13'), ('terrible', 'ATE13'), ('young', 'ATE13'), ('ready', 'ATE13'), ('redoodoodiculous', 'ATE13'), ('super', 'ATE13'), ('alone', 'ATE13'), ('good', 'ATE13'), ('headed', 'ATE13'), ('impure', 'ATE13'), ('criminal', 'ATE13'), ('fun', 'ATE13'), ('pure', 'ATE13'), ('wrong', 'ATE13'), ('enough', 'ATE13'), ('unfit', 'ATE13'), ('squeaky', 'ATE13'), ('blue', 'ATE13'), ('nearby', 'ATE13'), ('giant', 'ATE13'), ('slow', 'ATE13'), ('whole', 'ATE13'), ('magical', 'ATE13'), ('poor', 'ATE13'), ('aoh', 'ATE13'), ('high', 'ATE13'), ('naked', 'ATE13'), ('able', 'ATE13'), ('welcome', 'ATE13'), ('red', 'ATE13'), ('only', 'ATE13'), ('-', 'ATE13'), ('hard', 'ATE13'), ('right', 'ATE13'), ('dirty', 'ATE13'), ('filthy', 'ATE13'), ('sorry', 'ATE13'), ('crooked', 'ATE13'), ('cute', 'ATE13'), ('big', 'ATE13'), ('homeless', 'ATE13'), ('virgin', 'ATE13'), ('new', 'ATE13'), ('stupid', 'ATE13'), ('little', 'ATE13')}
# {('pretty', 'ATE17'), ('giant', 'ATE17'), ('huge', 'ATE17'), ('normal', 'ATE17'), ('angry', 'ATE17'), ('female', 'ATE17'), ('gross', 'ATE17'), ('threatening', 'ATE17'), ('beautiful', 'ATE17'), ('weird', 'ATE17'), ('comfortable', 'ATE17'), ('prepared', 'ATE17'), ('up—80', 'ATE17'), ('right', 'ATE17'), ('double', 'ATE17'), ('traditional', 'ATE17'), ('sweet', 'ATE17'), ('stinky', 'ATE17'), ('big', 'ATE17'), ('nervous', 'ATE17'), ('allergic', 'ATE17'), ('sure', 'ATE17'), ('stupid', 'ATE17'), ('large', 'ATE17'), ('cool', 'ATE17'), ('happy', 'ATE17'), ('hot', 'ATE17'), ('sized', 'ATE17'), ('other', 'ATE17'), ('different', 'ATE17'), ('male', 'ATE17'), ('black', 'ATE17'), ('last', 'ATE17'), ('okay', 'ATE17'), ('official', 'ATE17'), ('glad', 'ATE17'), ('fine', 'ATE17'), ('well', 'ATE17'), ('about', 'ATE17'), ('worth', 'ATE17'), ('open', 'ATE17'), ("y'know", 'ATE17'), ('bad', 'ATE17'), ('ready', 'ATE17'), ('old', 'ATE17'), ('glazed', 'ATE17'), ('nearby', 'ATE17'), ('good', 'ATE17'), ('same', 'ATE17'), ('lucky', 'ATE17'), ('more', 'ATE17'), ('spontaneous', 'ATE17'), ('creepy', 'ATE17'), ('crazy', 'ATE17'), ('wrong', 'ATE17'), ('married', 'ATE17'), ('lousy', 'ATE17'), ('spiky', 'ATE17'), ('serious', 'ATE17'), ('free', 'ATE17'), ('lame', 'ATE17'), ('bored', 'ATE17'), ('total', 'ATE17')}
# {('normal', 'ATE16'), ('slow', 'ATE16'), ('few', 'ATE16'), ('pretty', 'ATE16'), ('least', 'ATE16'), ('gross', 'ATE16'), ('multiple', 'ATE16'), ('perfect', 'ATE16'), ('beautiful', 'ATE16'), ('proud', 'ATE16'), ('red', 'ATE16'), ('entire', 'ATE16'), ('own', 'ATE16'), ('-', 'ATE16'), ('right', 'ATE16'), ('heroic', 'ATE16'), ('scared', 'ATE16'), ('pre', 'ATE16'), ('underwater', 'ATE16'), ('late', 'ATE16'), ('barefoot', 'ATE16'), ('war', 'ATE16'), ('sure', 'ATE16'), ('pathetic', 'ATE16'), ('hot', 'ATE16'), ('cool', 'ATE16'), ('black', 'ATE16'), ('single', 'ATE16'), ('great', 'ATE16'), ('afraid', 'ATE16'), ('panting', 'ATE16'), ('glad', 'ATE16'), ('un', 'ATE16'), ('about', 'ATE16'), ('ok', 'ATE16'), ('bad', 'ATE16'), ('rusty', 'ATE16'), ('safe', 'ATE16'), ('dark', 'ATE16'), ('ready', 'ATE16'), ('good', 'ATE16'), ('wonderful', 'ATE16'), ('small', 'ATE16'), ('more', 'ATE16'), ('awesome', 'ATE16'), ('crazy', 'ATE16'), ('deep', 'ATE16'), ('nasty', 'ATE16'), ('wrong', 'ATE16'), ('wuss', 'ATE16'), ('maniacal', 'ATE16'), ('nuts', 'ATE16'), ('ominous', 'ATE16'), ('true', 'ATE16'), ('rapid', 'ATE16')}
# {('other', 'ATE14'), ('first', 'ATE14'), ('prideful', 'ATE14'), ('cool', 'ATE14'), ('black', 'ATE14'), ('dyin', 'ATE14'), ('okay', 'ATE14'), ('great', 'ATE14'), ('easy', 'ATE14'), ('energetic', 'ATE14'), ('glad', 'ATE14'), ('clear', 'ATE14'), ('tired', 'ATE14'), ('bad', 'ATE14'), ('much', 'ATE14'), ('current', 'ATE14'), ('poisonous', 'ATE14'), ('good', 'ATE14'), ('old', 'ATE14'), ('lucky', 'ATE14'), ('more', 'ATE14'), ('ideal', 'ATE14'), ('powerless', 'ATE14'), ('hungry', 'ATE14'), ('regular', 'ATE14'), ('deep', 'ATE14'), ('kinda', 'ATE14'), ('lazy', 'ATE14'), ('subconscious', 'ATE14'), ('chilly', 'ATE14'), ('wrong', 'ATE14'), ('alive', 'ATE14'), ('humiliating', 'ATE14'), ('full', 'ATE14'), ('exhausting', 'ATE14'), ('magical', 'ATE14'), ('whole', 'ATE14'), ('humble', 'ATE14'), ('true', 'ATE14'), ('total', 'ATE14'), ('annoyed', 'ATE14'), ('giant', 'ATE14'), ('cutesy', 'ATE14'), ('alright', 'ATE14'), ('ergh', 'ATE14'), ('various', 'ATE14'), ('locked', 'ATE14'), ('evil', 'ATE14'), ('ironic', 'ATE14'), ('gross', 'ATE14'), ('beautiful', 'ATE14'), ('weird', 'ATE14'), ('magic', 'ATE14'), ('many', 'ATE14'), ('only', 'ATE14'), ('hard', 'ATE14'), ('right', 'ATE14'), ('desperate', 'ATE14'), ('fat', 'ATE14'), ('sorry', 'ATE14'), ('industrial', 'ATE14'), ('big', 'ATE14'), ('cute', 'ATE14'), ('chubby', 'ATE14'), ('stupid', 'ATE14'), ('large', 'ATE14'), ('little', 'ATE14')}
# {('functional', 'ATE15'), ('hot', 'ATE15'), ('troubled', 'ATE15'), ('innocent', 'ATE15'), ('stupid', 'ATE15'), ('little', 'ATE15'), ('asleep', 'ATE15'), ('different', 'ATE15'), ('great', 'ATE15'), ('unsettling', 'ATE15'), ('well', 'ATE15'), ('melty', 'ATE15'), ('about', 'ATE15'), ('private', 'ATE15'), ('young', 'ATE15'), ('terrible', 'ATE15'), ('good', 'ATE15'), ('daring', 'ATE15'), ('small', 'ATE15'), ('lucky', 'ATE15'), ('eager', 'ATE15'), ('more', 'ATE15'), ('awesome', 'ATE15'), ('funny', 'ATE15'), ('deep', 'ATE15'), ('long', 'ATE15'), ('full', 'ATE15'), ('dumb', 'ATE15'), ('free', 'ATE15'), ('very', 'ATE15'), ('awake', 'ATE15'), ('heavy', 'ATE15'), ('imaginary', 'ATE15'), ('personal', 'ATE15'), ('normal', 'ATE15'), ('hardcore', 'ATE15'), ('crybaby', 'ATE15'), ('perfect', 'ATE15'), ('angry', 'ATE15'), ('female', 'ATE15'), ('mortal', 'ATE15'), ('semi', 'ATE15'), ('loyal', 'ATE15'), ('beautiful', 'ATE15'), ('sudden', 'ATE15'), ('frustrated', 'ATE15'), ('right', 'ATE15'), ('magic', 'ATE15'), ('mock', 'ATE15'), ('-', 'ATE15'), ('hard', 'ATE15'), ('low', 'ATE15'), ('big', 'ATE15'), ('fat', 'ATE15'), ('cold', 'ATE15')}
# {('terrible', 'ATE1'), ('tasty', 'ATE1'), ('convenient', 'ATE1'), ('delicious', 'ATE1'), ('permanent', 'ATE1'), ('young', 'ATE1'), ('simple', 'ATE1'), ('good', 'ATE1'), ('old', 'ATE1'), ('super', 'ATE1'), ('correct', 'ATE1'), ('alone', 'ATE1'), ('more', 'ATE1'), ('important', 'ATE1'), ('crazy', 'ATE1'), ('deep', 'ATE1'), ('smart', 'ATE1'), ('wrong', 'ATE1'), ('incomplete', 'ATE1'), ('momentous', 'ATE1'), ('ignorant', 'ATE1'), ('full', 'ATE1'), ('nuts', 'ATE1'), ('present', 'ATE1'), ('blindfolded', 'ATE1'), ('awake', 'ATE1'), ('whole', 'ATE1'), ('adorable', 'ATE1'), ('pretty', 'ATE1'), ('giant', 'ATE1'), ('least', 'ATE1'), ('alright', 'ATE1'), ('complicated', 'ATE1'), ('ok', 'ATE1'), ('saucy', 'ATE1'), ('welcome', 'ATE1'), ('former', 'ATE1'), ('healthy', 'ATE1'), ('right', 'ATE1'), ('sweet', 'ATE1'), ('improbable', 'ATE1'), ('scared', 'ATE1'), ('cute', 'ATE1'), ('big', 'ATE1'), ('sure', 'ATE1'), ('new', 'ATE1'), ('stupid', 'ATE1'), ('large', 'ATE1'), ('hot', 'ATE1'), ('explosive', 'ATE1'), ('cool', 'ATE1'), ('different', 'ATE1'), ('first', 'ATE1'), ('unaffected', 'ATE1'), ('royal', 'ATE1'), ('great', 'ATE1'), ('last', 'ATE1'), ('easy', 'ATE1'), ('dead', 'ATE1'), ('well', 'ATE1'), ('tough', 'ATE1'), ('main', 'ATE1'), ('bad', 'ATE1')}
# {('shaggy', 'ATE3'), ('small', 'ATE3'), ('same', 'ATE3'), ('more', 'ATE3'), ('dear', 'ATE3'), ('fun', 'ATE3'), ('wrong', 'ATE3'), ('potential', 'ATE3'), ('free', 'ATE3'), ('serious', 'ATE3'), ('sad', 'ATE3'), ('nuts', 'ATE3'), ('lame', 'ATE3'), ('bored', 'ATE3'), ('high', 'ATE3'), ('giant', 'ATE3'), ('alright', 'ATE3'), ('quirky', 'ATE3'), ('naked', 'ATE3'), ('star', 'ATE3'), ('angry', 'ATE3'), ('gross', 'ATE3'), ('welcome', 'ATE3'), ('entire', 'ATE3'), ('captive', 'ATE3'), ('front', 'ATE3'), ('right', 'ATE3'), ('possible', 'ATE3'), ('magic', 'ATE3'), ('hard', 'ATE3'), ('sweet', 'ATE3'), ('sorry', 'ATE3'), ('big', 'ATE3'), ('sure', 'ATE3'), ('electric', 'ATE3'), ('hot', 'ATE3'), ('cool', 'ATE3'), ('little', 'ATE3'), ('other', 'ATE3'), ('first', 'ATE3'), ('plastic', 'ATE3'), ('holy', 'ATE3'), ('last', 'ATE3'), ('okay', 'ATE3'), ('fine', 'ATE3'), ('ticklish', 'ATE3'), ('worried', 'ATE3'), ('middle', 'ATE3'), ('favorite', 'ATE3'), ('sexy', 'ATE3'), ('much', 'ATE3'), ('young', 'ATE3'), ('simple', 'ATE3'), ('good', 'ATE3')}
# {('last', 'ATE2'), ('weekly', 'ATE2'), ('non', 'ATE2'), ('mad', 'ATE2'), ('baaaaad', 'ATE2'), ('easy', 'ATE2'), ('romantic', 'ATE2'), ('up', 'ATE2'), ('fine', 'ATE2'), ('rude', 'ATE2'), ('lumpy', 'ATE2'), ('royal', 'ATE2'), ('much', 'ATE2'), ('gracious', 'ATE2'), ('nice', 'ATE2'), ('bad', 'ATE2'), ('terrible', 'ATE2'), ('lumpers', 'ATE2'), ("y'know", 'ATE2'), ('good', 'ATE2'), ('sheer', 'ATE2'), ('electronic', 'ATE2'), ('more', 'ATE2'), ('freakin', 'ATE2'), ('awesome', 'ATE2'), ('insane', 'ATE2'), ('drunk', 'ATE2'), ('muffled', 'ATE2'), ('smooth', 'ATE2'), ('muscular', 'ATE2'), ('serious', 'ATE2'), ('wannabe', 'ATE2'), ('dumb', 'ATE2'), ('shady', 'ATE2'), ('lame', 'ATE2'), ('ominous', 'ATE2'), ('horrible', 'ATE2'), ('fake', 'ATE2'), ('normal', 'ATE2'), ('dangerous', 'ATE2'), ('close', 'ATE2'), ('multiple', 'ATE2'), ('welcome', 'ATE2'), ('notorious', 'ATE2'), ('right', 'ATE2'), ('eternal', 'ATE2'), ('-', 'ATE2'), ('sorry', 'ATE2'), ('hard', 'ATE2'), ('early', 'ATE2'), ('big', 'ATE2'), ('cold', 'ATE2'), ('plaintive', 'ATE2'), ('directionless', 'ATE2'), ('new', 'ATE2'), ('hot', 'ATE2'), ('sure', 'ATE2')}
# {('sweet', 'ATE6'), ('sick', 'ATE6'), ('cold', 'ATE6'), ('new', 'ATE6'), ('little', 'ATE6'), ('cool', 'ATE6'), ('hot', 'ATE6'), ('other', 'ATE6'), ('different', 'ATE6'), ('jiggly', 'ATE6'), ('holy', 'ATE6'), ('several', 'ATE6'), ('loose', 'ATE6'), ('extraordinary', 'ATE6'), ('dead', 'ATE6'), ('fine', 'ATE6'), ('well', 'ATE6'), ('tough', 'ATE6'), ('favorite', 'ATE6'), ('tired', 'ATE6'), ('ok', 'ATE6'), ('bad', 'ATE6'), ('quick', 'ATE6'), ('terrible', 'ATE6'), ('safe', 'ATE6'), ('ready', 'ATE6'), ('unknown', 'ATE6'), ('good', 'ATE6'), ('comfy', 'ATE6'), ('small', 'ATE6'), ('strange', 'ATE6'), ('limp', 'ATE6'), ('more', 'ATE6'), ('purple', 'ATE6'), ('awesome', 'ATE6'), ('like', 'ATE6'), ('distressed', 'ATE6'), ('crazy', 'ATE6'), ('wrong', 'ATE6'), ('nuts', 'ATE6'), ('doooowwwn', 'ATE6'), ('pink', 'ATE6'), ('weak', 'ATE6'), ('least', 'ATE6'), ('fair', 'ATE6'), ('adorable', 'ATE6'), ('enraged', 'ATE6'), ('normal', 'ATE6'), ('various', 'ATE6'), ('angry', 'ATE6'), ('able', 'ATE6'), ('weird', 'ATE6'), ('right', 'ATE6'), ('own', 'ATE6'), ('many', 'ATE6'), ('globular', 'ATE6'), ('wild', 'ATE6')}
# {('wonderful', 'ATE7'), ('wicked', 'ATE7'), ('nice', 'ATE7'), ('dark', 'ATE7'), ('current', 'ATE7'), ('pro', 'ATE7'), ('ready', 'ATE7'), ('ancient', 'ATE7'), ('super', 'ATE7'), ('old', 'ATE7'), ('focused', 'ATE7'), ('consensual', 'ATE7'), ('alone', 'ATE7'), ('naive', 'ATE7'), ('good', 'ATE7'), ('plasmodial', 'ATE7'), ('complete', 'ATE7'), ('next', 'ATE7'), ('independent', 'ATE7'), ('deep', 'ATE7'), ('smart', 'ATE7'), ('wrong', 'ATE7'), ('suspicious', 'ATE7'), ('funny', 'ATE7'), ('serious', 'ATE7'), ('pink', 'ATE7'), ('less', 'ATE7'), ('fragile', 'ATE7'), ('weak', 'ATE7'), ('full', 'ATE7'), ('twisty', 'ATE7'), ('annoyed', 'ATE7'), ('total', 'ATE7'), ('ridiculous', 'ATE7'), ('engaging', 'ATE7'), ('irritated', 'ATE7'), ('normal', 'ATE7'), ('sinister', 'ATE7'), ('evil', 'ATE7'), ('posterior', 'ATE7'), ('alright', 'ATE7'), ('threatening', 'ATE7'), ('weird', 'ATE7'), ('welcome', 'ATE7'), ('own', 'ATE7'), ('-', 'ATE7'), ('right', 'ATE7'), ('jealous', 'ATE7'), ('low', 'ATE7'), ('cute', 'ATE7'), ('big', 'ATE7'), ('balbaflonic', 'ATE7'), ('new', 'ATE7'), ('powerful', 'ATE7'), ('foldy', 'ATE7'), ('little', 'ATE7'), ('foolish', 'ATE7'), ('enervated', 'ATE7'), ('holy', 'ATE7'), ('other', 'ATE7'), ('villainous', 'ATE7'), ('great', 'ATE7'), ('dead', 'ATE7'), ('dramatic', 'ATE7'), ('glad', 'ATE7'), ('romantic', 'ATE7'), ('bad', 'ATE7')}
# {('blue', 'ATE5'), ('treacherous', 'ATE5'), ('real', 'ATE5'), ('opposite', 'ATE5'), ('sad', 'ATE5'), ('magical', 'ATE5'), ('grueling', 'ATE5'), ('wrongteous', 'ATE5'), ('giant', 'ATE5'), ('true', 'ATE5'), ('high', 'ATE5'), ('alright', 'ATE5'), ('menacing', 'ATE5'), ('weird', 'ATE5'), ('evil', 'ATE5'), ('certain', 'ATE5'), ('red', 'ATE5'), ('unaligned', 'ATE5'), ('noble', 'ATE5'), ('welcome', 'ATE5'), ('manly', 'ATE5'), ('many', 'ATE5'), ('sweet', 'ATE5'), ('-', 'ATE5'), ('heroic', 'ATE5'), ('final', 'ATE5'), ('sorry', 'ATE5'), ('impossible', 'ATE5'), ('key', 'ATE5'), ('big', 'ATE5'), ('cute', 'ATE5'), ('little', 'ATE5'), ('other', 'ATE5'), ('black', 'ATE5'), ('first', 'ATE5'), ('worthy', 'ATE5'), ('last', 'ATE5'), ('okay', 'ATE5'), ('dead', 'ATE5'), ('yellow', 'ATE5'), ('just', 'ATE5'), ('most', 'ATE5'), ('marvelous', 'ATE5'), ('fine', 'ATE5'), ('ok', 'ATE5'), ('gray', 'ATE5'), ('devil', 'ATE5'), ('open', 'ATE5'), ('safe', 'ATE5'), ('neutral', 'ATE5'), ('young', 'ATE5'), ('ready', 'ATE5'), ('wonderful', 'ATE5'), ('old', 'ATE5'), ('disembodied', 'ATE5'), ('good', 'ATE5'), ('small', 'ATE5'), ('more', 'ATE5'), ('mannish', 'ATE5'), ('aware', 'ATE5'), ('crazy', 'ATE5'), ('distressed', 'ATE5'), ('secret', 'ATE5'), ('regular', 'ATE5'), ('righteous', 'ATE5'), ('human', 'ATE5'), ('alive', 'ATE5'), ('la', 'ATE5'), ('smart', 'ATE5'), ('long', 'ATE5')}
# {('rare', 'ATE4'), ('perfect', 'ATE4'), ('magic', 'ATE4'), ('own', 'ATE4'), ('satisfied', 'ATE4'), ('many', 'ATE4'), ('-', 'ATE4'), ('sorry', 'ATE4'), ('cute', 'ATE4'), ('big', 'ATE4'), ('womanly', 'ATE4'), ('sure', 'ATE4'), ('new', 'ATE4'), ('stupid', 'ATE4'), ('little', 'ATE4'), ('cool', 'ATE4'), ('careful', 'ATE4'), ('top', 'ATE4'), ('mad', 'ATE4'), ('oww', 'ATE4'), ('okay', 'ATE4'), ('well', 'ATE4'), ('fine', 'ATE4'), ('holographic', 'ATE4'), ('shocking', 'ATE4'), ('nice', 'ATE4'), ('sexy', 'ATE4'), ('terrible', 'ATE4'), ('delicious', 'ATE4'), ('crummy', 'ATE4'), ('upset', 'ATE4'), ('good', 'ATE4'), ('old', 'ATE4'), ('super', 'ATE4'), ('precious', 'ATE4'), ('lonely', 'ATE4'), ('bonkers', 'ATE4'), ('awesome', 'ATE4'), ('deep', 'ATE4'), ('squishy', 'ATE4'), ('enough', 'ATE4'), ('outer', 'ATE4'), ('weak', 'ATE4'), ('lame', 'ATE4'), ('horrible', 'ATE4'), ('total', 'ATE4'), ('high', 'ATE4'), ('pretty', 'ATE4'), ('huge', 'ATE4'), ('evil', 'ATE4')}
# {('good', 'ATE9'), ('old', 'ATE9'), ('small', 'ATE9'), ('next', 'ATE9'), ('same', 'ATE9'), ('silent', 'ATE9'), ('universal', 'ATE9'), ('funn', 'ATE9'), ('deadly', 'ATE9'), ('more', 'ATE9'), ('awesome', 'ATE9'), ('crazy', 'ATE9'), ('like', 'ATE9'), ('ooor', 'ATE9'), ('blue', 'ATE9'), ('free', 'ATE9'), ('쟤가', 'ATE9'), ('sad', 'ATE9'), ('magical', 'ATE9'), ('whole', 'ATE9'), ('normal', 'ATE9'), ('few', 'ATE9'), ('grungy', 'ATE9'), ('naked', 'ATE9'), ('least', 'ATE9'), ('huge', 'ATE9'), ('evil', 'ATE9'), ('angry', 'ATE9'), ('able', 'ATE9'), ('timeless', 'ATE9'), ('flat', 'ATE9'), ('beautiful', 'ATE9'), ('nerdy', 'ATE9'), ('weird', 'ATE9'), ('뛰어다닌', 'ATE9'), ('many', 'ATE9'), ('scratchy', 'ATE9'), ('indistinguishable', 'ATE9'), ('right', 'ATE9'), ('front', 'ATE9'), ('jealous', 'ATE9'), ('sweet', 'ATE9'), ('sorry', 'ATE9'), ('late', 'ATE9'), ('hurt', 'ATE9'), ('있었을까', 'ATE9'), ('back', 'ATE9'), ('wavy', 'ATE9'), ('rocky', 'ATE9'), ('little', 'ATE9'), ('cool', 'ATE9'), ('tender', 'ATE9'), ('stupid', 'ATE9'), ('other', 'ATE9'), ('alien', 'ATE9'), ('startled', 'ATE9'), ('idiot', 'ATE9'), ('green', 'ATE9'), ('mad', 'ATE9'), ('incredible', 'ATE9'), ('great', 'ATE9'), ('okay', 'ATE9'), ('dead', 'ATE9'), ('nice', 'ATE9'), ('much', 'ATE9'), ('disturbed', 'ATE9'), ('harsh', 'ATE9')}
# {('poor', 'ATE8'), ('weird', 'ATE8'), ('able', 'ATE8'), ('red', 'ATE8'), ('right', 'ATE8'), ('sharp', 'ATE8'), ('fat', 'ATE8'), ('resilient', 'ATE8'), ('hard', 'ATE8'), ('orange', 'ATE8'), ('big', 'ATE8'), ('chubby', 'ATE8'), ('rewarding', 'ATE8'), ('large', 'ATE8'), ('excited', 'ATE8'), ('happy', 'ATE8'), ('stinkin', 'ATE8'), ('hot', 'ATE8'), ('unhappy', 'ATE8'), ('several', 'ATE8'), ('other', 'ATE8'), ('different', 'ATE8'), ('great', 'ATE8'), ('second', 'ATE8'), ('single', 'ATE8'), ('hind', 'ATE8'), ('adequate', 'ATE8'), ('radd', 'ATE8'), ('ok', 'ATE8'), ('tired', 'ATE8'), ('later', 'ATE8'), ('bottled', 'ATE8'), ('nice', 'ATE8'), ('ready', 'ATE8'), ('old', 'ATE8'), ('buncha', 'ATE8'), ('shiny', 'ATE8'), ('clean', 'ATE8'), ('complete', 'ATE8'), ('good', 'ATE8'), ('murmur', 'ATE8'), ('small', 'ATE8'), ('more', 'ATE8'), ('moldable', 'ATE8'), ('creepy', 'ATE8'), ('annoying', 'ATE8'), ('enormous', 'ATE8'), ('enough', 'ATE8'), ('lazy', 'ATE8'), ('awesome', 'ATE8'), ('crazy', 'ATE8'), ('fun', 'ATE8'), ('visible', 'ATE8'), ('attractive', 'ATE8'), ('horrible', 'ATE8'), ('full', 'ATE8'), ('ugly', 'ATE8'), ('frickin', 'ATE8'), ('free', 'ATE8'), ('fast', 'ATE8'), ('stark', 'ATE8'), ('empty', 'ATE8'), ('giant', 'ATE8'), ('huge', 'ATE8'), ('normal', 'ATE8'), ('efficient', 'ATE8'), ('true', 'ATE8'), ('legit', 'ATE8'), ('various', 'ATE8')}
# {('further', 'ATE18'), ('intelligent', 'ATE18'), ('black', 'ATE18'), ('different', 'ATE18'), ('green', 'ATE18'), ('last', 'ATE18'), ('freaky', 'ATE18'), ('okay', 'ATE18'), ('sick', 'ATE18'), ('thine', 'ATE18'), ('powdered', 'ATE18'), ('afraid', 'ATE18'), ('single', 'ATE18'), ('silly', 'ATE18'), ('fine', 'ATE18'), ('well', 'ATE18'), ('about', 'ATE18'), ('skeletal', 'ATE18'), ('worried', 'ATE18'), ('royal', 'ATE18'), ('idiot', 'ATE18'), ('raspy', 'ATE18'), ('gelatinous', 'ATE18'), ('ready', 'ATE18'), ('old', 'ATE18'), ('good', 'ATE18'), ('small', 'ATE18'), ('more', 'ATE18'), ('approximate', 'ATE18'), ('strange', 'ATE18'), ('accursed', 'ATE18'), ('secret', 'ATE18'), ('awesome', 'ATE18'), ('deep', 'ATE18'), ('muffled', 'ATE18'), ('long', 'ATE18'), ('awake', 'ATE18'), ('full', 'ATE18'), ('hideous', 'ATE18'), ('frustrating', 'ATE18'), ('darn', 'ATE18'), ('giant', 'ATE18'), ('huge', 'ATE18'), ('few', 'ATE18'), ('heavy', 'ATE18'), ('true', 'ATE18'), ('farth', 'ATE18'), ('angry', 'ATE18'), ('dangerous', 'ATE18'), ('evil', 'ATE18'), ('radical', 'ATE18'), ('own', 'ATE18'), ('comfortable', 'ATE18'), ('beautiful', 'ATE18'), ('right', 'ATE18'), ('many', 'ATE18'), ('sweet', 'ATE18'), ('exponential', 'ATE18'), ('demonic', 'ATE18'), ('magnificent', 'ATE18'), ('key', 'ATE18'), ('big', 'ATE18'), ('nervous', 'ATE18'), ('low', 'ATE18'), ('scared', 'ATE18'), ('impossible', 'ATE18'), ('mimic', 'ATE18'), ('*', 'ATE18'), ('pathetic', 'ATE18'), ('little', 'ATE18')}
# {('sweet', 'ATE24'), ('sorry', 'ATE24'), ('sick', 'ATE24'), ('sure', 'ATE24'), ('new', 'ATE24'), ('happy', 'ATE24'), ('common', 'ATE24'), ('straight', 'ATE24'), ('other', 'ATE24'), ('first', 'ATE24'), ('shrunken', 'ATE24'), ('well', 'ATE24'), ('dead', 'ATE24'), ('glad', 'ATE24'), ('awful', 'ATE24'), ('bad', 'ATE24'), ('recent', 'ATE24'), ('worth', 'ATE24'), ('much', 'ATE24'), ('lifeless', 'ATE24'), ('pained', 'ATE24'), ('dark', 'ATE24'), ('terrible', 'ATE24'), ('mean', 'ATE24'), ('ready', 'ATE24'), ('fist', 'ATE24'), ('old', 'ATE24'), ('own', 'ATE24'), ('deserted', 'ATE24'), ('good', 'ATE24'), ('more', 'ATE24'), ('crazy', 'ATE24'), ('loud', 'ATE24'), ('secret', 'ATE24'), ('meaningless', 'ATE24'), ('wrong', 'ATE24'), ('offscreen', 'ATE24'), ('lousy', 'ATE24'), ('brittle', 'ATE24'), ('blue', 'ATE24'), ('long', 'ATE24'), ('pink', 'ATE24'), ('full', 'ATE24'), ('candy', 'ATE24'), ('healthy', 'ATE24'), ('ominous', 'ATE24'), ('giddy', 'ATE24'), ('More', 'ATE24'), ('true', 'ATE24'), ('total', 'ATE24'), ('giant', 'ATE24'), ('magical', 'ATE24'), ('enraged', 'ATE24'), ('menacing', 'ATE24'), ('underway', 'ATE24'), ('behold', 'ATE24'), ('prepared', 'ATE24'), ('rockin', 'ATE24'), ('proud', 'ATE24'), ('gloomy', 'ATE24'), ('entire', 'ATE24'), ('virile', 'ATE24'), ('weird', 'ATE24'), ('only', 'ATE24'), ('front', 'ATE24'), ('right', 'ATE24'), ('magic', 'ATE24'), ('sound', 'ATE24')}
# {('tiny', 'ATE25'), ('beautiful', 'ATE25'), ('exciting', 'ATE25'), ('little', 'ATE25'), ('happy', 'ATE25'), ('last', 'ATE25'), ('active', 'ATE25'), ('mathematical', 'ATE25'), ('tough', 'ATE25'), ('complete', 'ATE25'), ('violent', 'ATE25'), ('more', 'ATE25'), ('hungry', 'ATE25'), ('secret', 'ATE25'), ('paunchy', 'ATE25'), ('hey', 'ATE25'), ('empty', 'ATE25'), ('heavy', 'ATE25'), ('horrible', 'ATE25'), ('evil', 'ATE25'), ('literal', 'ATE25'), ('useless', 'ATE25'), ('right', 'ATE25'), ('magic', 'ATE25'), ('smokin', 'ATE25'), ('inflatable', 'ATE25'), ('elated', 'ATE25'), ('new', 'ATE25'), ('different', 'ATE25'), ('first', 'ATE25'), ('easy', 'ATE25'), ('well', 'ATE25'), ('adequate', 'ATE25'), ('chunk', 'ATE25'), ('lumpy', 'ATE25'), ('old', 'ATE25'), ('legendary', 'ATE25'), ('wrong', 'ATE25'), ('halfway', 'ATE25'), ('extra', 'ATE25'), ('huge', 'ATE25'), ('frustrated', 'ATE25'), ('own', 'ATE25'), ('sure', 'ATE25'), ('robotic', 'ATE25'), ('content', 'ATE25'), ('great', 'ATE25'), ('hopeless', 'ATE25'), ('silly', 'ATE25'), ('much', 'ATE25'), ('funky', 'ATE25'), ('rowdy', 'ATE25'), ('terminal', 'ATE25'), ('fancy', 'ATE25'), ('serious', 'ATE25'), ('quiet', 'ATE25'), ('mini', 'ATE25'), ('pointless', 'ATE25'), ('weird', 'ATE25'), ('nonviolent', 'ATE25'), ('powerful', 'ATE25'), ('cool', 'ATE25'), ('hot', 'ATE25'), ('other', 'ATE25'), ('dead', 'ATE25'), ('clear', 'ATE25'), ('bad', 'ATE25'), ('pained', 'ATE25'), ('good', 'ATE25'), ('small', 'ATE25'), ('broken', 'ATE25'), ('weeeelcooome', 'ATE25'), ('freakin', 'ATE25'), ('left', 'ATE25'), ('alive', 'ATE25'), ('righteous', 'ATE25'), ('free', 'ATE25'), ('very', 'ATE25'), ('medical', 'ATE25'), ('cyborg', 'ATE25'), ('bummed', 'ATE25'), ('musical', 'ATE25'), ('More', 'ATE25'), ('true', 'ATE25')}
# {('odd', 'ATE19'), ('own', 'ATE19'), ('beautiful', 'ATE19'), ('right', 'ATE19'), ('-', 'ATE19'), ('sorry', 'ATE19'), ('crooked', 'ATE19'), ('oval', 'ATE19'), ('orange', 'ATE19'), ('evil', 'ATE19'), ('cold', 'ATE19'), ('pre', 'ATE19'), ('stupid', 'ATE19'), ('gooey', 'ATE19'), ('little', 'ATE19'), ('bubblegummy', 'ATE19'), ('innocent', 'ATE19'), ('golden', 'ATE19'), ('green', 'ATE19'), ('villainous', 'ATE19'), ('thick', 'ATE19'), ('okay', 'ATE19'), ('sucky', 'ATE19'), ('dead', 'ATE19'), ('mad', 'ATE19'), ('presumptuous', 'ATE19'), ('rare', 'ATE19'), ('tough', 'ATE19'), ('ok', 'ATE19'), ('royal', 'ATE19'), ('open', 'ATE19'), ('nice', 'ATE19'), ('bad', 'ATE19'), ('embarrassed', 'ATE19'), ('humanoid', 'ATE19'), ('wonderful', 'ATE19'), ('unknown', 'ATE19'), ('bald', 'ATE19'), ('good', 'ATE19'), ('flush', 'ATE19'), ('small', 'ATE19'), ('wet', 'ATE19'), ('strange', 'ATE19'), ('creepy', 'ATE19'), ('purple', 'ATE19'), ('bonkers', 'ATE19'), ('pet', 'ATE19'), ('enough', 'ATE19'), ('flawless', 'ATE19'), ('dear', 'ATE19'), ('necessary', 'ATE19'), ('long', 'ATE19'), ('ugly', 'ATE19'), ('blue', 'ATE19'), ('nuts', 'ATE19'), ('grave', 'ATE19'), ('lame', 'ATE19'), ('medical', 'ATE19'), ('pink', 'ATE19'), ('very', 'ATE19'), ('nearby', 'ATE19'), ('rancid', 'ATE19'), ('fair', 'ATE19'), ('unnoticed', 'ATE19'), ('written', 'ATE19'), ('privileged', 'ATE19'), ('distinguished', 'ATE19'), ('true', 'ATE19'), ('depressed', 'ATE19'), ('penitent', 'ATE19'), ('poor', 'ATE19'), ('mobile', 'ATE19'), ('rotten', 'ATE19')}
# {('radical', 'ATE26'), ('-', 'ATE26'), ('sharp', 'ATE26'), ('distant', 'ATE26'), ('fat', 'ATE26'), ('big', 'ATE26'), ('cute', 'ATE26'), ('scared', 'ATE26'), ('stupid', 'ATE26'), ('little', 'ATE26'), ('hot', 'ATE26'), ('sized', 'ATE26'), ('kiddin', 'ATE26'), ('different', 'ATE26'), ('several', 'ATE26'), ('mad', 'ATE26'), ('bad', 'ATE26'), ('worried', 'ATE26'), ('open', 'ATE26'), ('naughty', 'ATE26'), ('interesting', 'ATE26'), ('terrified', 'ATE26'), ('old', 'ATE26'), ('monstrous', 'ATE26'), ('good', 'ATE26'), ('more', 'ATE26'), ('creepy', 'ATE26'), ('crazy', 'ATE26'), ('enough', 'ATE26'), ('fit', 'ATE26'), ('awesome', 'ATE26'), ('like', 'ATE26'), ('free', 'ATE26'), ('spiky', 'ATE26'), ('very', 'ATE26'), ('nuts', 'ATE26'), ('obvious', 'ATE26'), ("wee'd", 'ATE26'), ('true', 'ATE26'), ('ridiculous', 'ATE26'), ('normal', 'ATE26'), ('wee', 'ATE26'), ('scary', 'ATE26'), ('huge', 'ATE26'), ('horrible', 'ATE26'), ('cutesy', 'ATE26'), ('perfect', 'ATE26'), ('weird', 'ATE26')}
# {('like', 'ATE22'), ('married', 'ATE22'), ('wrong', 'ATE22'), ('bombastic', 'ATE22'), ('blue', 'ATE22'), ('free', 'ATE22'), ('casual', 'ATE22'), ('adorable', 'ATE22'), ('hardcore', 'ATE22'), ('poor', 'ATE22'), ('immobile', 'ATE22'), ('evil', 'ATE22'), ('unholy', 'ATE22'), ('perfect', 'ATE22'), ('eeehhh', 'ATE22'), ('beautiful', 'ATE22'), ('horrific', 'ATE22'), ('radical', 'ATE22'), ('red', 'ATE22'), ('entire', 'ATE22'), ('many', 'ATE22'), ('right', 'ATE22'), ('rear', 'ATE22'), ('wild', 'ATE22'), ('sorry', 'ATE22'), ('late', 'ATE22'), ('cute', 'ATE22'), ('big', 'ATE22'), ('excited', 'ATE22'), ('sure', 'ATE22'), ('little', 'ATE22'), ('cool', 'ATE22'), ('triangular', 'ATE22'), ('happy', 'ATE22'), ('innocent', 'ATE22'), ('next', 'ATE22'), ('first', 'ATE22'), ('other', 'ATE22'), ('black', 'ATE22'), ('peach', 'ATE22'), ('single', 'ATE22'), ('sentient', 'ATE22'), ('yellow', 'ATE22'), ('dead', 'ATE22'), ('second', 'ATE22'), ('gray', 'ATE22'), ('favorite', 'ATE22'), ('liquid', 'ATE22'), ('bad', 'ATE22'), ('dimple', 'ATE22'), ('open', 'ATE22'), ('light', 'ATE22'), ('white', 'ATE22'), ('delicious', 'ATE22'), ('ready', 'ATE22'), ('wonderful', 'ATE22'), ('old', 'ATE22'), ('good', 'ATE22'), ('undead', 'ATE22'), ('more', 'ATE22'), ('lucky', 'ATE22'), ('crimson', 'ATE22'), ('human', 'ATE22'), ('enough', 'ATE22')}
# {('sorry', 'ATE23'), ('continuous', 'ATE23'), ('late', 'ATE23'), ('big', 'ATE23'), ('cute', 'ATE23'), ('dainty', 'ATE23'), ('stayin', 'ATE23'), ('robotic', 'ATE23'), ('mmmm', 'ATE23'), ('new', 'ATE23'), ('purposeless', 'ATE23'), ('cool', 'ATE23'), ('kick', 'ATE23'), ('happy', 'ATE23'), ('shut', 'ATE23'), ('other', 'ATE23'), ('latter', 'ATE23'), ('imaginative', 'ATE23'), ('mine', 'ATE23'), ('mad', 'ATE23'), ('okay', 'ATE23'), ('easy', 'ATE23'), ('well', 'ATE23'), ('about', 'ATE23'), ('amazing', 'ATE23'), ('clear', 'ATE23'), ('bad', 'ATE23'), ('former', 'ATE23'), ('mysterious', 'ATE23'), ('dark', 'ATE23'), ('young', 'ATE23'), ('interesting', 'ATE23'), ('ready', 'ATE23'), ('simple', 'ATE23'), ('good', 'ATE23'), ('hyper', 'ATE23'), ('regular', 'ATE23'), ('gentle', 'ATE23'), ('secret', 'ATE23'), ('like', 'ATE23'), ('alive', 'ATE23'), ('bombastic', 'ATE23'), ('short', 'ATE23'), ('intense', 'ATE23'), ('real', 'ATE23'), ('weak', 'ATE23'), ('awake', 'ATE23'), ('lame', 'ATE23'), ('invisible', 'ATE23'), ('imaginary', 'ATE23'), ('true', 'ATE23'), ('high', 'ATE23'), ('celebratory', 'ATE23'), ('few', 'ATE23'), ('cosmic', 'ATE23'), ('least', 'ATE23'), ('normal', 'ATE23'), ('naked', 'ATE23'), ('angry', 'ATE23'), ('beautiful', 'ATE23'), ('frustrated', 'ATE23'), ('near', 'ATE23'), ('own', 'ATE23'), ('healthy', 'ATE23'), ('rockin', 'ATE23'), ('civilized', 'ATE23')}
# {('regular', 'ATE21'), ('like', 'ATE21'), ('wrong', 'ATE21'), ('loud', 'ATE21'), ('such', 'ATE21'), ('short', 'ATE21'), ('dumb', 'ATE21'), ('fun', 'ATE21'), ('natural', 'ATE21'), ('blue', 'ATE21'), ('real', 'ATE21'), ('musical', 'ATE21'), ('deadly', 'ATE21'), ('giant', 'ATE21'), ('mixed', 'ATE21'), ('sensitive', 'ATE21'), ('incapable', 'ATE21'), ('normal', 'ATE21'), ('steady', 'ATE21'), ('sinister', 'ATE21'), ('comical', 'ATE21'), ('ninja', 'ATE21'), ('alright', 'ATE21'), ('perfect', 'ATE21'), ('angry', 'ATE21'), ('tiny', 'ATE21'), ('entire', 'ATE21'), ('lookin', 'ATE21'), ('right', 'ATE21'), ('sweet', 'ATE21'), ('feelin', 'ATE21'), ('siamese', 'ATE21'), ('sorry', 'ATE21'), ('calm', 'ATE21'), ('sure', 'ATE21'), ('cute', 'ATE21'), ('stupid', 'ATE21'), ('powerful', 'ATE21'), ('little', 'ATE21'), ('cool', 'ATE21'), ('new', 'ATE21'), ('careful', 'ATE21'), ('kiddin', 'ATE21'), ('common', 'ATE21'), ('jerky', 'ATE21'), ('pathetic', 'ATE21'), ('other', 'ATE21'), ('tragic', 'ATE21'), ('okay', 'ATE21'), ('great', 'ATE21'), ('mad', 'ATE21'), ('bottom', 'ATE21'), ('tall', 'ATE21'), ('ordinary', 'ATE21'), ('well', 'ATE21'), ('fine', 'ATE21'), ('pungent', 'ATE21'), ('rough', 'ATE21'), ('much', 'ATE21'), ('complicated', 'ATE21'), ('transparent', 'ATE21'), ('open', 'ATE21'), ('bad', 'ATE21'), ('twin', 'ATE21'), ('quick', 'ATE21'), ('tired', 'ATE21'), ('ready', 'ATE21'), ('old', 'ATE21'), ('complete', 'ATE21'), ('unknown', 'ATE21'), ('obnoxious', 'ATE21'), ('good', 'ATE21'), ('super', 'ATE21'), ('more', 'ATE21'), ('sticky', 'ATE21'), ('jowl', 'ATE21')}
# {('low', 'ATE20'), ('cute', 'ATE20'), ('hot', 'ATE20'), ('cool', 'ATE20'), ('top', 'ATE20'), ('light', 'ATE20'), ('humanoid', 'ATE20'), ('same', 'ATE20'), ('rid', 'ATE20'), ('miserable', 'ATE20'), ('small', 'ATE20'), ('wide', 'ATE20'), ('deep', 'ATE20'), ('enormous', 'ATE20'), ('accursed', 'ATE20'), ('makeshift', 'ATE20'), ('pink', 'ATE20'), ('full', 'ATE20'), ('worthless', 'ATE20'), ('magical', 'ATE20'), ('normal', 'ATE20'), ('tiny', 'ATE20'), ('mystical', 'ATE20'), ('orange', 'ATE20'), ('kind', 'ATE20'), ('big', 'ATE20'), ('homeless', 'ATE20'), ('little', 'ATE20'), ('happy', 'ATE20'), ('puzzled', 'ATE20'), ('about', 'ATE20'), ('embarrassed', 'ATE20'), ('mysterious', 'ATE20'), ('more', 'ATE20'), ('next', 'ATE20'), ('secret', 'ATE20'), ('surprised', 'ATE20'), ('emotional', 'ATE20'), ('least', 'ATE20'), ('poor', 'ATE20'), ('evil', 'ATE20'), ('angry', 'ATE20'), ('close', 'ATE20'), ('perfect', 'ATE20'), ('only', 'ATE20'), ('right', 'ATE20'), ('magic', 'ATE20'), ('stinky', 'ATE20'), ('strong', 'ATE20'), ('tattered', 'ATE20'), ('single', 'ATE20'), ('beige', 'ATE20'), ('complicated', 'ATE20'), ('clumped', 'ATE20'), ('upset', 'ATE20'), ('nutty', 'ATE20'), ('old', 'ATE20'), ('original', 'ATE20'), ('indistinct', 'ATE20'), ('fancy', 'ATE20'), ('wrong', 'ATE20'), ('frickin', 'ATE20'), ('huge', 'ATE20'), ('welcome', 'ATE20'), ('red', 'ATE20'), ('fat', 'ATE20'), ('sick', 'ATE20'), ('distraught', 'ATE20'), ('sure', 'ATE20'), ('other', 'ATE20'), ('green', 'ATE20'), ('great', 'ATE20'), ('second', 'ATE20'), ('afraid', 'ATE20'), ('worried', 'ATE20'), ('nice', 'ATE20'), ('worth', 'ATE20'), ('unsure', 'ATE20'), ('good', 'ATE20'), ('headed', 'ATE20'), ('regular', 'ATE20'), ('blue', 'ATE20'), ('darn', 'ATE20'), ('depressed', 'ATE20'), ('giant', 'ATE20'), ('brown', 'ATE20'), ('comfortable', 'ATE20')}

# %% [markdown]
# ### Let's try dataframes to store these relations of word-form to unit
# Dataframes, supporteed by the pandas library in Python, facilitate handling data in spreadsheet / CSV / TSV format.
# We want to output some data to a TSV (tab-separated values file) so we can send it to network visualization software.
#
# We'll need to open a terminal and  **pip install pandas** (or python3.12 -m pip install pandas) to get dataframes working.

# %%
import pandas as pd

def wordCollector(words, unit):
    wordList = []
    nodeAtts = []
    unitList = []
    for token in words:
        if token.pos_ == "ADJ":
            wordList.append(token.lemma_)
            nodeAtts.append(token.pos_)
            unitList.append(unit)

    data = {
        'word': wordList,
        'nodeType': nodeAtts,
        'unit': unitList
    }
    df = pd.DataFrame(data)
    return df

for file in os.listdir(collPath):
    if file.endswith(".txt"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            spacyRead = nlp(readFile)
            myDataFrame = wordCollector(spacyRead, name)
            print(myDataFrame)
# Out:
#          word nodeType   unit
# 0       magic      ADJ  ATE11
# 1        free      ADJ  ATE11
# 2        rash      ADJ  ATE11
# 3      sunken      ADJ  ATE11
# 4    lifeless      ADJ  ATE11
# ..        ...      ...    ...
# 126      good      ADJ  ATE11
# 127      glad      ADJ  ATE11
# 128     naked      ADJ  ATE11
# 129      free      ADJ  ATE11
# 130      full      ADJ  ATE11
#
# [131 rows x 3 columns]
#          word nodeType   unit
# 0       squid      ADJ  ATE10
# 1       other      ADJ  ATE10
# 2        many      ADJ  ATE10
# 3         bad      ADJ  ATE10
# 4       human      ADJ  ATE10
# ..        ...      ...    ...
# 98      ready      ADJ  ATE10
# 99      ready      ADJ  ATE10
# 100   several      ADJ  ATE10
# 101     naked      ADJ  ATE10
# 102  gorgeous      ADJ  ATE10
#
# [103 rows x 3 columns]
#          word nodeType   unit
# 0   vaporized      ADJ  ATE12
# 1        true      ADJ  ATE12
# 2      honest      ADJ  ATE12
# 3        true      ADJ  ATE12
# 4    reliable      ADJ  ATE12
# ..        ...      ...    ...
# 58      ready      ADJ  ATE12
# 59        fun      ADJ  ATE12
# 60       dead      ADJ  ATE12
# 61   hardcore      ADJ  ATE12
# 62        old      ADJ  ATE12
#
# [63 rows x 3 columns]
#       word nodeType   unit
# 0     slow      ADJ  ATE13
# 1    ready      ADJ  ATE13
# 2     hard      ADJ  ATE13
# 3      aoh      ADJ  ATE13
# 4     hard      ADJ  ATE13
# ..     ...      ...    ...
# 87    good      ADJ  ATE13
# 88  virgin      ADJ  ATE13
# 89  second      ADJ  ATE13
# 90    pure      ADJ  ATE13
# 91   naked      ADJ  ATE13
#
# [92 rows x 3 columns]
#         word nodeType   unit
# 0     glazed      ADJ  ATE17
# 1       open      ADJ  ATE17
# 2       okay      ADJ  ATE17
# 3      bored      ADJ  ATE17
# 4       good      ADJ  ATE17
# ..       ...      ...    ...
# 90     lousy      ADJ  ATE17
# 91     right      ADJ  ATE17
# 92   married      ADJ  ATE17
# 93  official      ADJ  ATE17
# 94    normal      ADJ  ATE17
#
# [95 rows x 3 columns]
#          word nodeType   unit
# 0        dark      ADJ  ATE16
# 1       gross      ADJ  ATE16
# 2         red      ADJ  ATE16
# 3     ominous      ADJ  ATE16
# 4        slow      ADJ  ATE16
# ..        ...      ...    ...
# 89      great      ADJ  ATE16
# 90      nasty      ADJ  ATE16
# 91  wonderful      ADJ  ATE16
# 92      least      ADJ  ATE16
# 93   maniacal      ADJ  ATE16
#
# [94 rows x 3 columns]
#           word nodeType   unit
# 0       locked      ADJ  ATE14
# 1         cool      ADJ  ATE14
# 2          bad      ADJ  ATE14
# 3    poisonous      ADJ  ATE14
# 4        magic      ADJ  ATE14
# ..         ...      ...    ...
# 99         big      ADJ  ATE14
# 100      great      ADJ  ATE14
# 101     cutesy      ADJ  ATE14
# 102       cute      ADJ  ATE14
# 103       glad      ADJ  ATE14
#
# [104 rows x 3 columns]
#          word nodeType   unit
# 0       funny      ADJ  ATE15
# 1       funny      ADJ  ATE15
# 2      mortal      ADJ  ATE15
# 3        hard      ADJ  ATE15
# 4        long      ADJ  ATE15
# ..        ...      ...    ...
# 69      angry      ADJ  ATE15
# 70       full      ADJ  ATE15
# 71  beautiful      ADJ  ATE15
# 72  imaginary      ADJ  ATE15
# 73     little      ADJ  ATE15
#
# [74 rows x 3 columns]
#          word nodeType  unit
# 0      pretty      ADJ  ATE1
# 1        full      ADJ  ATE1
# 2   different      ADJ  ATE1
# 3        more      ADJ  ATE1
# 4   explosive      ADJ  ATE1
# ..        ...      ...   ...
# 82       full      ADJ  ATE1
# 83      awake      ADJ  ATE1
# 84   adorable      ADJ  ATE1
# 85  delicious      ADJ  ATE1
# 86  delicious      ADJ  ATE1
#
# [87 rows x 3 columns]
#         word nodeType  unit
# 0       high      ADJ  ATE3
# 1      giant      ADJ  ATE3
# 2        big      ADJ  ATE3
# 3       holy      ADJ  ATE3
# 4        big      ADJ  ATE3
# ..       ...      ...   ...
# 76      star      ADJ  ATE3
# 77  ticklish      ADJ  ATE3
# 78   welcome      ADJ  ATE3
# 79     gross      ADJ  ATE3
# 80     sorry      ADJ  ATE3
#
# [81 rows x 3 columns]
#        word nodeType  unit
# 0       big      ADJ  ATE2
# 1      more      ADJ  ATE2
# 2      hard      ADJ  ATE2
# 3      easy      ADJ  ATE2
# 4       big      ADJ  ATE2
# ..      ...      ...   ...
# 97     last      ADJ  ATE2
# 98     good      ADJ  ATE2
# 99    lumpy      ADJ  ATE2
# 100    lame      ADJ  ATE2
# 101  normal      ADJ  ATE2
#
# [102 rows x 3 columns]
#        word nodeType  unit
# 0   unknown      ADJ  ATE6
# 1    little      ADJ  ATE6
# 2    little      ADJ  ATE6
# 3    little      ADJ  ATE6
# 4     small      ADJ  ATE6
# ..      ...      ...   ...
# 83     pink      ADJ  ATE6
# 84  enraged      ADJ  ATE6
# 85      own      ADJ  ATE6
# 86     wild      ADJ  ATE6
# 87   normal      ADJ  ATE6
#
# [88 rows x 3 columns]
#          word nodeType  unit
# 0     foolish      ADJ  ATE7
# 1   posterior      ADJ  ATE7
# 2   posterior      ADJ  ATE7
# 3   posterior      ADJ  ATE7
# 4       other      ADJ  ATE7
# ..        ...      ...   ...
# 92    jealous      ADJ  ATE7
# 93    jealous      ADJ  ATE7
# 94  posterior      ADJ  ATE7
# 95       deep      ADJ  ATE7
# 96     normal      ADJ  ATE7
#
# [97 rows x 3 columns]
#           word nodeType  unit
# 0        crazy      ADJ  ATE5
# 1    wonderful      ADJ  ATE5
# 2    marvelous      ADJ  ATE5
# 3         safe      ADJ  ATE5
# 4       secret      ADJ  ATE5
# ..         ...      ...   ...
# 119    magical      ADJ  ATE5
# 120    mannish      ADJ  ATE5
# 121    mannish      ADJ  ATE5
# 122    mannish      ADJ  ATE5
# 123    mannish      ADJ  ATE5
#
# [124 rows x 3 columns]
#          word nodeType  unit
# 0        good      ADJ  ATE4
# 1         new      ADJ  ATE4
# 2         new      ADJ  ATE4
# 3   delicious      ADJ  ATE4
# 4        good      ADJ  ATE4
# ..        ...      ...   ...
# 75       okay      ADJ  ATE4
# 76       okay      ADJ  ATE4
# 77     stupid      ADJ  ATE4
# 78     stupid      ADJ  ATE4
# 79   shocking      ADJ  ATE4
#
# [80 rows x 3 columns]
#         word nodeType  unit
# 0      great      ADJ  ATE9
# 1     normal      ADJ  ATE9
# 2       late      ADJ  ATE9
# 3       next      ADJ  ATE9
# 4    awesome      ADJ  ATE9
# ..       ...      ...   ...
# 105      old      ADJ  ATE9
# 106     good      ADJ  ATE9
# 107    sorry      ADJ  ATE9
# 108   stupid      ADJ  ATE9
# 109   stupid      ADJ  ATE9
#
# [110 rows x 3 columns]
#         word nodeType  unit
# 0    several      ADJ  ATE8
# 1       more      ADJ  ATE8
# 2       more      ADJ  ATE8
# 3     chubby      ADJ  ATE8
# 4     enough      ADJ  ATE8
# ..       ...      ...   ...
# 126       ok      ADJ  ATE8
# 127      red      ADJ  ATE8
# 128      red      ADJ  ATE8
# 129   normal      ADJ  ATE8
# 130    stark      ADJ  ATE8
#
# [131 rows x 3 columns]
#            word nodeType   unit
# 0         royal      ADJ  ATE18
# 1          last      ADJ  ATE18
# 2     dangerous      ADJ  ATE18
# 3       awesome      ADJ  ATE18
# 4        secret      ADJ  ATE18
# ..          ...      ...    ...
# 85        angry      ADJ  ATE18
# 86         well      ADJ  ATE18
# 87  intelligent      ADJ  ATE18
# 88         darn      ADJ  ATE18
# 89        right      ADJ  ATE18
#
# [90 rows x 3 columns]
#          word nodeType   unit
# 0      secret      ADJ  ATE24
# 1    underway      ADJ  ATE24
# 2        loud      ADJ  ATE24
# 3       front      ADJ  ATE24
# 4     brittle      ADJ  ATE24
# ..        ...      ...    ...
# 99   lifeless      ADJ  ATE24
# 100      mean      ADJ  ATE24
# 101  lifeless      ADJ  ATE24
# 102      dead      ADJ  ATE24
# 103      dead      ADJ  ATE24
#
# [104 rows x 3 columns]
#            word nodeType   unit
# 0         great      ADJ  ATE25
# 1          last      ADJ  ATE25
# 2      terminal      ADJ  ATE25
# 3    inflatable      ADJ  ATE25
# 4          mini      ADJ  ATE25
# ..          ...      ...    ...
# 125        very      ADJ  ATE25
# 126     literal      ADJ  ATE25
# 127     freakin      ADJ  ATE25
# 128         old      ADJ  ATE25
# 129         old      ADJ  ATE25
#
# [130 rows x 3 columns]
#         word nodeType   unit
# 0     nearby      ADJ  ATE19
# 1     purple      ADJ  ATE19
# 2   humanoid      ADJ  ATE19
# 3     orange      ADJ  ATE19
# 4      green      ADJ  ATE19
# ..       ...      ...    ...
# 94      oval      ADJ  ATE19
# 95         -      ADJ  ATE19
# 96      oval      ADJ  ATE19
# 97         -      ADJ  ATE19
# 98      open      ADJ  ATE19
#
# [99 rows x 3 columns]
#         word nodeType   unit
# 0   horrible      ADJ  ATE26
# 1    distant      ADJ  ATE26
# 2    several      ADJ  ATE26
# 3    awesome      ADJ  ATE26
# 4        big      ADJ  ATE26
# ..       ...      ...    ...
# 84       hot      ADJ  ATE26
# 85     spiky      ADJ  ATE26
# 86   naughty      ADJ  ATE26
# 87     spiky      ADJ  ATE26
# 88     spiky      ADJ  ATE26
#
# [89 rows x 3 columns]
#         word nodeType   unit
# 0       many      ADJ  ATE22
# 1        old      ADJ  ATE22
# 2       poor      ADJ  ATE22
# 3        old      ADJ  ATE22
# 4        old      ADJ  ATE22
# ..       ...      ...    ...
# 113  radical      ADJ  ATE22
# 114     free      ADJ  ATE22
# 115     cool      ADJ  ATE22
# 116      big      ADJ  ATE22
# 117    right      ADJ  ATE22
#
# [118 rows x 3 columns]
#      word nodeType   unit
# 0   ready      ADJ  ATE23
# 1   ready      ADJ  ATE23
# 2    cool      ADJ  ATE23
# 3    dark      ADJ  ATE23
# 4     big      ADJ  ATE23
# ..    ...      ...    ...
# 85  naked      ADJ  ATE23
# 86   okay      ADJ  ATE23
# 87   mmmm      ADJ  ATE23
# 88  clear      ADJ  ATE23
# 89   good      ADJ  ATE23
#
# [90 rows x 3 columns]
#           word nodeType   unit
# 0         tall      ADJ  ATE21
# 1     ordinary      ADJ  ATE21
# 2       little      ADJ  ATE21
# 3     ordinary      ADJ  ATE21
# 4       little      ADJ  ATE21
# ..         ...      ...    ...
# 109  obnoxious      ADJ  ATE21
# 110      ready      ADJ  ATE21
# 111        new      ADJ  ATE21
# 112      sorry      ADJ  ATE21
# 113      tired      ADJ  ATE21
#
# [114 rows x 3 columns]
#             word nodeType   unit
# 0     mysterious      ADJ  ATE20
# 1       tattered      ADJ  ATE20
# 2           poor      ADJ  ATE20
# 3            old      ADJ  ATE20
# 4      surprised      ADJ  ATE20
# ..           ...      ...    ...
# 130     original      ADJ  ATE20
# 131       strong      ADJ  ATE20
# 132  embarrassed      ADJ  ATE20
# 133  complicated      ADJ  ATE20
# 134          old      ADJ  ATE20
#
# [135 rows x 3 columns]

# %% [markdown]
# ## Write the dataframes to an output TSV file
# TSV means **tab-separated-values**. We'll use the tab character as a separator.
# The other popular alternative is the CSV: **comma-separated-values**, which uses the comma as a separator.
# You can use either one for our network data.
#
# I'm going to output some "node attributes" for tne network. In a network visualization, we'll want to be able to quickly distinguish the word nodes from the unit nodes (possibly by shape), and providing a qualifier or "node attribute" in the dataframe will be helpful.
# We can add other kinds of node attributes perhaps as numerical ranges (see below).

# %%
import pandas as pd

def wordCollector(words, unit):
    wordList = []
    nodeAtts = []
    unitList = []
    for token in words:
        if token.pos_ == "ADJ":
            wordList.append(token.lemma_)
            nodeAtts.append(token.pos_)
            unitList.append(unit)

    data = {
        'word': wordList,
        'nodeType': nodeAtts,
        'unit': unitList
    }
    df = pd.DataFrame(data)
    return df
    # This is returning a separate dataframe for every source text file. 

# We need to consolidate all the dataframes into one file. Collect all dataframes here!
allDataFrames = []

for file in os.listdir(collPath):
    if file.endswith(".txt"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            spacyRead = nlp(readFile)
            myDataFrame = wordCollector(spacyRead, name)
            # Add each individual dataframe as it comes out into the list of dataframes!
            allDataFrames.append(myDataFrame)

# Make an output filepath
outputFilePath = 'networkData.tsv'
# Turn the list of dataframes into one dataframe:
fullDataFrame = pd.concat(allDataFrames, ignore_index=True)
# print(fullDataFrame)

# Note, since Pandas knows how to open and write files line by line, we can skip that open() step we used last time.
fullDataFrame.to_csv(outputFilePath, sep='\t', index=False)
print('I just saved a dataframe as a TSV file.')
# Go check your filestash for the file.
# Out:
# I just saved a dataframe as a TSV file.

# %% [markdown]
# ### Something to try...
# * Try developing this to return synsets from WordNet.
# * Add an Ambiguity metric to count the number of synsets it belongs to.
# * Output this as a second "node attribute" qualifier to the Part of Speech. We could use that to color-code the words by ambiguity...

# %%
# This time, with Wordnet data!
import pandas as pd
import nltk
from nltk.corpus import wordnet as wn

def wordCollector(words, unit):
    wordList = []
    nodeAtts = []
    synsetCounts = []
    unitList = []
    for token in words:
        if token.pos_ == "ADJ":
            synsets = len(wn.synsets(token.lemma_))
            # We should be able to look up and count those synsets right here!          
            wordList.append(token.lemma_)
            nodeAtts.append(token.pos_)
            synsetCounts.append(synsets)
            unitList.append(unit)
                          
    data = {
        'word': wordList,
        'nodeType': nodeAtts,
        'synsetCount': synsetCounts,
        'unit': unitList
    }
    df = pd.DataFrame(data)
    return df
    # This is returning a separate dataframe for every source text file. 

# We need to consolidate all the dataframes into one file. Collect all dataframes here!
allDataFrames = []

for file in os.listdir(collPath):
    if file.endswith(".txt"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            spacyRead = nlp(readFile)
            myDataFrame = wordCollector(spacyRead, name)
            # Add each individual dataframe as it comes out into the list of dataframes!
            allDataFrames.append(myDataFrame)

# Make an output filepath
outputFilePath = 'networkData-2.tsv'
# Turn the list of dataframes into one dataframe:
fullDataFrame = pd.concat(allDataFrames, ignore_index=True)

# Note, since Pandas knows how to open and write files line by line, we can skip that open() step we used last time.
fullDataFrame.to_csv(outputFilePath, sep='\t', index=False)
print('I just saved a NEW dataframe as a NEW TSV file.')
# Go check your filestash for the file.
# Out:
# I just saved a NEW dataframe as a NEW TSV file.

# %% [markdown]
# ## What will we do with this fancy TSV?
#
# We can analyze it as a **network** of data using network analysis. You could try importing your TSV into kumu.io, but we're going to introduce Cytoscape, which is a very powerful, artful method with lots of visualization options.
#
# To view the data we extracted in this notebook as an SVG export from Cytoscape, see <https://raw.githubusercontent.com/newtfire/textAnalysis-Hub/refs/heads/main/Class-Examples/Python/readFileCollections-examples/network-analysis-via-python/networkData-2.svg>

# %% [markdown]
# ## Your Turn!
# Adapt this notebook to explore one or more of your project files and prepare some network data of your own.
#
# * Output a CSV or TSV of data from your project for import into our network visualization software.
# * [Install Cytoscape](https://cytoscape.org/) on your computer and check to make sure it is working.
#      * Cytoscape now comes bundled with its own Java, so you should be good to go for running it (much like oXygen). If you have trouble, work through the [Troubleshooting](https://cytoscape.org/troubleshooting.html) guide first. Bring questions to class or via Canvas!
#      * After you install Cytoscape, see if you can also install the yFiles Layout Algorithms. Open Cytoscape, go to **Layout → Install yFiles**, which directs you to an App store to download it and apply it to Cytoscape.
